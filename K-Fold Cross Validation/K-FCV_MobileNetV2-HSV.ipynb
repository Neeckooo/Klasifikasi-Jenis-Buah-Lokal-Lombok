# %%
import numpy as np
import pandas as pd
import pathlib
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.applications import MobileNetV2
from sklearn.metrics import confusion_matrix
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from sklearn.model_selection import KFold

# %%
# Parameter
train_dir = "D:/kuliah/Tugas Akhir/Code/Klasifikasi Jenis Buah Lokal/dataset/hsv_dataset/train"
validation_dir = "D:/kuliah/Tugas Akhir/Code/Klasifikasi Jenis Buah Lokal/dataset/hsv_dataset/val"
test_dir = "D:/kuliah/Tugas Akhir/Code/Klasifikasi Jenis Buah Lokal/dataset/test" 
k = 3  # Jumlah fold untuk K-FCV
epochs = 50  # Jumlah epoch untuk training model per fold
batch_size = 64  # Batch size

# Image size
IMG_SIZE = (300, 300)

# %%
# Import data
train_datagen = ImageDataGenerator(rescale=1.0 / 255)
test_datagen = ImageDataGenerator(rescale=1.0 / 255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=IMG_SIZE,
    batch_size=batch_size,
    class_mode="categorical",
    shuffle=True
)

validation_generator = test_datagen.flow_from_directory(
    validation_dir,
    target_size=IMG_SIZE,
    batch_size=batch_size,
    class_mode="categorical",
    shuffle=False
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=IMG_SIZE,
    batch_size=batch_size,
    class_mode="categorical",
    shuffle=False
)
# Out:
# Found 2100 images belonging to 3 classes.
# Found 600 images belonging to 3 classes.
# Found 300 images belonging to 3 classes.

# %%
def get_batch(generator, index):
    data = []
    labels = []
    for i in index:
        x, y = generator[i]
        data.extend(x)
        labels.extend(y)
    return np.array(data), np.array(labels)

# %%
def create_model():
    base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(300, 300, 3))
    model = Sequential([
        base_model,
        Flatten(),
        Dropout(0.5),
        Dense(16, activation="relu"),
        Dropout(0.5),
        Dense(3, activation="softmax"),
    ])

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
        loss="categorical_crossentropy",
        metrics=["accuracy", tf.keras.metrics.Precision(), tf.keras.metrics.Recall()],
    )
    
    return model

model = create_model()
print(model.summary())
# Out:
# <ipython-input-26-ca7b5d164f6f>:2: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(300, 300, 3))
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ mobilenetv2_1.00_224            │ ?                      │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,257,984 (8.61 MB)
#  Trainable params: 2,223,872 (8.48 MB)
#  Non-trainable params: 34,112 (133.25 KB)
# None

# %%
def plot_history(history_list, k):
    fig, axs = plt.subplots(nrows=k, ncols=2, figsize=(12, k * 4))

    for i, history in enumerate(history_list):
        # Plot Accuracy
        axs[i, 0].plot(history['accuracy'], label=f'Train Fold {i+1}')
        axs[i, 0].plot(history['val_accuracy'], label=f'Validation Fold {i+1}')
        axs[i, 0].set_title(f'Fold {i+1} - Training and Validation Accuracy')
        axs[i, 0].set_xlabel('Epochs')
        axs[i, 0].set_ylabel('Accuracy')
        axs[i, 0].legend()

        # Plot Loss
        axs[i, 1].plot(history['loss'], label=f'Train Fold {i+1}')
        axs[i, 1].plot(history['val_loss'], label=f'Validation Fold {i+1}')
        axs[i, 1].set_title(f'Fold {i+1} - Training and Validation Loss')
        axs[i, 1].set_xlabel('Epochs')
        axs[i, 1].set_ylabel('Loss')
        axs[i, 1].legend()

    plt.tight_layout()
    plt.show()

# %%
# Evaluasi dengan K-FCV
history_list = []
average_acc = 0
average_loss = 0

kf = KFold(n_splits=k, shuffle=True, random_state=42)

# List to store accuracy and loss for each fold
fold_accuracy = []
fold_loss = []
test_accuracies = []

for fold, (train_index, val_index) in enumerate(kf.split(train_generator)):
    # Dapatkan batch data pelatihan dan validasi berdasarkan indeks fold
    train_data, train_labels = get_batch(train_generator, train_index)
    val_data, val_labels = get_batch(train_generator, val_index)

    # Buat model baru untuk setiap fold
    model = create_model()

    # Latih model menggunakan data pelatihan
    history = model.fit(
        train_data,
        train_labels,
        epochs=epochs,
        validation_data=(val_data, val_labels),
        verbose=1,  # Tampilkan informasi training per epoch
    )

    history_list.append(history.history)

    # Save the model for each fold
    model.save(f"D:/kuliah/Tugas Akhir/Code/Klasifikasi Jenis Buah Lokal/models/K-Fold Validation/MobileNetV2-HSV_fold_{fold+1}.h5")
    

    # Evaluate the model using the validation data
    val_loss, val_accuracy, val_precision, val_recall = model.evaluate(val_data, val_labels)
    fold_accuracy.append(val_accuracy)
    fold_loss.append(val_loss)

    print(f"Fold {fold+1} - Validation Accuracy: {val_accuracy}")
    print(f"Fold {fold+1} - Validation Loss: {val_loss}")

    # Evaluate the model using the test data
    test_loss, test_accuracy, test_precision, test_recall = model.evaluate(test_generator)
    test_accuracies.append(test_accuracy)
    print(f"Fold {fold+1} - Test Accuracy: {test_accuracy}")
    print(f"Fold {fold+1} - Test Loss: {test_loss}")

# Calculate average accuracy and loss across all folds
average_acc = np.mean(fold_accuracy)
average_loss = np.mean(fold_loss)
average_test_accuracy = np.mean(test_accuracies)

print(f"\nAverage Validation Accuracy: {average_acc}")
print(f"Average Validation Loss: {average_loss}")
print(f"\nAverage Test Accuracy: {average_test_accuracy}")

# Plotting hasil training dan validasi untuk setiap fold
plot_history(history_list, k)
# Out:
# <ipython-input-26-ca7b5d164f6f>:2: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(300, 300, 3))
# Epoch 1/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 196s 4s/step - accuracy: 0.6629 - loss: 0.9181 - precision_8: 0.7559 - recall_8: 0.5619 - val_accuracy: 0.9318 - val_loss: 0.2436 - val_precision_8: 0.9356 - val_recall_8: 0.9290
# Epoch 2/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9346 - loss: 0.1551 - precision_8: 0.9648 - recall_8: 0.8984 - val_accuracy: 0.9247 - val_loss: 0.2366 - val_precision_8: 0.9327 - val_recall_8: 0.9247
# Epoch 3/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 170s 4s/step - accuracy: 0.9662 - loss: 0.0710 - precision_8: 0.9839 - recall_8: 0.9494 - val_accuracy: 0.9418 - val_loss: 0.2250 - val_precision_8: 0.9430 - val_recall_8: 0.9403
# Epoch 4/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 170s 4s/step - accuracy: 0.9699 - loss: 0.0720 - precision_8: 0.9805 - recall_8: 0.9448 - val_accuracy: 0.9489 - val_loss: 0.1920 - val_precision_8: 0.9489 - val_recall_8: 0.9489
# Epoch 5/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 170s 4s/step - accuracy: 0.9617 - loss: 0.0711 - precision_8: 0.9734 - recall_8: 0.9431 - val_accuracy: 0.9886 - val_loss: 0.0644 - val_precision_8: 0.9886 - val_recall_8: 0.9886
# Epoch 6/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 170s 4s/step - accuracy: 0.9524 - loss: 0.0775 - precision_8: 0.9733 - recall_8: 0.9270 - val_accuracy: 0.9773 - val_loss: 0.1140 - val_precision_8: 0.9773 - val_recall_8: 0.9773
# Epoch 7/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9637 - loss: 0.0568 - precision_8: 0.9866 - recall_8: 0.9458 - val_accuracy: 0.9886 - val_loss: 0.0631 - val_precision_8: 0.9886 - val_recall_8: 0.9886
# Epoch 8/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 170s 4s/step - accuracy: 0.9616 - loss: 0.0660 - precision_8: 0.9788 - recall_8: 0.9355 - val_accuracy: 0.9872 - val_loss: 0.0705 - val_precision_8: 0.9872 - val_recall_8: 0.9872
# Epoch 9/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 170s 4s/step - accuracy: 0.9839 - loss: 0.0404 - precision_8: 0.9907 - recall_8: 0.9657 - val_accuracy: 0.9844 - val_loss: 0.0782 - val_precision_8: 0.9844 - val_recall_8: 0.9844
# Epoch 10/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 170s 4s/step - accuracy: 0.9876 - loss: 0.0459 - precision_8: 0.9962 - recall_8: 0.9713 - val_accuracy: 0.9574 - val_loss: 0.1868 - val_precision_8: 0.9601 - val_recall_8: 0.9574
# Epoch 11/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 170s 4s/step - accuracy: 0.9853 - loss: 0.0573 - precision_8: 0.9992 - recall_8: 0.9622 - val_accuracy: 0.9688 - val_loss: 0.1517 - val_precision_8: 0.9688 - val_recall_8: 0.9688
# Epoch 12/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 170s 4s/step - accuracy: 0.9816 - loss: 0.0486 - precision_8: 0.9951 - recall_8: 0.9667 - val_accuracy: 0.9830 - val_loss: 0.0764 - val_precision_8: 0.9830 - val_recall_8: 0.9830
# Epoch 13/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 170s 4s/step - accuracy: 0.9872 - loss: 0.0599 - precision_8: 0.9956 - recall_8: 0.9536 - val_accuracy: 0.9858 - val_loss: 0.0575 - val_precision_8: 0.9858 - val_recall_8: 0.9858
# Epoch 14/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 170s 4s/step - accuracy: 0.9858 - loss: 0.0379 - precision_8: 0.9964 - recall_8: 0.9693 - val_accuracy: 0.9830 - val_loss: 0.0673 - val_precision_8: 0.9830 - val_recall_8: 0.9830
# Epoch 15/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 169s 4s/step - accuracy: 0.9848 - loss: 0.0341 - precision_8: 0.9955 - recall_8: 0.9704 - val_accuracy: 0.9943 - val_loss: 0.0265 - val_precision_8: 0.9943 - val_recall_8: 0.9943
# Epoch 16/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9821 - loss: 0.0472 - precision_8: 0.9970 - recall_8: 0.9591 - val_accuracy: 0.9915 - val_loss: 0.0495 - val_precision_8: 0.9915 - val_recall_8: 0.9915
# Epoch 17/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9847 - loss: 0.0371 - precision_8: 0.9997 - recall_8: 0.9682 - val_accuracy: 0.9943 - val_loss: 0.0363 - val_precision_8: 0.9943 - val_recall_8: 0.9943
# Epoch 18/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 170s 4s/step - accuracy: 0.9863 - loss: 0.0481 - precision_8: 0.9946 - recall_8: 0.9613 - val_accuracy: 0.9915 - val_loss: 0.0506 - val_precision_8: 0.9915 - val_recall_8: 0.9915
# Epoch 19/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9864 - loss: 0.0438 - precision_8: 0.9992 - recall_8: 0.9624 - val_accuracy: 0.9929 - val_loss: 0.0424 - val_precision_8: 0.9929 - val_recall_8: 0.9929
# Epoch 20/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 166s 4s/step - accuracy: 0.9817 - loss: 0.0470 - precision_8: 0.9928 - recall_8: 0.9577 - val_accuracy: 0.9929 - val_loss: 0.0425 - val_precision_8: 0.9929 - val_recall_8: 0.9929
# Epoch 21/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 167s 4s/step - accuracy: 0.9916 - loss: 0.0475 - precision_8: 0.9998 - recall_8: 0.9564 - val_accuracy: 0.9886 - val_loss: 0.0486 - val_precision_8: 0.9886 - val_recall_8: 0.9886
# Epoch 22/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9848 - loss: 0.0437 - precision_8: 0.9996 - recall_8: 0.9614 - val_accuracy: 0.9886 - val_loss: 0.0721 - val_precision_8: 0.9886 - val_recall_8: 0.9886
# Epoch 23/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 170s 4s/step - accuracy: 0.9921 - loss: 0.0308 - precision_8: 0.9985 - recall_8: 0.9763 - val_accuracy: 0.9901 - val_loss: 0.1003 - val_precision_8: 0.9901 - val_recall_8: 0.9901
# Epoch 24/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 170s 4s/step - accuracy: 0.9828 - loss: 0.0408 - precision_8: 0.9985 - recall_8: 0.9656 - val_accuracy: 0.9943 - val_loss: 0.0384 - val_precision_8: 0.9943 - val_recall_8: 0.9943
# Epoch 25/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 170s 4s/step - accuracy: 0.9798 - loss: 0.0543 - precision_8: 0.9991 - recall_8: 0.9529 - val_accuracy: 0.9986 - val_loss: 0.0126 - val_precision_8: 0.9986 - val_recall_8: 0.9986
# Epoch 26/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 170s 4s/step - accuracy: 0.9867 - loss: 0.0466 - precision_8: 0.9965 - recall_8: 0.9618 - val_accuracy: 0.9972 - val_loss: 0.0088 - val_precision_8: 0.9972 - val_recall_8: 0.9972
# Epoch 27/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 170s 4s/step - accuracy: 0.9862 - loss: 0.0373 - precision_8: 0.9972 - recall_8: 0.9677 - val_accuracy: 0.9972 - val_loss: 0.0139 - val_precision_8: 0.9972 - val_recall_8: 0.9972
# Epoch 28/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9814 - loss: 0.0367 - precision_8: 0.9965 - recall_8: 0.9686 - val_accuracy: 0.9972 - val_loss: 0.0058 - val_precision_8: 0.9972 - val_recall_8: 0.9972
# Epoch 29/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9817 - loss: 0.0575 - precision_8: 0.9959 - recall_8: 0.9599 - val_accuracy: 0.9787 - val_loss: 0.1009 - val_precision_8: 0.9787 - val_recall_8: 0.9787
# Epoch 30/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 170s 4s/step - accuracy: 0.9884 - loss: 0.0369 - precision_8: 0.9966 - recall_8: 0.9702 - val_accuracy: 0.9915 - val_loss: 0.0532 - val_precision_8: 0.9915 - val_recall_8: 0.9915
# Epoch 31/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 170s 4s/step - accuracy: 0.9914 - loss: 0.0521 - precision_8: 0.9961 - recall_8: 0.9681 - val_accuracy: 0.9858 - val_loss: 0.1120 - val_precision_8: 0.9858 - val_recall_8: 0.9858
# Epoch 32/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9689 - loss: 0.0850 - precision_8: 0.9911 - recall_8: 0.9469 - val_accuracy: 0.9943 - val_loss: 0.0409 - val_precision_8: 0.9943 - val_recall_8: 0.9943
# Epoch 33/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9811 - loss: 0.0426 - precision_8: 0.9926 - recall_8: 0.9668 - val_accuracy: 0.9972 - val_loss: 0.0414 - val_precision_8: 0.9972 - val_recall_8: 0.9972
# Epoch 34/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 170s 4s/step - accuracy: 0.9774 - loss: 0.0641 - precision_8: 0.9936 - recall_8: 0.9506 - val_accuracy: 0.9943 - val_loss: 0.0482 - val_precision_8: 0.9943 - val_recall_8: 0.9943
# Epoch 35/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9862 - loss: 0.0358 - precision_8: 0.9974 - recall_8: 0.9703 - val_accuracy: 0.9943 - val_loss: 0.0503 - val_precision_8: 0.9943 - val_recall_8: 0.9943
# Epoch 36/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9806 - loss: 0.0456 - precision_8: 0.9996 - recall_8: 0.9587 - val_accuracy: 0.9957 - val_loss: 0.0340 - val_precision_8: 0.9957 - val_recall_8: 0.9957
# Epoch 37/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9792 - loss: 0.0459 - precision_8: 0.9987 - recall_8: 0.9580 - val_accuracy: 0.9957 - val_loss: 0.0239 - val_precision_8: 0.9957 - val_recall_8: 0.9957
# Epoch 38/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9725 - loss: 0.0599 - precision_8: 0.9993 - recall_8: 0.9448 - val_accuracy: 0.9957 - val_loss: 0.0145 - val_precision_8: 0.9957 - val_recall_8: 0.9957
# Epoch 39/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9880 - loss: 0.0429 - precision_8: 0.9973 - recall_8: 0.9637 - val_accuracy: 1.0000 - val_loss: 2.9836e-04 - val_precision_8: 1.0000 - val_recall_8: 1.0000
# Epoch 40/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9880 - loss: 0.0498 - precision_8: 0.9991 - recall_8: 0.9547 - val_accuracy: 1.0000 - val_loss: 4.2885e-05 - val_precision_8: 1.0000 - val_recall_8: 1.0000
# Epoch 41/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9888 - loss: 0.0394 - precision_8: 1.0000 - recall_8: 0.9633 - val_accuracy: 1.0000 - val_loss: 1.9867e-06 - val_precision_8: 1.0000 - val_recall_8: 1.0000
# Epoch 42/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9875 - loss: 0.0486 - precision_8: 0.9980 - recall_8: 0.9547 - val_accuracy: 1.0000 - val_loss: 9.2865e-07 - val_precision_8: 1.0000 - val_recall_8: 1.0000
# Epoch 43/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9880 - loss: 0.0293 - precision_8: 0.9995 - recall_8: 0.9728 - val_accuracy: 1.0000 - val_loss: 6.8343e-07 - val_precision_8: 1.0000 - val_recall_8: 1.0000
# Epoch 44/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9834 - loss: 0.0428 - precision_8: 0.9976 - recall_8: 0.9615 - val_accuracy: 1.0000 - val_loss: 1.6592e-06 - val_precision_8: 1.0000 - val_recall_8: 1.0000
# Epoch 45/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9907 - loss: 0.0400 - precision_8: 0.9962 - recall_8: 0.9678 - val_accuracy: 1.0000 - val_loss: 1.5255e-04 - val_precision_8: 1.0000 - val_recall_8: 1.0000
# Epoch 46/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9850 - loss: 0.0361 - precision_8: 0.9997 - recall_8: 0.9678 - val_accuracy: 1.0000 - val_loss: 7.3207e-04 - val_precision_8: 1.0000 - val_recall_8: 1.0000
# Epoch 47/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9898 - loss: 0.0258 - precision_8: 0.9977 - recall_8: 0.9762 - val_accuracy: 1.0000 - val_loss: 3.2256e-05 - val_precision_8: 1.0000 - val_recall_8: 1.0000
# Epoch 48/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9884 - loss: 0.0373 - precision_8: 0.9998 - recall_8: 0.9647 - val_accuracy: 1.0000 - val_loss: 6.5195e-07 - val_precision_8: 1.0000 - val_recall_8: 1.0000
# Epoch 49/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9830 - loss: 0.0384 - precision_8: 1.0000 - recall_8: 0.9647 - val_accuracy: 1.0000 - val_loss: 1.0058e-04 - val_precision_8: 1.0000 - val_recall_8: 1.0000
# Epoch 50/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9921 - loss: 0.0359 - precision_8: 0.9995 - recall_8: 0.9674 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_precision_8: 1.0000 - val_recall_8: 1.0000
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 16s 738ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - precision_8: 1.0000 - recall_8: 1.0000
# Fold 1 - Validation Accuracy: 1.0
# Fold 1 - Validation Loss: 0.0
# c:\Users\CATUR WARGA COMPUTER\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.9965 - loss: 0.0057 - precision_8: 0.9965 - recall_8: 0.9965
# Fold 1 - Test Accuracy: 0.9933333396911621
# Fold 1 - Test Loss: 0.01097078900784254
# Epoch 1/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 195s 4s/step - accuracy: 0.6568 - loss: 0.8523 - precision_9: 0.7029 - recall_9: 0.6021 - val_accuracy: 0.9489 - val_loss: 0.1817 - val_precision_9: 0.9489 - val_recall_9: 0.9489
# Epoch 2/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9308 - loss: 0.1330 - precision_9: 0.9410 - recall_9: 0.9166 - val_accuracy: 0.9403 - val_loss: 0.2469 - val_precision_9: 0.9403 - val_recall_9: 0.9389
# Epoch 3/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9365 - loss: 0.1093 - precision_9: 0.9483 - recall_9: 0.9182 - val_accuracy: 0.9957 - val_loss: 0.0379 - val_precision_9: 0.9957 - val_recall_9: 0.9957
# Epoch 4/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9613 - loss: 0.0810 - precision_9: 0.9752 - recall_9: 0.9520 - val_accuracy: 0.9645 - val_loss: 0.1289 - val_precision_9: 0.9645 - val_recall_9: 0.9645
# Epoch 5/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9553 - loss: 0.0872 - precision_9: 0.9643 - recall_9: 0.9439 - val_accuracy: 0.9602 - val_loss: 0.1441 - val_precision_9: 0.9616 - val_recall_9: 0.9602
# Epoch 6/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 173s 4s/step - accuracy: 0.9652 - loss: 0.0601 - precision_9: 0.9712 - recall_9: 0.9535 - val_accuracy: 0.9801 - val_loss: 0.0699 - val_precision_9: 0.9801 - val_recall_9: 0.9801
# Epoch 7/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9552 - loss: 0.0716 - precision_9: 0.9741 - recall_9: 0.9453 - val_accuracy: 0.9957 - val_loss: 0.0298 - val_precision_9: 0.9957 - val_recall_9: 0.9957
# Epoch 8/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9623 - loss: 0.0626 - precision_9: 0.9709 - recall_9: 0.9539 - val_accuracy: 0.9972 - val_loss: 0.0314 - val_precision_9: 0.9972 - val_recall_9: 0.9972
# Epoch 9/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9420 - loss: 0.0810 - precision_9: 0.9526 - recall_9: 0.9300 - val_accuracy: 0.9929 - val_loss: 0.0389 - val_precision_9: 0.9929 - val_recall_9: 0.9929
# Epoch 10/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9503 - loss: 0.0666 - precision_9: 0.9647 - recall_9: 0.9433 - val_accuracy: 0.9972 - val_loss: 0.0299 - val_precision_9: 0.9972 - val_recall_9: 0.9972
# Epoch 11/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 173s 4s/step - accuracy: 0.9590 - loss: 0.0696 - precision_9: 0.9760 - recall_9: 0.9433 - val_accuracy: 0.9972 - val_loss: 0.0274 - val_precision_9: 0.9972 - val_recall_9: 0.9972
# Epoch 12/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 173s 4s/step - accuracy: 0.9541 - loss: 0.0638 - precision_9: 0.9690 - recall_9: 0.9464 - val_accuracy: 0.9972 - val_loss: 0.0246 - val_precision_9: 0.9972 - val_recall_9: 0.9972
# Epoch 13/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9609 - loss: 0.0668 - precision_9: 0.9722 - recall_9: 0.9519 - val_accuracy: 0.9972 - val_loss: 0.0237 - val_precision_9: 0.9972 - val_recall_9: 0.9972
# Epoch 14/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9592 - loss: 0.0698 - precision_9: 0.9725 - recall_9: 0.9424 - val_accuracy: 0.9972 - val_loss: 0.0256 - val_precision_9: 0.9972 - val_recall_9: 0.9972
# Epoch 15/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9515 - loss: 0.0718 - precision_9: 0.9665 - recall_9: 0.9406 - val_accuracy: 0.9972 - val_loss: 0.0283 - val_precision_9: 0.9972 - val_recall_9: 0.9972
# Epoch 16/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9471 - loss: 0.0846 - precision_9: 0.9593 - recall_9: 0.9333 - val_accuracy: 0.9957 - val_loss: 0.0343 - val_precision_9: 0.9957 - val_recall_9: 0.9957
# Epoch 17/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9646 - loss: 0.0603 - precision_9: 0.9734 - recall_9: 0.9519 - val_accuracy: 0.9957 - val_loss: 0.0389 - val_precision_9: 0.9957 - val_recall_9: 0.9957
# Epoch 18/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9536 - loss: 0.0687 - precision_9: 0.9706 - recall_9: 0.9429 - val_accuracy: 0.9972 - val_loss: 0.0228 - val_precision_9: 0.9972 - val_recall_9: 0.9972
# Epoch 19/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 167s 4s/step - accuracy: 0.9645 - loss: 0.0511 - precision_9: 0.9802 - recall_9: 0.9569 - val_accuracy: 0.9972 - val_loss: 0.0103 - val_precision_9: 0.9972 - val_recall_9: 0.9972
# Epoch 20/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 167s 4s/step - accuracy: 0.9601 - loss: 0.0616 - precision_9: 0.9784 - recall_9: 0.9461 - val_accuracy: 0.9986 - val_loss: 0.0037 - val_precision_9: 0.9986 - val_recall_9: 0.9986
# Epoch 21/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9636 - loss: 0.0583 - precision_9: 0.9823 - recall_9: 0.9487 - val_accuracy: 1.0000 - val_loss: 2.8236e-04 - val_precision_9: 1.0000 - val_recall_9: 1.0000
# Epoch 22/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 175s 4s/step - accuracy: 0.9701 - loss: 0.0433 - precision_9: 0.9843 - recall_9: 0.9622 - val_accuracy: 1.0000 - val_loss: 4.2207e-04 - val_precision_9: 1.0000 - val_recall_9: 1.0000
# Epoch 23/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 173s 4s/step - accuracy: 0.9593 - loss: 0.0624 - precision_9: 0.9797 - recall_9: 0.9448 - val_accuracy: 0.9986 - val_loss: 0.0043 - val_precision_9: 0.9986 - val_recall_9: 0.9986
# Epoch 24/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9613 - loss: 0.0559 - precision_9: 0.9817 - recall_9: 0.9493 - val_accuracy: 0.9986 - val_loss: 0.0034 - val_precision_9: 0.9986 - val_recall_9: 0.9986
# Epoch 25/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9665 - loss: 0.0516 - precision_9: 0.9841 - recall_9: 0.9567 - val_accuracy: 0.9986 - val_loss: 0.0022 - val_precision_9: 0.9986 - val_recall_9: 0.9986
# Epoch 26/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9610 - loss: 0.0624 - precision_9: 0.9781 - recall_9: 0.9453 - val_accuracy: 1.0000 - val_loss: 1.4983e-05 - val_precision_9: 1.0000 - val_recall_9: 1.0000
# Epoch 27/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9564 - loss: 0.0548 - precision_9: 0.9762 - recall_9: 0.9499 - val_accuracy: 1.0000 - val_loss: 1.0010e-04 - val_precision_9: 1.0000 - val_recall_9: 1.0000
# Epoch 28/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9599 - loss: 0.0520 - precision_9: 0.9764 - recall_9: 0.9538 - val_accuracy: 1.0000 - val_loss: 0.0010 - val_precision_9: 1.0000 - val_recall_9: 1.0000
# Epoch 29/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9702 - loss: 0.0613 - precision_9: 0.9891 - recall_9: 0.9457 - val_accuracy: 1.0000 - val_loss: 1.0901e-04 - val_precision_9: 1.0000 - val_recall_9: 1.0000
# Epoch 30/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9632 - loss: 0.0571 - precision_9: 0.9794 - recall_9: 0.9489 - val_accuracy: 0.9986 - val_loss: 0.0012 - val_precision_9: 0.9986 - val_recall_9: 0.9986
# Epoch 31/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9632 - loss: 0.0617 - precision_9: 0.9802 - recall_9: 0.9436 - val_accuracy: 1.0000 - val_loss: 3.8395e-04 - val_precision_9: 1.0000 - val_recall_9: 1.0000
# Epoch 32/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9407 - loss: 0.0713 - precision_9: 0.9657 - recall_9: 0.9320 - val_accuracy: 1.0000 - val_loss: 4.9870e-04 - val_precision_9: 1.0000 - val_recall_9: 1.0000
# Epoch 33/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9727 - loss: 0.0481 - precision_9: 0.9806 - recall_9: 0.9552 - val_accuracy: 1.0000 - val_loss: 4.2972e-04 - val_precision_9: 1.0000 - val_recall_9: 1.0000
# Epoch 34/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9615 - loss: 0.0618 - precision_9: 0.9809 - recall_9: 0.9438 - val_accuracy: 1.0000 - val_loss: 1.4668e-04 - val_precision_9: 1.0000 - val_recall_9: 1.0000
# Epoch 35/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9598 - loss: 0.0527 - precision_9: 0.9814 - recall_9: 0.9511 - val_accuracy: 1.0000 - val_loss: 1.4296e-06 - val_precision_9: 1.0000 - val_recall_9: 1.0000
# Epoch 36/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9613 - loss: 0.0544 - precision_9: 0.9766 - recall_9: 0.9490 - val_accuracy: 1.0000 - val_loss: 3.3886e-06 - val_precision_9: 1.0000 - val_recall_9: 1.0000
# Epoch 37/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9532 - loss: 0.0601 - precision_9: 0.9722 - recall_9: 0.9444 - val_accuracy: 1.0000 - val_loss: 2.2094e-06 - val_precision_9: 1.0000 - val_recall_9: 1.0000
# Epoch 38/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 173s 4s/step - accuracy: 0.9778 - loss: 0.0371 - precision_9: 0.9889 - recall_9: 0.9658 - val_accuracy: 1.0000 - val_loss: 9.0083e-08 - val_precision_9: 1.0000 - val_recall_9: 1.0000
# Epoch 39/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9646 - loss: 0.0449 - precision_9: 0.9768 - recall_9: 0.9576 - val_accuracy: 1.0000 - val_loss: 1.1514e-07 - val_precision_9: 1.0000 - val_recall_9: 1.0000
# Epoch 40/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9679 - loss: 0.0407 - precision_9: 0.9775 - recall_9: 0.9596 - val_accuracy: 1.0000 - val_loss: 1.9321e-06 - val_precision_9: 1.0000 - val_recall_9: 1.0000
# Epoch 41/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9761 - loss: 0.0520 - precision_9: 0.9844 - recall_9: 0.9554 - val_accuracy: 1.0000 - val_loss: 1.8626e-09 - val_precision_9: 1.0000 - val_recall_9: 1.0000
# Epoch 42/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9424 - loss: 0.0899 - precision_9: 0.9660 - recall_9: 0.9344 - val_accuracy: 0.9915 - val_loss: 0.0401 - val_precision_9: 0.9915 - val_recall_9: 0.9915
# Epoch 43/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9585 - loss: 0.1580 - precision_9: 0.9761 - recall_9: 0.9357 - val_accuracy: 1.0000 - val_loss: 1.0482e-07 - val_precision_9: 1.0000 - val_recall_9: 1.0000
# Epoch 44/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9598 - loss: 0.0637 - precision_9: 0.9764 - recall_9: 0.9454 - val_accuracy: 1.0000 - val_loss: 9.2285e-08 - val_precision_9: 1.0000 - val_recall_9: 1.0000
# Epoch 45/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9609 - loss: 0.0588 - precision_9: 0.9782 - recall_9: 0.9471 - val_accuracy: 1.0000 - val_loss: 1.1909e-06 - val_precision_9: 1.0000 - val_recall_9: 1.0000
# Epoch 46/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9519 - loss: 0.0857 - precision_9: 0.9718 - recall_9: 0.9419 - val_accuracy: 1.0000 - val_loss: 7.4505e-08 - val_precision_9: 1.0000 - val_recall_9: 1.0000
# Epoch 47/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9677 - loss: 0.0480 - precision_9: 0.9897 - recall_9: 0.9565 - val_accuracy: 1.0000 - val_loss: 1.0160e-09 - val_precision_9: 1.0000 - val_recall_9: 1.0000
# Epoch 48/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9616 - loss: 0.0521 - precision_9: 0.9751 - recall_9: 0.9520 - val_accuracy: 1.0000 - val_loss: 4.0196e-07 - val_precision_9: 1.0000 - val_recall_9: 1.0000
# Epoch 49/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9646 - loss: 0.0532 - precision_9: 0.9804 - recall_9: 0.9477 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_precision_9: 1.0000 - val_recall_9: 1.0000
# Epoch 50/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 173s 4s/step - accuracy: 0.9723 - loss: 0.0415 - precision_9: 0.9885 - recall_9: 0.9611 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_precision_9: 1.0000 - val_recall_9: 1.0000
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 16s 738ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - precision_9: 1.0000 - recall_9: 1.0000
# Fold 2 - Validation Accuracy: 1.0
# Fold 2 - Validation Loss: 0.0
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.9965 - loss: 0.0099 - precision_9: 0.9965 - recall_9: 0.9965
# Fold 2 - Test Accuracy: 0.9933333396911621
# Fold 2 - Test Loss: 0.0187575314193964
# Epoch 1/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 196s 4s/step - accuracy: 0.6527 - loss: 0.8506 - precision_10: 0.6804 - recall_10: 0.6090 - val_accuracy: 0.9393 - val_loss: 0.2229 - val_precision_10: 0.9428 - val_recall_10: 0.9292
# Epoch 2/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 173s 4s/step - accuracy: 0.9300 - loss: 0.1452 - precision_10: 0.9379 - recall_10: 0.9187 - val_accuracy: 0.9436 - val_loss: 0.2307 - val_precision_10: 0.9476 - val_recall_10: 0.9408
# Epoch 3/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 173s 4s/step - accuracy: 0.9436 - loss: 0.1084 - precision_10: 0.9523 - recall_10: 0.9347 - val_accuracy: 0.9711 - val_loss: 0.1423 - val_precision_10: 0.9710 - val_recall_10: 0.9682
# Epoch 4/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 173s 4s/step - accuracy: 0.9329 - loss: 0.1174 - precision_10: 0.9395 - recall_10: 0.9200 - val_accuracy: 0.9783 - val_loss: 0.0695 - val_precision_10: 0.9783 - val_recall_10: 0.9783
# Epoch 5/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 174s 4s/step - accuracy: 0.9289 - loss: 0.1117 - precision_10: 0.9349 - recall_10: 0.9165 - val_accuracy: 0.9725 - val_loss: 0.0685 - val_precision_10: 0.9725 - val_recall_10: 0.9725
# Epoch 6/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 173s 4s/step - accuracy: 0.9462 - loss: 0.0931 - precision_10: 0.9491 - recall_10: 0.9359 - val_accuracy: 0.9913 - val_loss: 0.0268 - val_precision_10: 0.9913 - val_recall_10: 0.9913
# Epoch 7/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 173s 4s/step - accuracy: 0.9532 - loss: 0.0922 - precision_10: 0.9576 - recall_10: 0.9426 - val_accuracy: 0.9942 - val_loss: 0.0211 - val_precision_10: 0.9942 - val_recall_10: 0.9942
# Epoch 8/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 173s 4s/step - accuracy: 0.9596 - loss: 0.0700 - precision_10: 0.9634 - recall_10: 0.9527 - val_accuracy: 0.9971 - val_loss: 0.0079 - val_precision_10: 0.9971 - val_recall_10: 0.9971
# Epoch 9/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 173s 4s/step - accuracy: 0.9659 - loss: 0.0642 - precision_10: 0.9708 - recall_10: 0.9566 - val_accuracy: 0.9812 - val_loss: 0.0830 - val_precision_10: 0.9812 - val_recall_10: 0.9812
# Epoch 10/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 174s 4s/step - accuracy: 0.9502 - loss: 0.0906 - precision_10: 0.9596 - recall_10: 0.9419 - val_accuracy: 0.9971 - val_loss: 0.0101 - val_precision_10: 0.9971 - val_recall_10: 0.9971
# Epoch 11/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 173s 4s/step - accuracy: 0.9684 - loss: 0.0725 - precision_10: 0.9743 - recall_10: 0.9542 - val_accuracy: 0.9986 - val_loss: 0.0112 - val_precision_10: 0.9986 - val_recall_10: 0.9986
# Epoch 12/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 175s 4s/step - accuracy: 0.9557 - loss: 0.0830 - precision_10: 0.9617 - recall_10: 0.9440 - val_accuracy: 1.0000 - val_loss: 0.0018 - val_precision_10: 1.0000 - val_recall_10: 1.0000
# Epoch 13/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 173s 4s/step - accuracy: 0.9652 - loss: 0.0698 - precision_10: 0.9680 - recall_10: 0.9517 - val_accuracy: 1.0000 - val_loss: 0.0023 - val_precision_10: 1.0000 - val_recall_10: 1.0000
# Epoch 14/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 173s 4s/step - accuracy: 0.9564 - loss: 0.0687 - precision_10: 0.9617 - recall_10: 0.9435 - val_accuracy: 0.9986 - val_loss: 0.0053 - val_precision_10: 0.9986 - val_recall_10: 0.9986
# Epoch 15/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 173s 4s/step - accuracy: 0.9705 - loss: 0.0464 - precision_10: 0.9755 - recall_10: 0.9667 - val_accuracy: 0.9986 - val_loss: 0.0140 - val_precision_10: 0.9986 - val_recall_10: 0.9986
# Epoch 16/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 173s 4s/step - accuracy: 0.9687 - loss: 0.0639 - precision_10: 0.9781 - recall_10: 0.9608 - val_accuracy: 0.9986 - val_loss: 0.0028 - val_precision_10: 0.9986 - val_recall_10: 0.9986
# Epoch 17/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 173s 4s/step - accuracy: 0.9740 - loss: 0.0543 - precision_10: 0.9775 - recall_10: 0.9587 - val_accuracy: 1.0000 - val_loss: 7.8056e-04 - val_precision_10: 1.0000 - val_recall_10: 1.0000
# Epoch 18/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 173s 4s/step - accuracy: 0.9560 - loss: 0.0638 - precision_10: 0.9671 - recall_10: 0.9447 - val_accuracy: 1.0000 - val_loss: 7.1754e-04 - val_precision_10: 1.0000 - val_recall_10: 1.0000
# Epoch 19/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9667 - loss: 0.0599 - precision_10: 0.9725 - recall_10: 0.9482 - val_accuracy: 1.0000 - val_loss: 2.5644e-04 - val_precision_10: 1.0000 - val_recall_10: 1.0000
# Epoch 20/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9638 - loss: 0.0674 - precision_10: 0.9659 - recall_10: 0.9481 - val_accuracy: 1.0000 - val_loss: 7.5151e-04 - val_precision_10: 1.0000 - val_recall_10: 1.0000
# Epoch 21/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 173s 4s/step - accuracy: 0.9655 - loss: 0.0569 - precision_10: 0.9771 - recall_10: 0.9543 - val_accuracy: 1.0000 - val_loss: 4.5870e-04 - val_precision_10: 1.0000 - val_recall_10: 1.0000
# Epoch 22/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9697 - loss: 0.0484 - precision_10: 0.9796 - recall_10: 0.9609 - val_accuracy: 1.0000 - val_loss: 9.8654e-05 - val_precision_10: 1.0000 - val_recall_10: 1.0000
# Epoch 23/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9643 - loss: 0.0468 - precision_10: 0.9714 - recall_10: 0.9600 - val_accuracy: 1.0000 - val_loss: 3.3339e-05 - val_precision_10: 1.0000 - val_recall_10: 1.0000
# Epoch 24/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 174s 4s/step - accuracy: 0.9695 - loss: 0.0469 - precision_10: 0.9768 - recall_10: 0.9577 - val_accuracy: 1.0000 - val_loss: 3.1756e-05 - val_precision_10: 1.0000 - val_recall_10: 1.0000
# Epoch 25/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9606 - loss: 0.0583 - precision_10: 0.9812 - recall_10: 0.9475 - val_accuracy: 1.0000 - val_loss: 8.8353e-06 - val_precision_10: 1.0000 - val_recall_10: 1.0000
# Epoch 26/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9557 - loss: 0.0692 - precision_10: 0.9665 - recall_10: 0.9365 - val_accuracy: 1.0000 - val_loss: 2.8178e-06 - val_precision_10: 1.0000 - val_recall_10: 1.0000
# Epoch 27/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9679 - loss: 0.0526 - precision_10: 0.9787 - recall_10: 0.9540 - val_accuracy: 1.0000 - val_loss: 2.0323e-06 - val_precision_10: 1.0000 - val_recall_10: 1.0000
# Epoch 28/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9666 - loss: 0.0466 - precision_10: 0.9744 - recall_10: 0.9574 - val_accuracy: 1.0000 - val_loss: 1.4424e-06 - val_precision_10: 1.0000 - val_recall_10: 1.0000
# Epoch 29/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9616 - loss: 0.0536 - precision_10: 0.9744 - recall_10: 0.9490 - val_accuracy: 1.0000 - val_loss: 1.2735e-06 - val_precision_10: 1.0000 - val_recall_10: 1.0000
# Epoch 30/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9650 - loss: 0.0536 - precision_10: 0.9801 - recall_10: 0.9542 - val_accuracy: 1.0000 - val_loss: 5.5393e-06 - val_precision_10: 1.0000 - val_recall_10: 1.0000
# Epoch 31/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9631 - loss: 0.0545 - precision_10: 0.9721 - recall_10: 0.9493 - val_accuracy: 1.0000 - val_loss: 1.4698e-05 - val_precision_10: 1.0000 - val_recall_10: 1.0000
# Epoch 32/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9649 - loss: 0.0494 - precision_10: 0.9725 - recall_10: 0.9555 - val_accuracy: 1.0000 - val_loss: 3.2454e-06 - val_precision_10: 1.0000 - val_recall_10: 1.0000
# Epoch 33/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 173s 4s/step - accuracy: 0.9541 - loss: 0.0614 - precision_10: 0.9623 - recall_10: 0.9417 - val_accuracy: 1.0000 - val_loss: 1.6070e-05 - val_precision_10: 1.0000 - val_recall_10: 1.0000
# Epoch 34/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9664 - loss: 0.0506 - precision_10: 0.9793 - recall_10: 0.9514 - val_accuracy: 1.0000 - val_loss: 2.9953e-06 - val_precision_10: 1.0000 - val_recall_10: 1.0000
# Epoch 35/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9667 - loss: 0.0474 - precision_10: 0.9701 - recall_10: 0.9525 - val_accuracy: 1.0000 - val_loss: 2.9050e-05 - val_precision_10: 1.0000 - val_recall_10: 1.0000
# Epoch 36/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9618 - loss: 0.0594 - precision_10: 0.9760 - recall_10: 0.9378 - val_accuracy: 1.0000 - val_loss: 8.7990e-04 - val_precision_10: 1.0000 - val_recall_10: 1.0000
# Epoch 37/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9602 - loss: 0.0525 - precision_10: 0.9734 - recall_10: 0.9508 - val_accuracy: 1.0000 - val_loss: 5.7718e-05 - val_precision_10: 1.0000 - val_recall_10: 1.0000
# Epoch 38/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9632 - loss: 0.0547 - precision_10: 0.9747 - recall_10: 0.9517 - val_accuracy: 1.0000 - val_loss: 1.8817e-05 - val_precision_10: 1.0000 - val_recall_10: 1.0000
# Epoch 39/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9719 - loss: 0.0463 - precision_10: 0.9755 - recall_10: 0.9543 - val_accuracy: 1.0000 - val_loss: 2.7244e-06 - val_precision_10: 1.0000 - val_recall_10: 1.0000
# Epoch 40/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9695 - loss: 0.0400 - precision_10: 0.9789 - recall_10: 0.9581 - val_accuracy: 1.0000 - val_loss: 1.1327e-06 - val_precision_10: 1.0000 - val_recall_10: 1.0000
# Epoch 41/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9678 - loss: 0.0388 - precision_10: 0.9779 - recall_10: 0.9623 - val_accuracy: 1.0000 - val_loss: 2.5099e-07 - val_precision_10: 1.0000 - val_recall_10: 1.0000
# Epoch 42/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9614 - loss: 0.0559 - precision_10: 0.9782 - recall_10: 0.9431 - val_accuracy: 1.0000 - val_loss: 2.5737e-07 - val_precision_10: 1.0000 - val_recall_10: 1.0000
# Epoch 43/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 173s 4s/step - accuracy: 0.9687 - loss: 0.0453 - precision_10: 0.9837 - recall_10: 0.9576 - val_accuracy: 1.0000 - val_loss: 1.8898e-07 - val_precision_10: 1.0000 - val_recall_10: 1.0000
# Epoch 44/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9692 - loss: 0.0475 - precision_10: 0.9806 - recall_10: 0.9525 - val_accuracy: 1.0000 - val_loss: 6.6668e-08 - val_precision_10: 1.0000 - val_recall_10: 1.0000
# Epoch 45/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9550 - loss: 0.0620 - precision_10: 0.9730 - recall_10: 0.9379 - val_accuracy: 1.0000 - val_loss: 3.1714e-07 - val_precision_10: 1.0000 - val_recall_10: 1.0000
# Epoch 46/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9640 - loss: 0.0492 - precision_10: 0.9718 - recall_10: 0.9496 - val_accuracy: 1.0000 - val_loss: 3.5401e-07 - val_precision_10: 1.0000 - val_recall_10: 1.0000
# Epoch 47/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9782 - loss: 0.0395 - precision_10: 0.9833 - recall_10: 0.9631 - val_accuracy: 0.9971 - val_loss: 0.0061 - val_precision_10: 0.9971 - val_recall_10: 0.9971
# Epoch 48/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9571 - loss: 0.1488 - precision_10: 0.9713 - recall_10: 0.9402 - val_accuracy: 1.0000 - val_loss: 1.2719e-05 - val_precision_10: 1.0000 - val_recall_10: 1.0000
# Epoch 49/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 172s 4s/step - accuracy: 0.9639 - loss: 0.0476 - precision_10: 0.9743 - recall_10: 0.9553 - val_accuracy: 1.0000 - val_loss: 2.9689e-04 - val_precision_10: 1.0000 - val_recall_10: 1.0000
# Epoch 50/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 171s 4s/step - accuracy: 0.9507 - loss: 0.0695 - precision_10: 0.9640 - recall_10: 0.9331 - val_accuracy: 1.0000 - val_loss: 7.6508e-04 - val_precision_10: 1.0000 - val_recall_10: 1.0000
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 16s 726ms/step - accuracy: 1.0000 - loss: 0.0027 - precision_10: 1.0000 - recall_10: 1.0000
# Fold 3 - Validation Accuracy: 1.0
# Fold 3 - Validation Loss: 0.0007650820189155638
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 1.0000 - loss: 7.1209e-05 - precision_10: 1.0000 - recall_10: 1.0000
# Fold 3 - Test Accuracy: 1.0
# Fold 3 - Test Loss: 0.00013033996219746768
#
# Average Validation Accuracy: 1.0
# Average Validation Loss: 0.00025502733963852126
#
# Average Test Accuracy: 0.995555559794108

# %%
# Additional code to evaluate and calculate TP, FN, TN, FP for each fold
fold_results = []

for fold in range(k):
    # Load the saved model for this fold
    model = load_model(f"D:/kuliah/Tugas Akhir/Code/Klasifikasi Jenis Buah Lokal/models/K-Fold Validation/MobileNetV2-HSV_fold_{fold+1}.h5")
    
    # Predict on the test data
    test_preds = model.predict(test_generator)
    test_preds_classes = np.argmax(test_preds, axis=1)
    test_labels = test_generator.classes
    
    # Calculate confusion matrix components
    TP = np.sum((test_preds_classes == 1) & (test_labels == 1))
    TN = np.sum((test_preds_classes == 0) & (test_labels == 0))
    FP = np.sum((test_preds_classes == 1) & (test_labels == 0))
    FN = np.sum((test_preds_classes == 0) & (test_labels == 1))
    
    # Calculate accuracy
    accuracy = (TP + TN) / (TP + TN + FP + FN)
    
    # Store results
    fold_results.append({
        "Fold": fold + 1,
        "TP": TP,
        "FN": FN,
        "TN": TN,
        "FP": FP,
        "Accuracy": accuracy * 100  # Convert to percentage
    })
    
    # Print results for this fold
    print(f"Fold {fold + 1} Results:")
    print(f"TP: {TP}")
    print(f"FN: {FN}")
    print(f"TN: {TN}")
    print(f"FP: {FP}")
    print(f"Accuracy: {accuracy}")
    print()

# Convert to DataFrame for easier handling
df = pd.DataFrame(fold_results)

# Calculate average accuracy
average_accuracy = df["Accuracy"].mean()

# Add the average row
df = df.append({
    "Fold": "Rata-rata (%)",
    "TP": "",
    "FN": "",
    "TN": "",
    "FP": "",
    "Accuracy": round(average_accuracy, 2)
}, ignore_index=True)

# Create the table
fig, ax = plt.subplots(figsize=(8, 4))  # Set size frame
ax.axis('tight')
ax.axis('off')
table = ax.table(cellText=df.values, colLabels=df.columns, cellLoc='center', loc='center')

# Style the table
table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1.2, 1.2)

# Save as image
plt.savefig("performance_table.png", bbox_inches='tight', pad_inches=0.1)
plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step
# Fold 1 Results:
# TP: 100
# FN: 0
# TN: 100
# FP: 0
# Accuracy: 1.0
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step
# Fold 2 Results:
# TP: 100
# FN: 0
# TN: 100
# FP: 0
# Accuracy: 1.0
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001B8081E3B80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001B8081E3B80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/5 ━━━━━━━━━━━━━━━━━━━━ 1s 2s/stepWARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001B8081E3B80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001B8081E3B80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step
# Fold 3 Results:
# TP: 100
# FN: 0
# TN: 100
# FP: 0
# Accuracy: 1.0
