# %%
import numpy as np
import pandas as pd
import pathlib
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.metrics import confusion_matrix
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from sklearn.model_selection import KFold

# %%
# Parameter
train_dir = "D:/kuliah/Tugas Akhir/Code/Klasifikasi Jenis Buah Lokal/dataset/hsv_dataset/train"
validation_dir = "D:/kuliah/Tugas Akhir/Code/Klasifikasi Jenis Buah Lokal/dataset/hsv_dataset/val"
test_dir = "D:/kuliah/Tugas Akhir/Code/Klasifikasi Jenis Buah Lokal/dataset/test" 
k = 3  # Jumlah fold untuk K-FCV
epochs = 50  # Jumlah epoch untuk training model per fold
batch_size = 64  # Batch size

# Image size
IMG_SIZE = (300, 300)

# %%
# Import data
train_datagen = ImageDataGenerator(rescale=1.0 / 255)
test_datagen = ImageDataGenerator(rescale=1.0 / 255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=IMG_SIZE,
    batch_size=batch_size,
    class_mode="categorical",
    shuffle=True
)

validation_generator = test_datagen.flow_from_directory(
    validation_dir,
    target_size=IMG_SIZE,
    batch_size=batch_size,
    class_mode="categorical",
    shuffle=False
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=IMG_SIZE,
    batch_size=batch_size,
    class_mode="categorical",
    shuffle=False
)
# Out:
# Found 2100 images belonging to 3 classes.
# Found 600 images belonging to 3 classes.
# Found 300 images belonging to 3 classes.

# %%
def get_batch(generator, index):
    data = []
    labels = []
    for i in index:
        x, y = generator[i]
        data.extend(x)
        labels.extend(y)
    return np.array(data), np.array(labels)

# Membuat model CNN
def create_model():
    model = Sequential([
        tf.keras.layers.InputLayer(input_shape=(300, 300, 3)),
        tf.keras.layers.Conv2D(filters=32, kernel_size=(3, 3), activation="relu"),
        tf.keras.layers.MaxPooling2D(),
        tf.keras.layers.Conv2D(filters=64, kernel_size=(3, 3), activation="relu"),
        tf.keras.layers.MaxPooling2D(),
        tf.keras.layers.Conv2D(filters=64, kernel_size=(3, 3), activation="relu"),
        tf.keras.layers.MaxPooling2D(),
        tf.keras.layers.Conv2D(filters=128, kernel_size=(3, 3), activation="relu"),
        tf.keras.layers.MaxPooling2D(),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(16, activation="relu"),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(3, activation="softmax"),
    ])

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
        loss="categorical_crossentropy",
        metrics=["accuracy", tf.keras.metrics.Precision(), tf.keras.metrics.Recall()],
    )
    
    return model

# %%
def plot_history(history_list, k):
    fig, axs = plt.subplots(nrows=k, ncols=2, figsize=(12, k * 4))

    for i, history in enumerate(history_list):
        # Plot Accuracy
        axs[i, 0].plot(history['accuracy'], label=f'Train Fold {i+1}')
        axs[i, 0].plot(history['val_accuracy'], label=f'Validation Fold {i+1}')
        axs[i, 0].set_title(f'Fold {i+1} - Training and Validation Accuracy')
        axs[i, 0].set_xlabel('Epochs')
        axs[i, 0].set_ylabel('Accuracy')
        axs[i, 0].legend()

        # Plot Loss
        axs[i, 1].plot(history['loss'], label=f'Train Fold {i+1}')
        axs[i, 1].plot(history['val_loss'], label=f'Validation Fold {i+1}')
        axs[i, 1].set_title(f'Fold {i+1} - Training and Validation Loss')
        axs[i, 1].set_xlabel('Epochs')
        axs[i, 1].set_ylabel('Loss')
        axs[i, 1].legend()

    plt.tight_layout()
    plt.show()

# %%
# Evaluasi dengan K-FCV
history_list = []
average_acc = 0
average_loss = 0

kf = KFold(n_splits=k, shuffle=True, random_state=42)

# List to store accuracy and loss for each fold
fold_accuracy = []
fold_loss = []
test_accuracies = []

for fold, (train_index, val_index) in enumerate(kf.split(train_generator)):
    # Dapatkan batch data pelatihan dan validasi berdasarkan indeks fold
    train_data, train_labels = get_batch(train_generator, train_index)
    val_data, val_labels = get_batch(train_generator, val_index)

    # Buat model baru untuk setiap fold
    model = create_model()

    # Latih model menggunakan data pelatihan
    history = model.fit(
        train_data,
        train_labels,
        epochs=epochs,
        validation_data=(val_data, val_labels),
        verbose=1,  # Tampilkan informasi training per epoch
    )

    history_list.append(history.history)

    # Save the model for each fold
    model.save(f"D:/kuliah/Tugas Akhir/Code/Klasifikasi Jenis Buah Lokal/models/K-Fold Validation/CNN-HSV_fold_{fold+1}.h5")
    

    # Evaluate the model using the validation data
    val_loss, val_accuracy, val_precision, val_recall = model.evaluate(val_data, val_labels)
    fold_accuracy.append(val_accuracy)
    fold_loss.append(val_loss)

    print(f"Fold {fold+1} - Validation Accuracy: {val_accuracy}")
    print(f"Fold {fold+1} - Validation Loss: {val_loss}")

    # Evaluate the model using the test data
    test_loss, test_accuracy, test_precision, test_recall = model.evaluate(test_generator)
    test_accuracies.append(test_accuracy)
    print(f"Fold {fold+1} - Test Accuracy: {test_accuracy}")
    print(f"Fold {fold+1} - Test Loss: {test_loss}")

# Calculate average accuracy and loss across all folds
average_acc = np.mean(fold_accuracy)
average_loss = np.mean(fold_loss)
average_test_accuracy = np.mean(test_accuracies)

print(f"\nAverage Validation Accuracy: {average_acc}")
print(f"Average Validation Loss: {average_loss}")
print(f"\nAverage Test Accuracy: {average_test_accuracy}")

# Plotting hasil training dan validasi untuk setiap fold
plot_history(history_list, k)
# Out:
# c:\Users\CATUR WARGA COMPUTER\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\layers\core\input_layer.py:25: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Epoch 1/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━
# Epoch 1/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 34s 726ms/step - accuracy: 0.4262 - loss: 1.0129 - precision_1: 0.7256 - recall_1: 0.1228 - val_accuracy: 0.7173 - val_loss: 0.6306 - val_precision_1: 0.7702 - val_recall_1: 0.5952
# Epoch 2/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 713ms/step - accuracy: 0.6482 - loss: 0.7091 - precision_1: 0.7431 - recall_1: 0.5464 - val_accuracy: 0.7812 - val_loss: 0.5011 - val_precision_1: 0.7985 - val_recall_1: 0.7372
# Epoch 3/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 710ms/step - accuracy: 0.7291 - loss: 0.5825 - precision_1: 0.7789 - recall_1: 0.6695 - val_accuracy: 0.8182 - val_loss: 0.4120 - val_precision_1: 0.8287 - val_recall_1: 0.7969
# Epoch 4/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 711ms/step - accuracy: 0.7759 - loss: 0.4907 - precision_1: 0.8226 - recall_1: 0.7290 - val_accuracy: 0.8253 - val_loss: 0.3816 - val_precision_1: 0.8387 - val_recall_1: 0.8196
# Epoch 5/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 711ms/step - accuracy: 0.7825 - loss: 0.4783 - precision_1: 0.8088 - recall_1: 0.7453 - val_accuracy: 0.8651 - val_loss: 0.3335 - val_precision_1: 0.8741 - val_recall_1: 0.8580
# Epoch 6/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 711ms/step - accuracy: 0.8281 - loss: 0.4086 - precision_1: 0.8596 - recall_1: 0.7880 - val_accuracy: 0.8693 - val_loss: 0.3274 - val_precision_1: 0.8700 - val_recall_1: 0.8651
# Epoch 7/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 711ms/step - accuracy: 0.8309 - loss: 0.3732 - precision_1: 0.8765 - recall_1: 0.7961 - val_accuracy: 0.8778 - val_loss: 0.3138 - val_precision_1: 0.8784 - val_recall_1: 0.8722
# Epoch 8/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 710ms/step - accuracy: 0.8196 - loss: 0.3865 - precision_1: 0.8487 - recall_1: 0.7733 - val_accuracy: 0.8864 - val_loss: 0.2779 - val_precision_1: 0.8860 - val_recall_1: 0.8835
# Epoch 9/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 714ms/step - accuracy: 0.8202 - loss: 0.3769 - precision_1: 0.8508 - recall_1: 0.7829 - val_accuracy: 0.8949 - val_loss: 0.2951 - val_precision_1: 0.8944 - val_recall_1: 0.8906
# Epoch 10/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 32s 719ms/step - accuracy: 0.8365 - loss: 0.3761 - precision_1: 0.8655 - recall_1: 0.7967 - val_accuracy: 0.8920 - val_loss: 0.2630 - val_precision_1: 0.8919 - val_recall_1: 0.8906
# Epoch 11/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 709ms/step - accuracy: 0.8470 - loss: 0.3468 - precision_1: 0.8736 - recall_1: 0.8108 - val_accuracy: 0.9048 - val_loss: 0.2526 - val_precision_1: 0.9071 - val_recall_1: 0.9020
# Epoch 12/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 706ms/step - accuracy: 0.8519 - loss: 0.3250 - precision_1: 0.8787 - recall_1: 0.8171 - val_accuracy: 0.8991 - val_loss: 0.2567 - val_precision_1: 0.9004 - val_recall_1: 0.8991
# Epoch 13/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 709ms/step - accuracy: 0.8624 - loss: 0.3089 - precision_1: 0.8862 - recall_1: 0.8424 - val_accuracy: 0.8963 - val_loss: 0.2770 - val_precision_1: 0.8959 - val_recall_1: 0.8920
# Epoch 14/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 711ms/step - accuracy: 0.8800 - loss: 0.2901 - precision_1: 0.9065 - recall_1: 0.8575 - val_accuracy: 0.9162 - val_loss: 0.2298 - val_precision_1: 0.9175 - val_recall_1: 0.9162
# Epoch 15/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 711ms/step - accuracy: 0.8698 - loss: 0.3037 - precision_1: 0.9005 - recall_1: 0.8411 - val_accuracy: 0.9091 - val_loss: 0.2291 - val_precision_1: 0.9104 - val_recall_1: 0.9091
# Epoch 16/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 711ms/step - accuracy: 0.8713 - loss: 0.2763 - precision_1: 0.8967 - recall_1: 0.8526 - val_accuracy: 0.9148 - val_loss: 0.2228 - val_precision_1: 0.9148 - val_recall_1: 0.9148
# Epoch 17/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 708ms/step - accuracy: 0.8985 - loss: 0.2335 - precision_1: 0.9190 - recall_1: 0.8721 - val_accuracy: 0.9091 - val_loss: 0.2353 - val_precision_1: 0.9088 - val_recall_1: 0.9062
# Epoch 18/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 712ms/step - accuracy: 0.8884 - loss: 0.2538 - precision_1: 0.9225 - recall_1: 0.8692 - val_accuracy: 0.9261 - val_loss: 0.1936 - val_precision_1: 0.9288 - val_recall_1: 0.9261
# Epoch 19/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 712ms/step - accuracy: 0.8834 - loss: 0.2595 - precision_1: 0.9135 - recall_1: 0.8553 - val_accuracy: 0.9105 - val_loss: 0.2197 - val_precision_1: 0.9105 - val_recall_1: 0.9105
# Epoch 20/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 708ms/step - accuracy: 0.8794 - loss: 0.2448 - precision_1: 0.9075 - recall_1: 0.8617 - val_accuracy: 0.9247 - val_loss: 0.2125 - val_precision_1: 0.9260 - val_recall_1: 0.9247
# Epoch 21/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 32s 737ms/step - accuracy: 0.9067 - loss: 0.1974 - precision_1: 0.9316 - recall_1: 0.8891 - val_accuracy: 0.9290 - val_loss: 0.1980 - val_precision_1: 0.9290 - val_recall_1: 0.9290
# Epoch 22/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 712ms/step - accuracy: 0.9119 - loss: 0.2051 - precision_1: 0.9366 - recall_1: 0.8971 - val_accuracy: 0.9318 - val_loss: 0.1867 - val_precision_1: 0.9318 - val_recall_1: 0.9318
# Epoch 23/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 710ms/step - accuracy: 0.9172 - loss: 0.1938 - precision_1: 0.9314 - recall_1: 0.9000 - val_accuracy: 0.9176 - val_loss: 0.2177 - val_precision_1: 0.9175 - val_recall_1: 0.9162
# Epoch 24/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 711ms/step - accuracy: 0.8867 - loss: 0.2438 - precision_1: 0.9214 - recall_1: 0.8597 - val_accuracy: 0.9304 - val_loss: 0.1952 - val_precision_1: 0.9304 - val_recall_1: 0.9304
# Epoch 25/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 33s 746ms/step - accuracy: 0.9023 - loss: 0.1975 - precision_1: 0.9200 - recall_1: 0.8852 - val_accuracy: 0.9418 - val_loss: 0.1549 - val_precision_1: 0.9457 - val_recall_1: 0.9403
# Epoch 26/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 708ms/step - accuracy: 0.9184 - loss: 0.1859 - precision_1: 0.9468 - recall_1: 0.9037 - val_accuracy: 0.9474 - val_loss: 0.1622 - val_precision_1: 0.9474 - val_recall_1: 0.9474
# Epoch 27/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 710ms/step - accuracy: 0.9027 - loss: 0.2001 - precision_1: 0.9370 - recall_1: 0.8882 - val_accuracy: 0.9361 - val_loss: 0.1726 - val_precision_1: 0.9387 - val_recall_1: 0.9361
# Epoch 28/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 710ms/step - accuracy: 0.9271 - loss: 0.1585 - precision_1: 0.9516 - recall_1: 0.9170 - val_accuracy: 0.9403 - val_loss: 0.1804 - val_precision_1: 0.9403 - val_recall_1: 0.9403
# Epoch 29/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 708ms/step - accuracy: 0.9302 - loss: 0.1587 - precision_1: 0.9576 - recall_1: 0.9126 - val_accuracy: 0.9403 - val_loss: 0.1708 - val_precision_1: 0.9403 - val_recall_1: 0.9403
# Epoch 30/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 712ms/step - accuracy: 0.9061 - loss: 0.1755 - precision_1: 0.9408 - recall_1: 0.9004 - val_accuracy: 0.9361 - val_loss: 0.1857 - val_precision_1: 0.9360 - val_recall_1: 0.9347
# Epoch 31/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 713ms/step - accuracy: 0.9271 - loss: 0.1659 - precision_1: 0.9536 - recall_1: 0.9128 - val_accuracy: 0.9403 - val_loss: 0.1926 - val_precision_1: 0.9403 - val_recall_1: 0.9403
# Epoch 32/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 710ms/step - accuracy: 0.9164 - loss: 0.1780 - precision_1: 0.9472 - recall_1: 0.9001 - val_accuracy: 0.9503 - val_loss: 0.1574 - val_precision_1: 0.9503 - val_recall_1: 0.9503
# Epoch 33/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 710ms/step - accuracy: 0.9256 - loss: 0.1418 - precision_1: 0.9503 - recall_1: 0.9161 - val_accuracy: 0.8949 - val_loss: 0.3370 - val_precision_1: 0.8959 - val_recall_1: 0.8920
# Epoch 34/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 712ms/step - accuracy: 0.9147 - loss: 0.1883 - precision_1: 0.9390 - recall_1: 0.9034 - val_accuracy: 0.9332 - val_loss: 0.1956 - val_precision_1: 0.9359 - val_recall_1: 0.9332
# Epoch 35/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 711ms/step - accuracy: 0.9167 - loss: 0.1730 - precision_1: 0.9456 - recall_1: 0.9036 - val_accuracy: 0.9460 - val_loss: 0.1594 - val_precision_1: 0.9460 - val_recall_1: 0.9460
# Epoch 36/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 707ms/step - accuracy: 0.9327 - loss: 0.1535 - precision_1: 0.9512 - recall_1: 0.9107 - val_accuracy: 0.9361 - val_loss: 0.1836 - val_precision_1: 0.9360 - val_recall_1: 0.9347
# Epoch 37/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 32s 720ms/step - accuracy: 0.9239 - loss: 0.1524 - precision_1: 0.9571 - recall_1: 0.9179 - val_accuracy: 0.9389 - val_loss: 0.1779 - val_precision_1: 0.9416 - val_recall_1: 0.9389
# Epoch 38/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 712ms/step - accuracy: 0.9339 - loss: 0.1383 - precision_1: 0.9650 - recall_1: 0.9196 - val_accuracy: 0.9474 - val_loss: 0.1571 - val_precision_1: 0.9474 - val_recall_1: 0.9474
# Epoch 39/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 710ms/step - accuracy: 0.9399 - loss: 0.1258 - precision_1: 0.9624 - recall_1: 0.9289 - val_accuracy: 0.9361 - val_loss: 0.1658 - val_precision_1: 0.9361 - val_recall_1: 0.9361
# Epoch 40/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 708ms/step - accuracy: 0.9355 - loss: 0.1347 - precision_1: 0.9619 - recall_1: 0.9234 - val_accuracy: 0.9531 - val_loss: 0.1531 - val_precision_1: 0.9531 - val_recall_1: 0.9531
# Epoch 41/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 710ms/step - accuracy: 0.9102 - loss: 0.1590 - precision_1: 0.9451 - recall_1: 0.8972 - val_accuracy: 0.9489 - val_loss: 0.1567 - val_precision_1: 0.9487 - val_recall_1: 0.9460
# Epoch 42/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 712ms/step - accuracy: 0.9309 - loss: 0.1444 - precision_1: 0.9518 - recall_1: 0.9133 - val_accuracy: 0.9347 - val_loss: 0.2440 - val_precision_1: 0.9347 - val_recall_1: 0.9347
# Epoch 43/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 711ms/step - accuracy: 0.9284 - loss: 0.1359 - precision_1: 0.9483 - recall_1: 0.9111 - val_accuracy: 0.9531 - val_loss: 0.1506 - val_precision_1: 0.9531 - val_recall_1: 0.9531
# Epoch 44/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 711ms/step - accuracy: 0.9447 - loss: 0.1194 - precision_1: 0.9607 - recall_1: 0.9298 - val_accuracy: 0.9403 - val_loss: 0.2092 - val_precision_1: 0.9403 - val_recall_1: 0.9403
# Epoch 45/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 710ms/step - accuracy: 0.9295 - loss: 0.1360 - precision_1: 0.9583 - recall_1: 0.9156 - val_accuracy: 0.9361 - val_loss: 0.1889 - val_precision_1: 0.9387 - val_recall_1: 0.9361
# Epoch 46/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 711ms/step - accuracy: 0.9446 - loss: 0.1221 - precision_1: 0.9586 - recall_1: 0.9304 - val_accuracy: 0.9545 - val_loss: 0.1450 - val_precision_1: 0.9545 - val_recall_1: 0.9531
# Epoch 47/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 712ms/step - accuracy: 0.9440 - loss: 0.1116 - precision_1: 0.9744 - recall_1: 0.9310 - val_accuracy: 0.9460 - val_loss: 0.1950 - val_precision_1: 0.9460 - val_recall_1: 0.9460
# Epoch 48/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 709ms/step - accuracy: 0.9281 - loss: 0.1515 - precision_1: 0.9447 - recall_1: 0.9109 - val_accuracy: 0.9432 - val_loss: 0.1884 - val_precision_1: 0.9432 - val_recall_1: 0.9432
# Epoch 49/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 713ms/step - accuracy: 0.9396 - loss: 0.1149 - precision_1: 0.9654 - recall_1: 0.9265 - val_accuracy: 0.9531 - val_loss: 0.1467 - val_precision_1: 0.9531 - val_recall_1: 0.9531
# Epoch 50/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 32s 718ms/step - accuracy: 0.9509 - loss: 0.1120 - precision_1: 0.9735 - recall_1: 0.9368 - val_accuracy: 0.9560 - val_loss: 0.1339 - val_precision_1: 0.9571 - val_recall_1: 0.9517
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 178ms/step - accuracy: 0.9645 - loss: 0.1107 - precision_1: 0.9654 - recall_1: 0.9551
# Fold 2 - Validation Accuracy: 0.9559659361839294
# Fold 2 - Validation Loss: 0.13386498391628265
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 312ms/step - accuracy: 0.5599 - loss: 37.8294 - precision_1: 0.5599 - recall_1: 0.5599
# Fold 2 - Test Accuracy: 0.3333333432674408
# Fold 2 - Test Loss: 64.21341705322266
# Epoch 1/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 34s 734ms/step - accuracy: 0.3595 - loss: 1.0011 - precision_2: 0.7661 - recall_2: 0.1675 - val_accuracy: 0.6402 - val_loss: 0.7880 - val_precision_2: 0.8129 - val_recall_2: 0.3454
# Epoch 2/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 32s 720ms/step - accuracy: 0.6385 - loss: 0.7731 - precision_2: 0.8410 - recall_2: 0.4136 - val_accuracy: 0.7500 - val_loss: 0.6138 - val_precision_2: 0.9212 - val_recall_2: 0.5405
# Epoch 3/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 715ms/step - accuracy: 0.7335 - loss: 0.6358 - precision_2: 0.8511 - recall_2: 0.5796 - val_accuracy: 0.8092 - val_loss: 0.5358 - val_precision_2: 0.9043 - val_recall_2: 0.6416
# Epoch 4/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 715ms/step - accuracy: 0.7362 - loss: 0.6128 - precision_2: 0.8389 - recall_2: 0.6095 - val_accuracy: 0.8396 - val_loss: 0.5070 - val_precision_2: 0.9235 - val_recall_2: 0.6806
# Epoch 5/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 713ms/step - accuracy: 0.7821 - loss: 0.5511 - precision_2: 0.8834 - recall_2: 0.6484 - val_accuracy: 0.8396 - val_loss: 0.4815 - val_precision_2: 0.8950 - val_recall_2: 0.7269
# Epoch 6/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 715ms/step - accuracy: 0.7733 - loss: 0.5366 - precision_2: 0.8645 - recall_2: 0.6615 - val_accuracy: 0.8540 - val_loss: 0.4429 - val_precision_2: 0.9124 - val_recall_2: 0.7673
# Epoch 7/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 713ms/step - accuracy: 0.8038 - loss: 0.5216 - precision_2: 0.8666 - recall_2: 0.6903 - val_accuracy: 0.8512 - val_loss: 0.4298 - val_precision_2: 0.9157 - val_recall_2: 0.7688
# Epoch 8/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 32s 718ms/step - accuracy: 0.8177 - loss: 0.4730 - precision_2: 0.8788 - recall_2: 0.7160 - val_accuracy: 0.8671 - val_loss: 0.3984 - val_precision_2: 0.9094 - val_recall_2: 0.7977
# Epoch 9/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 711ms/step - accuracy: 0.8320 - loss: 0.4376 - precision_2: 0.8948 - recall_2: 0.7563 - val_accuracy: 0.8627 - val_loss: 0.3916 - val_precision_2: 0.9043 - val_recall_2: 0.7919
# Epoch 10/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 714ms/step - accuracy: 0.8026 - loss: 0.5035 - precision_2: 0.8662 - recall_2: 0.7062 - val_accuracy: 0.8743 - val_loss: 0.3604 - val_precision_2: 0.9318 - val_recall_2: 0.8295
# Epoch 11/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 715ms/step - accuracy: 0.8281 - loss: 0.4246 - precision_2: 0.8933 - recall_2: 0.7564 - val_accuracy: 0.8786 - val_loss: 0.3393 - val_precision_2: 0.9355 - val_recall_2: 0.8382
# Epoch 12/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 712ms/step - accuracy: 0.8629 - loss: 0.3960 - precision_2: 0.9068 - recall_2: 0.7891 - val_accuracy: 0.8931 - val_loss: 0.3205 - val_precision_2: 0.9329 - val_recall_2: 0.8439
# Epoch 13/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 713ms/step - accuracy: 0.8574 - loss: 0.3691 - precision_2: 0.9206 - recall_2: 0.7775 - val_accuracy: 0.8873 - val_loss: 0.3191 - val_precision_2: 0.9213 - val_recall_2: 0.8627
# Epoch 14/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 713ms/step - accuracy: 0.8608 - loss: 0.3564 - precision_2: 0.9174 - recall_2: 0.8110 - val_accuracy: 0.9032 - val_loss: 0.2924 - val_precision_2: 0.9280 - val_recall_2: 0.8757
# Epoch 15/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 715ms/step - accuracy: 0.8812 - loss: 0.3251 - precision_2: 0.9382 - recall_2: 0.8141 - val_accuracy: 0.9118 - val_loss: 0.2867 - val_precision_2: 0.9346 - val_recall_2: 0.8671
# Epoch 16/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 715ms/step - accuracy: 0.8946 - loss: 0.2879 - precision_2: 0.9359 - recall_2: 0.8519 - val_accuracy: 0.9162 - val_loss: 0.2394 - val_precision_2: 0.9452 - val_recall_2: 0.8974
# Epoch 17/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 716ms/step - accuracy: 0.8754 - loss: 0.2931 - precision_2: 0.9400 - recall_2: 0.8224 - val_accuracy: 0.9393 - val_loss: 0.2329 - val_precision_2: 0.9559 - val_recall_2: 0.9090
# Epoch 18/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 714ms/step - accuracy: 0.8860 - loss: 0.3030 - precision_2: 0.9431 - recall_2: 0.8273 - val_accuracy: 0.9335 - val_loss: 0.2246 - val_precision_2: 0.9529 - val_recall_2: 0.9061
# Epoch 19/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 714ms/step - accuracy: 0.9030 - loss: 0.2577 - precision_2: 0.9407 - recall_2: 0.8596 - val_accuracy: 0.9422 - val_loss: 0.2161 - val_precision_2: 0.9590 - val_recall_2: 0.9133
# Epoch 20/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 715ms/step - accuracy: 0.9009 - loss: 0.2577 - precision_2: 0.9470 - recall_2: 0.8550 - val_accuracy: 0.9249 - val_loss: 0.2103 - val_precision_2: 0.9544 - val_recall_2: 0.9075
# Epoch 21/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 32s 718ms/step - accuracy: 0.8912 - loss: 0.2703 - precision_2: 0.9368 - recall_2: 0.8437 - val_accuracy: 0.9465 - val_loss: 0.1779 - val_precision_2: 0.9620 - val_recall_2: 0.9147
# Epoch 22/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 715ms/step - accuracy: 0.9100 - loss: 0.2310 - precision_2: 0.9603 - recall_2: 0.8694 - val_accuracy: 0.9451 - val_loss: 0.1678 - val_precision_2: 0.9571 - val_recall_2: 0.9350
# Epoch 23/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 714ms/step - accuracy: 0.9254 - loss: 0.1988 - precision_2: 0.9686 - recall_2: 0.8884 - val_accuracy: 0.9436 - val_loss: 0.1849 - val_precision_2: 0.9582 - val_recall_2: 0.9277
# Epoch 24/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 715ms/step - accuracy: 0.9023 - loss: 0.2473 - precision_2: 0.9678 - recall_2: 0.8537 - val_accuracy: 0.9451 - val_loss: 0.1680 - val_precision_2: 0.9611 - val_recall_2: 0.9277
# Epoch 25/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 715ms/step - accuracy: 0.9237 - loss: 0.2131 - precision_2: 0.9593 - recall_2: 0.8846 - val_accuracy: 0.9393 - val_loss: 0.1701 - val_precision_2: 0.9596 - val_recall_2: 0.9277
# Epoch 26/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 715ms/step - accuracy: 0.9212 - loss: 0.2030 - precision_2: 0.9588 - recall_2: 0.8810 - val_accuracy: 0.9610 - val_loss: 0.1387 - val_precision_2: 0.9704 - val_recall_2: 0.9465
# Epoch 27/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 714ms/step - accuracy: 0.9217 - loss: 0.2004 - precision_2: 0.9701 - recall_2: 0.8827 - val_accuracy: 0.9610 - val_loss: 0.1246 - val_precision_2: 0.9748 - val_recall_2: 0.9494
# Epoch 28/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 713ms/step - accuracy: 0.9405 - loss: 0.1640 - precision_2: 0.9780 - recall_2: 0.8987 - val_accuracy: 0.9653 - val_loss: 0.1214 - val_precision_2: 0.9691 - val_recall_2: 0.9509
# Epoch 29/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 32s 733ms/step - accuracy: 0.9366 - loss: 0.1710 - precision_2: 0.9729 - recall_2: 0.9054 - val_accuracy: 0.9639 - val_loss: 0.1238 - val_precision_2: 0.9645 - val_recall_2: 0.9422
# Epoch 30/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 714ms/step - accuracy: 0.9295 - loss: 0.1971 - precision_2: 0.9700 - recall_2: 0.8871 - val_accuracy: 0.9668 - val_loss: 0.1239 - val_precision_2: 0.9734 - val_recall_2: 0.9523
# Epoch 31/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 716ms/step - accuracy: 0.9421 - loss: 0.1624 - precision_2: 0.9784 - recall_2: 0.9040 - val_accuracy: 0.9523 - val_loss: 0.1463 - val_precision_2: 0.9630 - val_recall_2: 0.9393
# Epoch 32/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 33s 749ms/step - accuracy: 0.9484 - loss: 0.1441 - precision_2: 0.9872 - recall_2: 0.9113 - val_accuracy: 0.9653 - val_loss: 0.1006 - val_precision_2: 0.9751 - val_recall_2: 0.9610
# Epoch 33/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 715ms/step - accuracy: 0.9218 - loss: 0.2035 - precision_2: 0.9631 - recall_2: 0.8776 - val_accuracy: 0.9624 - val_loss: 0.1240 - val_precision_2: 0.9747 - val_recall_2: 0.9480
# Epoch 34/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 716ms/step - accuracy: 0.9509 - loss: 0.1533 - precision_2: 0.9758 - recall_2: 0.9136 - val_accuracy: 0.9711 - val_loss: 0.1029 - val_precision_2: 0.9706 - val_recall_2: 0.9552
# Epoch 35/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 32s 719ms/step - accuracy: 0.9481 - loss: 0.1508 - precision_2: 0.9870 - recall_2: 0.8960 - val_accuracy: 0.9711 - val_loss: 0.1082 - val_precision_2: 0.9749 - val_recall_2: 0.9552
# Epoch 36/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 715ms/step - accuracy: 0.9462 - loss: 0.1377 - precision_2: 0.9840 - recall_2: 0.9104 - val_accuracy: 0.9754 - val_loss: 0.1015 - val_precision_2: 0.9779 - val_recall_2: 0.9610
# Epoch 37/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 714ms/step - accuracy: 0.9409 - loss: 0.1544 - precision_2: 0.9812 - recall_2: 0.9032 - val_accuracy: 0.9725 - val_loss: 0.1155 - val_precision_2: 0.9780 - val_recall_2: 0.9653
# Epoch 38/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 32s 717ms/step - accuracy: 0.9569 - loss: 0.1394 - precision_2: 0.9889 - recall_2: 0.9034 - val_accuracy: 0.9740 - val_loss: 0.0960 - val_precision_2: 0.9765 - val_recall_2: 0.9624
# Epoch 39/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 713ms/step - accuracy: 0.9284 - loss: 0.1814 - precision_2: 0.9676 - recall_2: 0.8946 - val_accuracy: 0.9624 - val_loss: 0.1113 - val_precision_2: 0.9748 - val_recall_2: 0.9509
# Epoch 40/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 714ms/step - accuracy: 0.9441 - loss: 0.1413 - precision_2: 0.9833 - recall_2: 0.9058 - val_accuracy: 0.9769 - val_loss: 0.0908 - val_precision_2: 0.9796 - val_recall_2: 0.9711
# Epoch 41/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 32s 718ms/step - accuracy: 0.9542 - loss: 0.1283 - precision_2: 0.9757 - recall_2: 0.9219 - val_accuracy: 0.9538 - val_loss: 0.1510 - val_precision_2: 0.9617 - val_recall_2: 0.9422
# Epoch 42/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 32s 719ms/step - accuracy: 0.9244 - loss: 0.1659 - precision_2: 0.9763 - recall_2: 0.8894 - val_accuracy: 0.9725 - val_loss: 0.0926 - val_precision_2: 0.9737 - val_recall_2: 0.9624
# Epoch 43/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 715ms/step - accuracy: 0.9568 - loss: 0.1205 - precision_2: 0.9748 - recall_2: 0.9189 - val_accuracy: 0.9769 - val_loss: 0.0853 - val_precision_2: 0.9781 - val_recall_2: 0.9682
# Epoch 44/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 715ms/step - accuracy: 0.9621 - loss: 0.1099 - precision_2: 0.9927 - recall_2: 0.9217 - val_accuracy: 0.9754 - val_loss: 0.0908 - val_precision_2: 0.9781 - val_recall_2: 0.9682
# Epoch 45/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 715ms/step - accuracy: 0.9561 - loss: 0.1258 - precision_2: 0.9915 - recall_2: 0.9089 - val_accuracy: 0.9769 - val_loss: 0.1061 - val_precision_2: 0.9768 - val_recall_2: 0.9754
# Epoch 46/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 714ms/step - accuracy: 0.9595 - loss: 0.1141 - precision_2: 0.9887 - recall_2: 0.9272 - val_accuracy: 0.9624 - val_loss: 0.1017 - val_precision_2: 0.9721 - val_recall_2: 0.9581
# Epoch 47/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 715ms/step - accuracy: 0.9610 - loss: 0.1259 - precision_2: 0.9818 - recall_2: 0.9250 - val_accuracy: 0.9653 - val_loss: 0.0997 - val_precision_2: 0.9765 - val_recall_2: 0.9595
# Epoch 48/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 715ms/step - accuracy: 0.9695 - loss: 0.0929 - precision_2: 0.9942 - recall_2: 0.9352 - val_accuracy: 0.9740 - val_loss: 0.0885 - val_precision_2: 0.9782 - val_recall_2: 0.9725
# Epoch 49/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 31s 715ms/step - accuracy: 0.9608 - loss: 0.1138 - precision_2: 0.9903 - recall_2: 0.9220 - val_accuracy: 0.9769 - val_loss: 0.0824 - val_precision_2: 0.9811 - val_recall_2: 0.9754
# Epoch 50/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 32s 718ms/step - accuracy: 0.9665 - loss: 0.0937 - precision_2: 0.9935 - recall_2: 0.9371 - val_accuracy: 0.9653 - val_loss: 0.1347 - val_precision_2: 0.9708 - val_recall_2: 0.9610
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.9635 - loss: 0.1477 - precision_2: 0.9678 - recall_2: 0.9594
# Fold 3 - Validation Accuracy: 0.9653179049491882
# Fold 3 - Validation Loss: 0.134724423289299
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 307ms/step - accuracy: 0.5599 - loss: 69.7677 - precision_2: 0.5599 - recall_2: 0.5599
# Fold 3 - Test Accuracy: 0.3333333432674408
# Fold 3 - Test Loss: 110.64633178710938
#
# Average Validation Accuracy: 0.961924155553182
# Average Validation Loss: 0.15019245445728302
#
# Average Test Accuracy: 0.3333333432674408

# %%
# Additional code to evaluate and calculate TP, FN, TN, FP for each fold
fold_results = []

for fold in range(k):
    # Load the saved model for this fold
    model = load_model(f"D:/kuliah/Tugas Akhir/Code/Klasifikasi Jenis Buah Lokal/models/K-Fold Validation/CNN-HSV_fold_{fold+1}.h5")
    
    # Predict on the test data
    test_preds = model.predict(test_generator)
    test_preds_classes = np.argmax(test_preds, axis=1)
    test_labels = test_generator.classes
    
    # Calculate confusion matrix components
    TP = np.sum((test_preds_classes == 1) & (test_labels == 1))
    TN = np.sum((test_preds_classes == 0) & (test_labels == 0))
    FP = np.sum((test_preds_classes == 1) & (test_labels == 0))
    FN = np.sum((test_preds_classes == 0) & (test_labels == 1))
    
    # Calculate accuracy
    accuracy = (TP + TN) / (TP + TN + FP + FN)
    
    # Store results
    fold_results.append({
        "Fold": fold + 1,
        "TP": TP,
        "FN": FN,
        "TN": TN,
        "FP": FP,
        "Accuracy": accuracy * 100  # Convert to percentage
    })
    
    # Print results for this fold
    print(f"Fold {fold + 1} Results:")
    print(f"TP: {TP}")
    print(f"FN: {FN}")
    print(f"TN: {TN}")
    print(f"FP: {FP}")
    print(f"Accuracy: {accuracy}")
    print()

# Convert to DataFrame for easier handling
df = pd.DataFrame(fold_results)

# Calculate average accuracy
average_accuracy = df["Accuracy"].mean()

# Add the average row
df = df.append({
    "Fold": "Rata-rata (%)",
    "TP": "",
    "FN": "",
    "TN": "",
    "FP": "",
    "Accuracy": round(average_accuracy, 2)
}, ignore_index=True)

# Create the table
fig, ax = plt.subplots(figsize=(8, 4))  # Set size frame
ax.axis('tight')
ax.axis('off')
table = ax.table(cellText=df.values, colLabels=df.columns, cellLoc='center', loc='center')

# Style the table
table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1.2, 1.2)

# Save as image
plt.savefig("performance_table.png", bbox_inches='tight', pad_inches=0.1)
plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 319ms/step
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Fold 1 Results:
# TP: 0
# FN: 100
# TN: 100
# FP: 0
# Accuracy: 0.5
#
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 322ms/step
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Fold 2 Results:
# TP: 0
# FN: 100
# TN: 100
# FP: 0
# Accuracy: 0.5
#
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000014C21310040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000014C21310040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/5 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/stepWARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000014C21310040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000014C21310040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 327ms/step
# Fold 3 Results:
# TP: 0
# FN: 100
# TN: 100
# FP: 0
# Accuracy: 0.5
