# %%
import numpy as np
import pandas as pd
import pathlib
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.metrics import confusion_matrix
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from sklearn.model_selection import KFold

# %%
# Parameter
train_dir = "D:/kuliah/Tugas Akhir/Code/Klasifikasi Jenis Buah Lokal/dataset/rgb_dataset/train"
validation_dir = "D:/kuliah/Tugas Akhir/Code/Klasifikasi Jenis Buah Lokal/dataset/rgb_dataset/val"
test_dir = "D:/kuliah/Tugas Akhir/Code/Klasifikasi Jenis Buah Lokal/dataset/test" 
k = 3  # Jumlah fold untuk K-FCV
epochs = 50  # Jumlah epoch untuk training model per fold
batch_size = 64  # Batch size

# Image size
IMG_SIZE = (300, 300)

# %%
# Import data
train_datagen = ImageDataGenerator(rescale=1.0 / 255)
test_datagen = ImageDataGenerator(rescale=1.0 / 255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=IMG_SIZE,
    batch_size=batch_size,
    class_mode="categorical",
    shuffle=True
)

validation_generator = test_datagen.flow_from_directory(
    validation_dir,
    target_size=IMG_SIZE,
    batch_size=batch_size,
    class_mode="categorical",
    shuffle=False
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=IMG_SIZE,
    batch_size=batch_size,
    class_mode="categorical",
    shuffle=False
)
# Out:
# Found 2403 images belonging to 3 classes.
# Found 600 images belonging to 3 classes.
# Found 300 images belonging to 3 classes.

# %%
def get_batch(generator, index):
    data = []
    labels = []
    for i in index:
        x, y = generator[i]
        data.extend(x)
        labels.extend(y)
    return np.array(data), np.array(labels)

# Membuat model CNN
def create_model():
    model = Sequential([
        tf.keras.layers.InputLayer(input_shape=(300, 300, 3)),
        tf.keras.layers.Conv2D(filters=32, kernel_size=(3, 3), activation="relu"),
        tf.keras.layers.MaxPooling2D(),
        tf.keras.layers.Conv2D(filters=64, kernel_size=(3, 3), activation="relu"),
        tf.keras.layers.MaxPooling2D(),
        tf.keras.layers.Conv2D(filters=64, kernel_size=(3, 3), activation="relu"),
        tf.keras.layers.MaxPooling2D(),
        tf.keras.layers.Conv2D(filters=128, kernel_size=(3, 3), activation="relu"),
        tf.keras.layers.MaxPooling2D(),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(16, activation="relu"),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(3, activation="softmax"),
    ])

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
        loss="categorical_crossentropy",
        metrics=["accuracy", tf.keras.metrics.Precision(), tf.keras.metrics.Recall()],
    )
    
    return model

# %%
def plot_history(history_list, k):
    fig, axs = plt.subplots(nrows=k, ncols=2, figsize=(12, k * 4))

    for i, history in enumerate(history_list):
        # Plot Accuracy
        axs[i, 0].plot(history['accuracy'], label=f'Train Fold {i+1}')
        axs[i, 0].plot(history['val_accuracy'], label=f'Validation Fold {i+1}')
        axs[i, 0].set_title(f'Fold {i+1} - Training and Validation Accuracy')
        axs[i, 0].set_xlabel('Epochs')
        axs[i, 0].set_ylabel('Accuracy')
        axs[i, 0].legend()

        # Plot Loss
        axs[i, 1].plot(history['loss'], label=f'Train Fold {i+1}')
        axs[i, 1].plot(history['val_loss'], label=f'Validation Fold {i+1}')
        axs[i, 1].set_title(f'Fold {i+1} - Training and Validation Loss')
        axs[i, 1].set_xlabel('Epochs')
        axs[i, 1].set_ylabel('Loss')
        axs[i, 1].legend()

    plt.tight_layout()
    plt.show()

# %%
# Evaluasi dengan K-FCV
history_list = []
average_acc = 0
average_loss = 0

kf = KFold(n_splits=k, shuffle=True, random_state=42)

# List to store accuracy and loss for each fold
fold_accuracy = []
fold_loss = []
test_accuracies = []

for fold, (train_index, val_index) in enumerate(kf.split(train_generator)):
    # Dapatkan batch data pelatihan dan validasi berdasarkan indeks fold
    train_data, train_labels = get_batch(train_generator, train_index)
    val_data, val_labels = get_batch(train_generator, val_index)

    # Buat model baru untuk setiap fold
    model = create_model()

    # Latih model menggunakan data pelatihan
    history = model.fit(
        train_data,
        train_labels,
        epochs=epochs,
        validation_data=(val_data, val_labels),
        verbose=1,  # Tampilkan informasi training per epoch
    )

    history_list.append(history.history)

    # Save the model for each fold
    model.save(f"D:/kuliah/Tugas Akhir/Code/Klasifikasi Jenis Buah Lokal/models/K-Fold Validation/CNN-RGB_fold_{fold+1}.h5")
    

    # Evaluate the model using the validation data
    val_loss, val_accuracy, val_precision, val_recall = model.evaluate(val_data, val_labels)
    fold_accuracy.append(val_accuracy)
    fold_loss.append(val_loss)

    print(f"Fold {fold+1} - Validation Accuracy: {val_accuracy}")
    print(f"Fold {fold+1} - Validation Loss: {val_loss}")

    # Evaluate the model using the test data
    test_loss, test_accuracy, test_precision, test_recall = model.evaluate(test_generator)
    test_accuracies.append(test_accuracy)
    print(f"Fold {fold+1} - Test Accuracy: {test_accuracy}")
    print(f"Fold {fold+1} - Test Loss: {test_loss}")

# Calculate average accuracy and loss across all folds
average_acc = np.mean(fold_accuracy)
average_loss = np.mean(fold_loss)
average_test_accuracy = np.mean(test_accuracies)

print(f"\nAverage Validation Accuracy: {average_acc}")
print(f"Average Validation Loss: {average_loss}")
print(f"\nAverage Test Accuracy: {average_test_accuracy}")

# Plotting hasil training dan validasi untuk setiap fold
plot_history(history_list, k)
# Out:
# c:\Users\CATUR WARGA COMPUTER\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\layers\core\input_layer.py:25: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Epoch 1/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 41s 783ms/step - accuracy: 0.4701 - loss: 1.0404 - precision: 0.5772 - recall: 0.0604 - val_accuracy: 0.7115 - val_loss: 0.6879 - val_precision: 0.7860 - val_recall: 0.5649
# Epoch 2/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 39s 743ms/step - accuracy: 0.6435 - loss: 0.7087 - precision: 0.7062 - recall: 0.5330 - val_accuracy: 0.7728 - val_loss: 0.5209 - val_precision: 0.8129 - val_recall: 0.7260
# Epoch 3/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 37s 731ms/step - accuracy: 0.6930 - loss: 0.6042 - precision: 0.7405 - recall: 0.6081 - val_accuracy: 0.8221 - val_loss: 0.4388 - val_precision: 0.8456 - val_recall: 0.7897
# Epoch 4/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 37s 732ms/step - accuracy: 0.7567 - loss: 0.5187 - precision: 0.7846 - recall: 0.6984 - val_accuracy: 0.8401 - val_loss: 0.3800 - val_precision: 0.8513 - val_recall: 0.8257
# Epoch 5/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 36s 723ms/step - accuracy: 0.7588 - loss: 0.5079 - precision: 0.7805 - recall: 0.6947 - val_accuracy: 0.8161 - val_loss: 0.3693 - val_precision: 0.8202 - val_recall: 0.8113
# Epoch 6/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 36s 723ms/step - accuracy: 0.8011 - loss: 0.4485 - precision: 0.8198 - recall: 0.7660 - val_accuracy: 0.8666 - val_loss: 0.3229 - val_precision: 0.8708 - val_recall: 0.8666
# Epoch 7/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 36s 724ms/step - accuracy: 0.8082 - loss: 0.4147 - precision: 0.8318 - recall: 0.7814 - val_accuracy: 0.8558 - val_loss: 0.3181 - val_precision: 0.8585 - val_recall: 0.8534
# Epoch 8/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 36s 725ms/step - accuracy: 0.7931 - loss: 0.4136 - precision: 0.8132 - recall: 0.7758 - val_accuracy: 0.8906 - val_loss: 0.2846 - val_precision: 0.8906 - val_recall: 0.8906
# Epoch 9/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 36s 722ms/step - accuracy: 0.8206 - loss: 0.3874 - precision: 0.8332 - recall: 0.7949 - val_accuracy: 0.8870 - val_loss: 0.2801 - val_precision: 0.8874 - val_recall: 0.8810
# Epoch 10/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 38s 752ms/step - accuracy: 0.8328 - loss: 0.3570 - precision: 0.8547 - recall: 0.8144 - val_accuracy: 0.9062 - val_loss: 0.2405 - val_precision: 0.9070 - val_recall: 0.9026
# Epoch 11/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 36s 717ms/step - accuracy: 0.8323 - loss: 0.3432 - precision: 0.8545 - recall: 0.8216 - val_accuracy: 0.9243 - val_loss: 0.2285 - val_precision: 0.9263 - val_recall: 0.9219
# Epoch 12/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 36s 713ms/step - accuracy: 0.8519 - loss: 0.3201 - precision: 0.8723 - recall: 0.8365 - val_accuracy: 0.9363 - val_loss: 0.2200 - val_precision: 0.9362 - val_recall: 0.9351
# Epoch 13/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 36s 712ms/step - accuracy: 0.8508 - loss: 0.3188 - precision: 0.8799 - recall: 0.8346 - val_accuracy: 0.9339 - val_loss: 0.2038 - val_precision: 0.9358 - val_recall: 0.9279
# Epoch 14/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 35s 709ms/step - accuracy: 0
# Epoch 10/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 36s 712ms/step - accuracy: 0.8647 - loss: 0.2882 - precision_1: 0.8875 - recall_1: 0.8536 - val_accuracy: 0.9303 - val_loss: 0.1875 - val_precision_1: 0.9303 - val_recall_1: 0.9303
# Epoch 11/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 37s 746ms/step - accuracy: 0.8718 - loss: 0.2869 - precision_1: 0.8853 - recall_1: 0.8561 - val_accuracy: 0.9365 - val_loss: 0.1837 - val_precision_1: 0.9362 - val_recall_1: 0.9328
# Epoch 12/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 36s 713ms/step - accuracy: 0.8800 - loss: 0.2720 - precision_1: 0.9023 - recall_1: 0.8578 - val_accuracy: 0.9415 - val_loss: 0.1585 - val_precision_1: 0.9438 - val_recall_1: 0.9415
# Epoch 13/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 36s 712ms/step - accuracy: 0.8884 - loss: 0.2491 - precision_1: 0.9092 - recall_1: 0.8787 - val_accuracy: 0.9377 - val_loss: 0.1631 - val_precision_1: 0.9377 - val_recall_1: 0.9365
# Epoch 14/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 36s 712ms/step - accuracy: 0.8949 - loss: 0.2391 - precision_1: 0.9063 - recall_1: 0.8843 - val_accuracy: 0.9440 - val_loss: 0.1615 - val_precision_1: 0.9462 - val_recall_1: 0.9415
# Epoch 15/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 35s 710ms/step - accuracy: 0.9025 - loss: 0.2364 - precision_1: 0.9185 - recall_1: 0.8859 - val_accuracy: 0.9502 - val_loss: 0.1330 - val_precision_1: 0.9502 - val_recall_1: 0.9502
# Epoch 16/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 36s 712ms/step - accuracy: 0.9010 - loss: 0.2142 - precision_1: 0.9156 - recall_1: 0.8832 - val_accuracy: 0.9552 - val_loss: 0.1239 - val_precision_1: 0.9564 - val_recall_1: 0.9552
# Epoch 17/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 36s 713ms/step - accuracy: 0.9066 - loss: 0.2140 - precision_1: 0.9192 - recall_1: 0.8927 - val_accuracy: 0.9651 - val_loss: 0.1111 - val_precision_1: 0.9651 - val_recall_1: 0.9651
# Epoch 18/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 36s 711ms/step - accuracy: 0.9150 - loss: 0.1914 - precision_1: 0.9337 - recall_1: 0.9000 - val_accuracy: 0.9676 - val_loss: 0.1102 - val_precision_1: 0.9688 - val_recall_1: 0.9676
# Epoch 19/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 36s 712ms/step - accuracy: 0.9159 - loss: 0.1763 - precision_1: 0.9298 - recall_1: 0.9070 - val_accuracy: 0.9626 - val_loss: 0.1116 - val_precision_1: 0.9626 - val_recall_1: 0.9626
# Epoch 20/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 36s 718ms/step - accuracy: 0.9212 - loss: 0.1714 - precision_1: 0.9343 - recall_1: 0.9113 - val_accuracy: 0.9676 - val_loss: 0.0960 - val_precision_1: 0.9676 - val_recall_1: 0.9676
# Epoch 21/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 36s 713ms/step - accuracy: 0.9043 - loss: 0.1854 - precision_1: 0.9174 - recall_1: 0.8935 - val_accuracy: 0.9714 - val_loss: 0.0915 - val_precision_1: 0.9714 - val_recall_1: 0.9714
# Epoch 22/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 36s 712ms/step - accuracy: 0.9177 - loss: 0.1671 - precision_1: 0.9349 - recall_1: 0.9114 - val_accuracy: 0.9614 - val_loss: 0.1108 - val_precision_1: 0.9614 - val_recall_1: 0.9614
# Epoch 23/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 36s 713ms/step - accuracy: 0.9263 - loss: 0.1606 - precision_1: 0.9383 - recall_1: 0.9176 - val_accuracy: 0.9714 - val_loss: 0.0939 - val_precision_1: 0.9714 - val_recall_1: 0.9714
# Epoch 24/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 36s 712ms/step - accuracy: 0.9274 - loss: 0.1639 - precision_1: 0.9445 - recall_1: 0.9128 - val_accuracy: 0.9776 - val_loss: 0.0800 - val_precision_1: 0.9776 - val_recall_1: 0.9776
# Epoch 25/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 36s 717ms/step - accuracy: 0.9136 - loss: 0.1628 - precision_1: 0.9336 - recall_1: 0.9061 - val_accuracy: 0.9763 - val_loss: 0.0858 - val_precision_1: 0.9763 - val_recall_1: 0.9763
# Epoch 26/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 36s 713ms/step - accuracy: 0.
# Epoch 41/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 36s 713ms/step - accuracy: 0.9610 - loss: 0.0876 - precision_1: 0.9707 - recall_1: 0.9580 - val_accuracy: 0.9826 - val_loss: 0.0764 - val_precision_1: 0.9826 - val_recall_1: 0.9826
# Epoch 42/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 36s 713ms/step - accuracy: 0.9575 - loss: 0.0876 - precision_1: 0.9687 - recall_1: 0.9465 - val_accuracy: 0.9763 - val_loss: 0.0833 - val_precision_1: 0.9763 - val_recall_1: 0.9763
# Epoch 43/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 36s 714ms/step - accuracy: 0.9420 - loss: 0.1101 - precision_1: 0.9504 - recall_1: 0.9321 - val_accuracy: 0.9838 - val_loss: 0.0778 - val_precision_1: 0.9850 - val_recall_1: 0.9838
# Epoch 44/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 36s 714ms/step - accuracy: 0.9525 - loss: 0.1026 - precision_1: 0.9640 - recall_1: 0.9400 - val_accuracy: 0.9738 - val_loss: 0.1051 - val_precision_1: 0.9751 - val_recall_1: 0.9738
# Epoch 45/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 36s 712ms/step - accuracy: 0.9532 - loss: 0.0919 - precision_1: 0.9663 - recall_1: 0.9447 - val_accuracy: 0.9813 - val_loss: 0.0817 - val_precision_1: 0.9813 - val_recall_1: 0.9813
# Epoch 46/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 35s 694ms/step - accuracy: 0.9568 - loss: 0.0888 - precision_1: 0.9662 - recall_1: 0.9468 - val_accuracy: 0.9776 - val_loss: 0.0783 - val_precision_1: 0.9776 - val_recall_1: 0.9776
# Epoch 47/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 36s 714ms/step - accuracy: 0.9538 - loss: 0.1002 - precision_1: 0.9646 - recall_1: 0.9422 - val_accuracy: 0.9838 - val_loss: 0.0698 - val_precision_1: 0.9838 - val_recall_1: 0.9838
# Epoch 48/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 36s 712ms/step - accuracy: 0.9508 - loss: 0.0925 - precision_1: 0.9597 - recall_1: 0.9407 - val_accuracy: 0.9826 - val_loss: 0.0691 - val_precision_1: 0.9826 - val_recall_1: 0.9826
# Epoch 49/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 36s 713ms/step - accuracy: 0.9526 - loss: 0.1040 - precision_1: 0.9673 - recall_1: 0.9449 - val_accuracy: 0.9838 - val_loss: 0.0658 - val_precision_1: 0.9838 - val_recall_1: 0.9838
# Epoch 50/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 36s 726ms/step - accuracy: 0.9522 - loss: 0.0936 - precision_1: 0.9653 - recall_1: 0.9416 - val_accuracy: 0.9838 - val_loss: 0.0757 - val_precision_1: 0.9838 - val_recall_1: 0.9838
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.9849 - loss: 0.0806 - precision_1: 0.9849 - recall_1: 0.9849
# Fold 2 - Validation Accuracy: 0.9838107228279114
# Fold 2 - Validation Loss: 0.07568476349115372
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 320ms/step - accuracy: 0.5599 - loss: 41.1153 - precision_1: 0.5599 - recall_1: 0.5599
# Fold 2 - Test Accuracy: 0.3333333432674408
# Fold 2 - Test Loss: 70.60617065429688
# Epoch 1/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 39s 720ms/step - accuracy: 0.4336 - loss: 1.0259 - precision_2: 0.6419 - recall_2: 0.0960 - val_accuracy: 0.6654 - val_loss: 0.7012 - val_precision_2: 0.7267 - val_recall_2: 0.5781
# Epoch 2/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 36s 698ms/step - accuracy: 0.6677 - loss: 0.7698 - precision_2: 0.7465 - recall_2: 0.5394 - val_accuracy: 0.7695 - val_loss: 0.5669 - val_precision_2: 0.8253 - val_recall_2: 0.6706
# Epoch 3/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 37s 703ms/step - accuracy: 0.7261 - loss: 0.6195 - precision_2: 0.7978 - recall_2: 0.6280 - val_accuracy: 0.8073 - val_loss: 0.4571 - val_precision_2: 0.8400 - val_recall_2: 0.7656
# Epoch 4/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 37s 704ms/step - accuracy: 0.7805 - loss: 0.5279 - precision_2: 0.8302 - recall_2: 0.7091 - val_accuracy: 0.8503 - val_loss: 0.3916 - val_precision_2: 0.8745 - val_recall_2: 0.8164
# Epoch 5/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 36s 693ms/step - accuracy: 0.7891 - loss: 0.4895 - precision_2: 0.8215 - recall_2: 0.7247 - val_accuracy: 0.8711 - val_loss: 0.3785 - val_precision_2: 0.9069 - val_recall_2: 0.8372
# Epoch 6/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 36s 693ms/step - accuracy: 0.7959 - loss: 0.4825 - precision_2: 0.8258 - recall_2: 0.7313 - val_accuracy: 0.8815 - val_loss: 0.3154 - val_precision_2: 0.9034 - val_recall_2: 0.8646
# Epoch 7/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 36s 695ms/step - accuracy: 0.8132 - loss: 0.4261 - precision_2: 0.8407 - recall_2: 0.7702 - val_accuracy: 0.8893 - val_loss: 0.3144 - val_precision_2: 0.9118 - val_recall_2: 0.8620
# Epoch 8/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 36s 693ms/step - accuracy: 0.8203 - loss: 0.4185 - precision_2: 0.8548 - recall_2: 0.7643 - val_accuracy: 0.9010 - val_loss: 0.2634 - val_precision_2: 0.9230 - val_recall_2: 0.8893
# Epoch 9/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 36s 693ms/step - accuracy: 0.8537 - loss: 0.3630 - precision_2: 0.8813 - recall_2: 0.8086 - val_accuracy: 0.9271 - val_loss: 0.2351 - val_precision_2: 0.9366 - val_recall_2: 0.9036
# Epoch 10/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 36s 692ms/step - accuracy: 0.8451 - loss: 0.3699 - precision_2: 0.8840 - recall_2: 0.7818 - val_accuracy: 0.9284 - val_loss: 0.2167 - val_precision_2: 0.9434 - val_recall_2: 0.9115
# Epoch 11/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 36s 695ms/step - accuracy: 0.8688 - loss: 0.3252 - precision_2: 0.8948 - recall_2: 0.8135 - val_accuracy: 0.9245 - val_loss: 0.1979 - val_precision_2: 0.9378 - val_recall_2: 0.9232
# Epoch 12/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 38s 722ms/step - accuracy: 0.8852 - loss: 0.2958 - precision_2: 0.9162 - recall_2: 0.8429 - val_accuracy: 0.9310 - val_loss: 0.1778 - val_precision_2: 0.9387 - val_recall_2: 0.9167
# Epoch 13/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 36s 693ms/step - accuracy: 0.8917 - loss: 0.2819 - precision_2: 0.9102 - recall_2: 0.8591 - val_accuracy: 0.9401 - val_loss: 0.1704 - val_precision_2: 0.9548 - val_recall_2: 0.9349
# Epoch 14/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 36s 693ms/step - accuracy: 0.8807 - loss: 0.2782 - precision_2: 0.9108 - recall_2: 0.8612 - val_accuracy: 0.9518 - val_loss: 0.1299 - val_precision_2: 0.9615 - val_recall_2: 0.9440
# Epoch 15/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 36s 694ms/step - accuracy: 0.8821 - loss: 0.2530 - precision_2: 0.9160 - recall_2: 0.8613 - val_accuracy: 0.9570 - val_loss: 0.1218 - val_precision_2: 0.9642 - val_recall_2: 0.9466
# Epoch 16/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 36s 694ms/step - accuracy: 0.9031 - loss: 0.2089 - precision_2: 0.9253 - recall_2: 0.8873 - val_accuracy: 0.9414 - val_loss: 0.1420 - val_precision_2: 0.9495 - val_recall_2: 0.9297
# Epoch 17/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 36s 695ms/step - accuracy: 0.9209 - loss: 0.2169 - precision_2: 0.9449 - recall_2: 0.8891 - val_accuracy: 0.9609 - val_loss: 0.1021 - val_precision_2: 0.9670 - val_recall_2: 0.9544
# Epoch 18/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 36s 694ms/step - accuracy: 0.9264 - loss: 0.2050 - precision_2: 0.9529 - recall_2: 0.8989 - val_accuracy: 0.9596 - val_loss: 0.1042 - val_precision_2: 0.9632 - val_recall_2: 0.9531
# Epoch 19/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 36s 691ms/step - accuracy: 0.9322 - loss: 0.1808 - precision_2: 0.9455 - recall_2: 0.9070 - val_accuracy: 0.9714 - val_loss: 0.0816 - val_precision_2: 0.9737 - val_recall_2: 0.9648
# Epoch 20/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 36s 694ms/step - accuracy: 0.9255 - loss: 0.1812 - precision_2: 0.9538 - recall_2: 0.8950 - val_accuracy: 0.9648 - val_loss: 0.0873 - val_precision_2: 0.9735 - val_recall_2: 0.9583
# Epoch 21/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 36s 690ms/step - accuracy: 0.9332 - loss: 0.1676 - precision_2: 0.9550 - recall_2: 0.9059 - val_accuracy: 0.9570 - val_loss: 0.1057 - val_precision_2: 0.9632 - val_recall_2: 0.9544
# Epoch 22/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 36s 697ms/step - accuracy: 0.9369 - loss: 0.1640 - precision_2: 0.9531 - recall_2: 0.9086 - val_accuracy: 0.9753 - val_loss: 0.0654 - val_precision_2: 0.9790 - val_recall_2: 0.9727
# Epoch 23/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 36s 694ms/step - accuracy: 0.9407 - loss: 0.1561 - precision_2: 0.9593 - recall_2: 0.9168 - val_accuracy: 0.9714 - val_loss: 0.0775 - val_precision_2: 0.9790 - val_recall_2: 0.9701
# Epoch 24/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 38s 725ms/step - accuracy: 0.9484 - loss: 0.1663 - precision_2: 0.9667 - recall_2: 0.9200 - val_accuracy: 0.9805 - val_loss: 0.0606 - val_precision_2: 0.9830 - val_recall_2: 0.9779
# Epoch 25/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 36s 694ms/step - accuracy: 0.9535 - loss: 0.1281 - precision_2: 0.9714 - recall_2: 0.9243 - val_accuracy: 0.9570 - val_loss: 0.0984 - val_precision_2: 0.9620 - val_recall_2: 0.9557
# Epoch 26/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 36s 693ms/step - accuracy: 0.9532 - loss: 0.1281 - precision_2: 0.9650 - recall_2: 0.9329 - val_accuracy: 0.9792 - val_loss: 0.0588 - val_precision_2: 0.9804 - val_recall_2: 0.9779
# Epoch 27/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 36s 696ms/step - accuracy: 0.9533 - loss: 0.1357 - precision_2: 0.9696 - recall_2: 0.9328 - val_accuracy: 0.9753 - val_loss: 0.0674 - val_precision_2: 0.9791 - val_recall_2: 0.9753
# Epoch 28/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 36s 698ms/step - accuracy: 0.9627 - loss: 0.1193 - precision_2: 0.9760 - recall_2: 0.9408 - val_accuracy: 0.9792 - val_loss: 0.0481 - val_precision_2: 0.9817 - val_recall_2: 0.9792
# Epoch 29/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 36s 693ms/step - accuracy: 0.9662 - loss: 0.1108 - precision_2: 0.9719 - recall_2: 0.9451 - val_accuracy: 0.9766 - val_loss: 0.0496 - val_precision_2: 0.9817 - val_recall_2: 0.9753
# Epoch 30/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 36s 693ms/step - accuracy: 0.9594 - loss: 0.1106 - precision_2: 0.9758 - recall_2: 0.9405 - val_accuracy: 0.9818 - val_loss: 0.0400 - val_precision_2: 0.9869 - val_recall_2: 0.9818
# Epoch 31/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 36s 693ms/step - accuracy: 0.9627 - loss: 0.1140 - precision_2: 0.9711 - recall_2: 0.9380 - val_accuracy: 0.9831 - val_loss: 0.0422 - val_precision_2: 0.9856 - val_recall_2: 0.9805
# Epoch 32/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 36s 694ms/step - accuracy: 0.9644 - loss: 0.1152 - precision_2: 0.9737 - recall_2: 0.9336 - val_accuracy: 0.9844 - val_loss: 0.0352 - val_precision_2: 0.9908 - val_recall_2: 0.9844
# Epoch 33/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 36s 692ms/step - accuracy: 0.9553 - loss: 0.1054 - precision_2: 0.9726 - recall_2: 0.9382 - val_accuracy: 0.9674 - val_loss: 0.0821 - val_precision_2: 0.9672 - val_recall_2: 0.9596
# Epoch 34/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 36s 693ms/step - accuracy: 0.9571 - loss: 0.1048 - precision_2: 0.9717 - recall_2: 0.9376 - val_accuracy: 0.9753 - val_loss: 0.0533 - val_precision_2: 0.9816 - val_recall_2: 0.9714
# Epoch 35/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 36s 694ms/step - accuracy: 0.9640 - loss: 0.1034 - precision_2: 0.9793 - recall_2: 0.9442 - val_accuracy: 0.9844 - val_loss: 0.0544 - val_precision_2: 0.9843 - val_recall_2: 0.9792
# Epoch 36/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 36s 693ms/step - accuracy: 0.9647 - loss: 0.1070 - precision_2: 0.9758 - recall_2: 0.9446 - val_accuracy: 0.9844 - val_loss: 0.0329 - val_precision_2: 0.9869 - val_recall_2: 0.9818
# Epoch 37/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 37s 703ms/step - accuracy: 0.9498 - loss: 0.1260 - precision_2: 0.9734 - recall_2: 0.9284 - val_accuracy: 0.9844 - val_loss: 0.0398 - val_precision_2: 0.9882 - val_recall_2: 0.9818
# Epoch 38/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 36s 693ms/step - accuracy: 0.9562 - loss: 0.1196 - precision_2: 0.9744 - recall_2: 0.9356 - val_accuracy: 0.9922 - val_loss: 0.0348 - val_precision_2: 0.9948 - val_recall_2: 0.9909
# Epoch 39/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 36s 695ms/step - accuracy: 0.9573 - loss: 0.1053 - precision_2: 0.9789 - recall_2: 0.9339 - val_accuracy: 0.9844 - val_loss: 0.0432 - val_precision_2: 0.9856 - val_recall_2: 0.9792
# Epoch 40/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 36s 693ms/step - accuracy: 0.9667 - loss: 0.0920 - precision_2: 0.9862 - recall_2: 0.9467 - val_accuracy: 0.9740 - val_loss: 0.0527 - val_precision_2: 0.9777 - val_recall_2: 0.9727
# Epoch 41/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 36s 694ms/step - accuracy: 0.9557 - loss: 0.1031 - precision_2: 0.9745 - recall_2: 0.9394 - val_accuracy: 0.9792 - val_loss: 0.0592 - val_precision_2: 0.9843 - val_recall_2: 0.9792
# Epoch 42/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 36s 695ms/step - accuracy: 0.9558 - loss: 0.1106 - precision_2: 0.9728 - recall_2: 0.9313 - val_accuracy: 0.9896 - val_loss: 0.0311 - val_precision_2: 0.9908 - val_recall_2: 0.9870
# Epoch 43/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 36s 694ms/step - accuracy: 0.9630 - loss: 0.0915 - precision_2: 0.9811 - recall_2: 0.9464 - val_accuracy: 0.9909 - val_loss: 0.0245 - val_precision_2: 0.9935 - val_recall_2: 0.9896
# Epoch 44/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 36s 692ms/step - accuracy: 0.9723 - loss: 0.0626 - precision_2: 0.9877 - recall_2: 0.9599 - val_accuracy: 0.9727 - val_loss: 0.0516 - val_precision_2: 0.9752 - val_recall_2: 0.9714
# Epoch 45/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 36s 695ms/step - accuracy: 0.9628 - loss: 0.0953 - precision_2: 0.9774 - recall_2: 0.9419 - val_accuracy: 0.9935 - val_loss: 0.0248 - val_precision_2: 0.9935 - val_recall_2: 0.9896
# Epoch 46/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 36s 693ms/step - accuracy: 0.9637 - loss: 0.0933 - precision_2: 0.9795 - recall_2: 0.9492 - val_accuracy: 0.9961 - val_loss: 0.0205 - val_precision_2: 0.9961 - val_recall_2: 0.9935
# Epoch 47/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 36s 693ms/step - accuracy: 0.9798 - loss: 0.0610 - precision_2: 0.9873 - recall_2: 0.9656 - val_accuracy: 0.9792 - val_loss: 0.0448 - val_precision_2: 0.9791 - val_recall_2: 0.9766
# Epoch 48/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 36s 698ms/step - accuracy: 0.9672 - loss: 0.0837 - precision_2: 0.9797 - recall_2: 0.9444 - val_accuracy: 0.9922 - val_loss: 0.0240 - val_precision_2: 0.9948 - val_recall_2: 0.9909
# Epoch 49/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 36s 699ms/step - accuracy: 0.9722 - loss: 0.0900 - precision_2: 0.9786 - recall_2: 0.9552 - val_accuracy: 0.9622 - val_loss: 0.0838 - val_precision_2: 0.9684 - val_recall_2: 0.9583
# Epoch 50/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 36s 698ms/step - accuracy: 0.9662 - loss: 0.0955 - precision_2: 0.9789 - recall_2: 0.9377 - val_accuracy: 0.9922 - val_loss: 0.0185 - val_precision_2: 0.9948 - val_recall_2: 0.9909
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.9946 - loss: 0.0158 - precision_2: 0.9951 - recall_2: 0.9929
# Fold 3 - Validation Accuracy: 0.9921875
# Fold 3 - Validation Loss: 0.018539903685450554
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 323ms/step - accuracy: 0.5599 - loss: 66.5728 - precision_2: 0.5599 - recall_2: 0.5599
# Fold 3 - Test Accuracy: 0.3333333432674408
# Fold 3 - Test Loss: 98.90828704833984
#
# Average Validation Accuracy: 0.9859897891680399
# Average Validation Loss: 0.05114540519813696
#
# Average Test Accuracy: 0.3333333432674408

# %%
# Additional code to evaluate and calculate TP, FN, TN, FP for each fold
fold_results = []

for fold in range(k):
    # Load the saved model for this fold
    model = load_model(f"D:/kuliah/Tugas Akhir/Code/Klasifikasi Jenis Buah Lokal/models/K-Fold Validation/CNN-RGB_fold_{fold+1}.h5")
    
    # Predict on the test data
    test_preds = model.predict(test_generator)
    test_preds_classes = np.argmax(test_preds, axis=1)
    test_labels = test_generator.classes
    
    # Calculate confusion matrix components
    TP = np.sum((test_preds_classes == 1) & (test_labels == 1))
    TN = np.sum((test_preds_classes == 0) & (test_labels == 0))
    FP = np.sum((test_preds_classes == 1) & (test_labels == 0))
    FN = np.sum((test_preds_classes == 0) & (test_labels == 1))
    
    # Calculate accuracy
    accuracy = (TP + TN) / (TP + TN + FP + FN)
    
    # Store results
    fold_results.append({
        "Fold": fold + 1,
        "TP": TP,
        "FN": FN,
        "TN": TN,
        "FP": FP,
        "Accuracy": accuracy * 100  # Convert to percentage
    })
    
    # Print results for this fold
    print(f"Fold {fold + 1} Results:")
    print(f"TP: {TP}")
    print(f"FN: {FN}")
    print(f"TN: {TN}")
    print(f"FP: {FP}")
    print(f"Accuracy: {accuracy}")
    print()

# Convert to DataFrame for easier handling
df = pd.DataFrame(fold_results)

# Calculate average accuracy
average_accuracy = df["Accuracy"].mean()

# Add the average row
df = df.append({
    "Fold": "Rata-rata (%)",
    "TP": "",
    "FN": "",
    "TN": "",
    "FP": "",
    "Accuracy": round(average_accuracy, 2)
}, ignore_index=True)

# Create the table
fig, ax = plt.subplots(figsize=(8, 4))  # Set size frame
ax.axis('tight')
ax.axis('off')
table = ax.table(cellText=df.values, colLabels=df.columns, cellLoc='center', loc='center')

# Style the table
table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1.2, 1.2)

# Save as image
plt.savefig("performance_table.png", bbox_inches='tight', pad_inches=0.1)
plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 352ms/step
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Fold 1 Results:
# TP: 0
# FN: 100
# TN: 100
# FP: 0
# Accuracy: 0.5
#
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 344ms/step
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Fold 2 Results:
# TP: 0
# FN: 100
# TN: 100
# FP: 0
# Accuracy: 0.5
#
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000197E768B3A0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000197E768B3A0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/5 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/stepWARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000197E768B3A0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000197E768B3A0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 348ms/step
# Fold 3 Results:
# TP: 0
# FN: 100
# TN: 100
# FP: 0
# Accuracy: 0.5
