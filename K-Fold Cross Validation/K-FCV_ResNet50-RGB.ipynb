# %%
import numpy as np
import pandas as pd
import pathlib
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from sklearn.metrics import confusion_matrix
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from sklearn.model_selection import KFold

# %%
# Parameter
train_dir = "D:/kuliah/Tugas Akhir/Code/Klasifikasi Jenis Buah Lokal/dataset/rgb_dataset/train"
validation_dir = "D:/kuliah/Tugas Akhir/Code/Klasifikasi Jenis Buah Lokal/dataset/rgb_dataset/val"
test_dir = "D:/kuliah/Tugas Akhir/Code/Klasifikasi Jenis Buah Lokal/dataset/test" 
k = 3  # Jumlah fold untuk K-FCV
epochs = 50  # Jumlah epoch untuk training model per fold
batch_size = 64  # Batch size

# Image size
IMG_SIZE = (300, 300)

# %%
# Import data
train_datagen = ImageDataGenerator(rescale=1.0 / 255)
test_datagen = ImageDataGenerator(rescale=1.0 / 255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=IMG_SIZE,
    batch_size=batch_size,
    class_mode="categorical",
    shuffle=True
)

validation_generator = test_datagen.flow_from_directory(
    validation_dir,
    target_size=IMG_SIZE,
    batch_size=batch_size,
    class_mode="categorical",
    shuffle=False
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=IMG_SIZE,
    batch_size=batch_size,
    class_mode="categorical",
    shuffle=False
)
# Out:
# Found 2403 images belonging to 3 classes.
# Found 600 images belonging to 3 classes.
# Found 300 images belonging to 3 classes.

# %%
def get_batch(generator, index):
    data = []
    labels = []
    for i in index:
        x, y = generator[i]
        data.extend(x)
        labels.extend(y)
    return np.array(data), np.array(labels)

# %%
def create_model():
    base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(300, 300, 3))
    model = Sequential([
        base_model,
        Flatten(),
        Dropout(0.5),
        Dense(16, activation="relu"),
        Dropout(0.5),
        Dense(3, activation="softmax"),
    ])

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
        loss="categorical_crossentropy",
        metrics=["accuracy", tf.keras.metrics.Precision(), tf.keras.metrics.Recall()],
    )
    
    return model

model = create_model()
print(model.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)           │ ?                      │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,587,712 (89.98 MB)
#  Trainable params: 23,534,592 (89.78 MB)
#  Non-trainable params: 53,120 (207.50 KB)
# None

# %%
def plot_history(history_list, k):
    fig, axs = plt.subplots(nrows=k, ncols=2, figsize=(12, k * 4))

    for i, history in enumerate(history_list):
        # Plot Accuracy
        axs[i, 0].plot(history['accuracy'], label=f'Train Fold {i+1}')
        axs[i, 0].plot(history['val_accuracy'], label=f'Validation Fold {i+1}')
        axs[i, 0].set_title(f'Fold {i+1} - Training and Validation Accuracy')
        axs[i, 0].set_xlabel('Epochs')
        axs[i, 0].set_ylabel('Accuracy')
        axs[i, 0].legend()

        # Plot Loss
        axs[i, 1].plot(history['loss'], label=f'Train Fold {i+1}')
        axs[i, 1].plot(history['val_loss'], label=f'Validation Fold {i+1}')
        axs[i, 1].set_title(f'Fold {i+1} - Training and Validation Loss')
        axs[i, 1].set_xlabel('Epochs')
        axs[i, 1].set_ylabel('Loss')
        axs[i, 1].legend()

    plt.tight_layout()
    plt.show()

# %%
# Evaluasi dengan K-FCV
history_list = []
average_acc = 0
average_loss = 0

kf = KFold(n_splits=k, shuffle=True, random_state=42)

# List to store accuracy and loss for each fold
fold_accuracy = []
fold_loss = []
test_accuracies = []

for fold, (train_index, val_index) in enumerate(kf.split(train_generator)):
    # Dapatkan batch data pelatihan dan validasi berdasarkan indeks fold
    train_data, train_labels = get_batch(train_generator, train_index)
    val_data, val_labels = get_batch(train_generator, val_index)

    # Buat model baru untuk setiap fold
    model = create_model()

    # Latih model menggunakan data pelatihan
    history = model.fit(
        train_data,
        train_labels,
        epochs=epochs,
        validation_data=(val_data, val_labels),
        verbose=1,  # Tampilkan informasi training per epoch
    )

    history_list.append(history.history)

    # Save the model for each fold
    model.save(f"D:/kuliah/Tugas Akhir/Code/Klasifikasi Jenis Buah Lokal/models/K-Fold Validation/ResNet50-RGB_fold_{fold+1}.h5")
    

    # Evaluate the model using the validation data
    val_loss, val_accuracy, val_precision, val_recall = model.evaluate(val_data, val_labels)
    fold_accuracy.append(val_accuracy)
    fold_loss.append(val_loss)

    print(f"Fold {fold+1} - Validation Accuracy: {val_accuracy}")
    print(f"Fold {fold+1} - Validation Loss: {val_loss}")

    # Evaluate the model using the test data
    test_loss, test_accuracy, test_precision, test_recall = model.evaluate(test_generator)
    test_accuracies.append(test_accuracy)
    print(f"Fold {fold+1} - Test Accuracy: {test_accuracy}")
    print(f"Fold {fold+1} - Test Loss: {test_loss}")

# Calculate average accuracy and loss across all folds
average_acc = np.mean(fold_accuracy)
average_loss = np.mean(fold_loss)
average_test_accuracy = np.mean(test_accuracies)

print(f"\nAverage Validation Accuracy: {average_acc}")
print(f"Average Validation Loss: {average_loss}")
print(f"\nAverage Test Accuracy: {average_test_accuracy}")

# Plotting hasil training dan validasi untuk setiap fold
plot_history(history_list, k)
# Out:
# Epoch 1/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 527s 10s/step - accuracy: 0.6866 - loss: 0.9642 - precision_1: 0.7234 - recall_1: 0.6445 - val_accuracy: 0.3221 - val_loss: 9.0701 - val_precision_1: 0.3221 - val_recall_1: 0.3221
# Epoch 2/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 497s 10s/step - accuracy: 0.9161 - loss: 0.1708 - precision_1: 0.9327 - recall_1: 0.8975 - val_accuracy: 0.3221 - val_loss: 4.9911 - val_precision_1: 0.3221 - val_recall_1: 0.3221
# Epoch 3/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 498s 10s/step - accuracy: 0.9445 - loss: 0.1100 - precision_1: 0.9582 - recall_1: 0.9303 - val_accuracy: 0.4603 - val_loss: 5.2385 - val_precision_1: 0.4603 - val_recall_1: 0.4603
# Epoch 4/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 491s 10s/step - accuracy: 0.9594 - loss: 0.0831 - precision_1: 0.9696 - recall_1: 0.9453 - val_accuracy: 0.3570 - val_loss: 6.2246 - val_precision_1: 0.3570 - val_recall_1: 0.3570
# Epoch 5/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 492s 10s/step - accuracy: 0.9473 - loss: 0.0848 - precision_1: 0.9676 - recall_1: 0.9316 - val_accuracy: 0.3221 - val_loss: 6.7556 - val_precision_1: 0.3221 - val_recall_1: 0.3221
# Epoch 6/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 493s 10s/step - accuracy: 0.9488 - loss: 0.0861 - precision_1: 0.9660 - recall_1: 0.9322 - val_accuracy: 0.3450 - val_loss: 3.7846 - val_precision_1: 0.3450 - val_recall_1: 0.3450
# Epoch 7/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 494s 10s/step - accuracy: 0.9646 - loss: 0.0803 - precision_1: 0.9767 - recall_1: 0.9468 - val_accuracy: 0.5457 - val_loss: 3.2741 - val_precision_1: 0.5457 - val_recall_1: 0.5457
# Epoch 8/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 497s 10s/step - accuracy: 0.9674 - loss: 0.0654 - precision_1: 0.9801 - recall_1: 0.9474 - val_accuracy: 0.3846 - val_loss: 2.9745 - val_precision_1: 0.3846 - val_recall_1: 0.3846
# Epoch 9/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 494s 10s/step - accuracy: 0.9672 - loss: 0.0610 - precision_1: 0.9811 - recall_1: 0.9486 - val_accuracy: 0.5721 - val_loss: 2.3369 - val_precision_1: 0.5716 - val_recall_1: 0.5709
# Epoch 10/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 493s 10s/step - accuracy: 0.9657 - loss: 0.0706 - precision_1: 0.9777 - recall_1: 0.9448 - val_accuracy: 0.4712 - val_loss: 3.5163 - val_precision_1: 0.4712 - val_recall_1: 0.4712
# Epoch 11/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 493s 10s/step - accuracy: 0.9793 - loss: 0.0594 - precision_1: 0.9876 - recall_1: 0.9520 - val_accuracy: 0.6587 - val_loss: 2.3157 - val_precision_1: 0.6587 - val_recall_1: 0.6587
# Epoch 12/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 495s 10s/step - accuracy: 0.9739 - loss: 0.0476 - precision_1: 0.9820 - recall_1: 0.9555 - val_accuracy: 0.6779 - val_loss: 1.2367 - val_precision_1: 0.6787 - val_recall_1: 0.6779
# Epoch 13/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 494s 10s/step - accuracy: 0.9692 - loss: 0.0523 - precision_1: 0.9797 - recall_1: 0.9488 - val_accuracy: 0.7248 - val_loss: 0.9527 - val_precision_1: 0.7248 - val_recall_1: 0.7248
# Epoch 14/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 494s 10s/step - accuracy: 0.9647 - loss: 0.0603 - precision_1: 0.9772 - recall_1: 0.9423 - val_accuracy: 0.8197 - val_loss: 0.5200 - val_precision_1: 0.8197 - val_recall_1: 0.8197
# Epoch 15/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 497s 10s/step - accuracy: 0.9763 - loss: 0.0601 - precision_1: 0.9888 - recall_1: 0.9471 - val_accuracy: 0.8618 - val_loss: 0.4119 - val_precision_1: 0.8618 - val_recall_1: 0.8618
# Epoch 16/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 488s 10s/step - accuracy: 0.9823 - loss: 0.0646 - precision_1: 0.9880 - recall_1: 0.9424 - val_accuracy: 0.9688 - val_loss: 0.0849 - val_precision_1: 0.9699 - val_recall_1: 0.9688
# Epoch 17/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 490s 10s/step - accuracy: 0.9647 - loss: 0.0621 - precision_1: 0.9805 - recall_1: 0.9412 - val_accuracy: 0.9832 - val_loss: 0.0456 - val_precision_1: 0.9832 - val_recall_1: 0.9832
# Epoch 18/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 489s 10s/step - accuracy: 0.9751 - loss: 0.0508 - precision_1: 0.9813 - recall_1: 0.9520 - val_accuracy: 0.9916 - val_loss: 0.0156 - val_precision_1: 0.9916 - val_recall_1: 0.9904
# Epoch 19/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 488s 10s/step - accuracy: 0.9677 - loss: 0.1374 - precision_1: 0.9765 - recall_1: 0.9314 - val_accuracy: 0.8077 - val_loss: 3.4259 - val_precision_1: 0.8077 - val_recall_1: 0.8077
# Epoch 20/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 492s 10s/step - accuracy: 0.9605 - loss: 0.1045 - precision_1: 0.9750 - recall_1: 0.9329 - val_accuracy: 0.9952 - val_loss: 0.0274 - val_precision_1: 0.9964 - val_recall_1: 0.9928
# Epoch 21/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 496s 10s/step - accuracy: 0.9712 - loss: 0.0586 - precision_1: 0.9793 - recall_1: 0.9516 - val_accuracy: 0.9868 - val_loss: 0.0481 - val_precision_1: 0.9915 - val_recall_1: 0.9856
# Epoch 22/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 496s 10s/step - accuracy: 0.9691 - loss: 0.0829 - precision_1: 0.9909 - recall_1: 0.9286 - val_accuracy: 0.9952 - val_loss: 0.0368 - val_precision_1: 0.9952 - val_recall_1: 0.9952
# Epoch 23/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 496s 10s/step - accuracy: 0.9793 - loss: 0.0619 - precision_1: 0.9884 - recall_1: 0.9420 - val_accuracy: 0.9892 - val_loss: 0.0711 - val_precision_1: 0.9892 - val_recall_1: 0.9892
# Epoch 24/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 495s 10s/step - accuracy: 0.9767 - loss: 0.0626 - precision_1: 0.9902 - recall_1: 0.9411 - val_accuracy: 0.9952 - val_loss: 0.0270 - val_precision_1: 0.9952 - val_recall_1: 0.9952
# Epoch 25/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 495s 10s/step - accuracy: 0.9681 - loss: 0.0705 - precision_1: 0.9732 - recall_1: 0.9330 - val_accuracy: 1.0000 - val_loss: 4.0644e-05 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 26/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 495s 10s/step - accuracy: 0.9776 - loss: 0.0652 - precision_1: 0.9880 - recall_1: 0.9386 - val_accuracy: 1.0000 - val_loss: 6.2643e-07 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 27/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 494s 10s/step - accuracy: 0.9741 - loss: 0.0617 - precision_1: 0.9854 - recall_1: 0.9382 - val_accuracy: 1.0000 - val_loss: 1.8511e-07 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 28/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 494s 10s/step - accuracy: 0.9804 - loss: 0.0590 - precision_1: 0.9931 - recall_1: 0.9428 - val_accuracy: 1.0000 - val_loss: 2.0000e-07 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 29/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 494s 10s/step - accuracy: 0.9860 - loss: 0.0425 - precision_1: 0.9961 - recall_1: 0.9579 - val_accuracy: 1.0000 - val_loss: 1.3182e-08 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 30/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 498s 10s/step - accuracy: 0.9786 - loss: 0.0539 - precision_1: 0.9899 - recall_1: 0.9501 - val_accuracy: 1.0000 - val_loss: 7.8100e-05 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 31/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 495s 10s/step - accuracy: 0.9658 - loss: 0.1625 - precision_1: 0.9756 - recall_1: 0.9088 - val_accuracy: 0.5950 - val_loss: 26.3621 - val_precision_1: 0.5950 - val_recall_1: 0.5950
# Epoch 32/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 495s 10s/step - accuracy: 0.9709 - loss: 0.0992 - precision_1: 0.9891 - recall_1: 0.9210 - val_accuracy: 0.9591 - val_loss: 2.3425 - val_precision_1: 0.9591 - val_recall_1: 0.9591
# Epoch 33/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 495s 10s/step - accuracy: 0.9784 - loss: 0.0739 - precision_1: 0.9918 - recall_1: 0.9389 - val_accuracy: 0.9952 - val_loss: 0.0892 - val_precision_1: 0.9952 - val_recall_1: 0.9952
# Epoch 34/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 495s 10s/step - accuracy: 0.9839 - loss: 0.0562 - precision_1: 0.9972 - recall_1: 0.9529 - val_accuracy: 0.9916 - val_loss: 0.0342 - val_precision_1: 0.9916 - val_recall_1: 0.9916
# Epoch 35/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 496s 10s/step - accuracy: 0.8423 - loss: 0.5114 - precision_1: 0.9195 - recall_1: 0.7276 - val_accuracy: 0.9279 - val_loss: 0.3023 - val_precision_1: 0.9289 - val_recall_1: 0.9267
# Epoch 36/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 495s 10s/step - accuracy: 0.9276 - loss: 0.1629 - precision_1: 0.9731 - recall_1: 0.8812 - val_accuracy: 0.9940 - val_loss: 0.0154 - val_precision_1: 0.9940 - val_recall_1: 0.9940
# Epoch 37/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 498s 10s/step - accuracy: 0.9575 - loss: 0.0994 - precision_1: 0.9950 - recall_1: 0.9154 - val_accuracy: 0.9988 - val_loss: 0.0041 - val_precision_1: 0.9988 - val_recall_1: 0.9976
# Epoch 38/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 495s 10s/step - accuracy: 0.9652 - loss: 0.0728 - precision_1: 0.9934 - recall_1: 0.9348 - val_accuracy: 0.9988 - val_loss: 0.0024 - val_precision_1: 0.9988 - val_recall_1: 0.9988
# Epoch 39/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 494s 10s/step - accuracy: 0.9672 - loss: 0.0781 - precision_1: 0.9905 - recall_1: 0.9303 - val_accuracy: 0.9964 - val_loss: 0.0097 - val_precision_1: 0.9964 - val_recall_1: 0.9964
# Epoch 40/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 495s 10s/step - accuracy: 0.9796 - loss: 0.0589 - precision_1: 0.9941 - recall_1: 0.9461 - val_accuracy: 0.9988 - val_loss: 0.0015 - val_precision_1: 0.9988 - val_recall_1: 0.9988
# Epoch 41/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 494s 10s/step - accuracy: 0.9624 - loss: 0.0820 - precision_1: 0.9914 - recall_1: 0.9235 - val_accuracy: 0.9988 - val_loss: 0.0026 - val_precision_1: 0.9988 - val_recall_1: 0.9988
# Epoch 42/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 494s 10s/step - accuracy: 0.9767 - loss: 0.0603 - precision_1: 0.9931 - recall_1: 0.9431 - val_accuracy: 1.0000 - val_loss: 1.0270e-04 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 43/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 493s 10s/step - accuracy: 0.9713 - loss: 0.2159 - precision_1: 0.9838 - recall_1: 0.9376 - val_accuracy: 0.9976 - val_loss: 0.1296 - val_precision_1: 0.9976 - val_recall_1: 0.9976
# Epoch 44/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 499s 10s/step - accuracy: 0.9701 - loss: 0.0973 - precision_1: 0.9886 - recall_1: 0.9245 - val_accuracy: 0.9904 - val_loss: 0.2288 - val_precision_1: 0.9904 - val_recall_1: 0.9904
# Epoch 45/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 495s 10s/step - accuracy: 0.9398 - loss: 0.2173 - precision_1: 0.9744 - recall_1: 0.8853 - val_accuracy: 0.9916 - val_loss: 0.1637 - val_precision_1: 0.9916 - val_recall_1: 0.9904
# Epoch 46/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 496s 10s/step - accuracy: 0.9594 - loss: 0.1367 - precision_1: 0.9913 - recall_1: 0.9101 - val_accuracy: 0.9868 - val_loss: 0.1017 - val_precision_1: 0.9880 - val_recall_1: 0.9868
# Epoch 47/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 495s 10s/step - accuracy: 0.9529 - loss: 0.1193 - precision_1: 0.9923 - recall_1: 0.9060 - val_accuracy: 0.9988 - val_loss: 0.0134 - val_precision_1: 0.9988 - val_recall_1: 0.9988
# Epoch 48/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 495s 10s/step - accuracy: 0.9859 - loss: 0.0660 - precision_1: 0.9993 - recall_1: 0.9447 - val_accuracy: 0.9988 - val_loss: 0.0255 - val_precision_1: 0.9988 - val_recall_1: 0.9988
# Epoch 49/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 497s 10s/step - accuracy: 0.9832 - loss: 0.0658 - precision_1: 0.9991 - recall_1: 0.9377 - val_accuracy: 0.9988 - val_loss: 0.0319 - val_precision_1: 0.9988 - val_recall_1: 0.9988
# Epoch 50/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 494s 10s/step - accuracy: 0.9754 - loss: 0.0715 - precision_1: 0.9984 - recall_1: 0.9338 - val_accuracy: 0.9988 - val_loss: 0.0018 - val_precision_1: 0.9988 - val_recall_1: 0.9988
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 45s 2s/step - accuracy: 0.9992 - loss: 0.0012 - precision_1: 0.9992 - recall_1: 0.9992
# Fold 1 - Validation Accuracy: 0.9987980723381042
# Fold 1 - Validation Loss: 0.0017870408482849598
# c:\Users\CATUR WARGA COMPUTER\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 18s 3s/step - accuracy: 0.5599 - loss: 144.9287 - precision_1: 0.5599 - recall_1: 0.5599
# Fold 1 - Test Accuracy: 0.3333333432674408
# Fold 1 - Test Loss: 214.49417114257812
# Epoch 1/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 536s 10s/step - accuracy: 0.7201 - loss: 1.0490 - precision_2: 0.7527 - recall_2: 0.5759 - val_accuracy: 0.3238 - val_loss: 3.2356 - val_precision_2: 0.3238 - val_recall_2: 0.3238
# Epoch 2/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 501s 10s/step - accuracy: 0.9475 - loss: 0.1903 - precision_2: 0.9686 - recall_2: 0.8750 - val_accuracy: 0.3337 - val_loss: 3.9895 - val_precision_2: 0.3337 - val_recall_2: 0.3337
# Epoch 3/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 500s 10s/step - accuracy: 0.9705 - loss: 0.1402 - precision_2: 0.9886 - recall_2: 0.8862 - val_accuracy: 0.3337 - val_loss: 4.9561 - val_precision_2: 0.3337 - val_recall_2: 0.3337
# Epoch 4/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 501s 10s/step - accuracy: 0.9733 - loss: 0.1084 - precision_2: 0.9828 - recall_2: 0.9057 - val_accuracy: 0.3337 - val_loss: 5.4380 - val_precision_2: 0.3337 - val_recall_2: 0.3337
# Epoch 5/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 501s 10s/step - accuracy: 0.9605 - loss: 0.1285 - precision_2: 0.9885 - recall_2: 0.8856 - val_accuracy: 0.3337 - val_loss: 7.2101 - val_precision_2: 0.3337 - val_recall_2: 0.3337
# Epoch 6/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 500s 10s/step - accuracy: 0.9727 - loss: 0.1202 - precision_2: 0.9892 - recall_2: 0.8921 - val_accuracy: 0.3337 - val_loss: 5.7852 - val_precision_2: 0.3337 - val_recall_2: 0.3337
# Epoch 7/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 501s 10s/step - accuracy: 0.9792 - loss: 0.1210 - precision_2: 0.9954 - recall_2: 0.8889 - val_accuracy: 0.3337 - val_loss: 5.5090 - val_precision_2: 0.3337 - val_recall_2: 0.3337
# Epoch 8/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 503s 10s/step - accuracy: 0.9709 - loss: 0.1172 - precision_2: 0.9874 - recall_2: 0.9025 - val_accuracy: 0.3337 - val_loss: 4.1023 - val_precision_2: 0.3337 - val_recall_2: 0.3337
# Epoch 9/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 499s 10s/step - accuracy: 0.9790 - loss: 0.1082 - precision_2: 0.9922 - recall_2: 0.8990 - val_accuracy: 0.3350 - val_loss: 3.9266 - val_precision_2: 0.3350 - val_recall_2: 0.3350
# Epoch 10/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 502s 10s/step - accuracy: 0.9737 - loss: 0.1573 - precision_2: 0.9817 - recall_2: 0.8870 - val_accuracy: 0.6376 - val_loss: 2.2480 - val_precision_2: 0.6384 - val_recall_2: 0.6376
# Epoch 11/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 500s 10s/step - accuracy: 0.9704 - loss: 0.1100 - precision_2: 0.9861 - recall_2: 0.8995 - val_accuracy: 0.6451 - val_loss: 1.1921 - val_precision_2: 0.6549 - val_recall_2: 0.6451
# Epoch 12/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 501s 10s/step - accuracy: 0.9686 - loss: 0.1039 - precision_2: 0.9877 - recall_2: 0.9045 - val_accuracy: 0.6538 - val_loss: 1.3202 - val_precision_2: 0.6662 - val_recall_2: 0.6538
# Epoch 13/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 501s 10s/step - accuracy: 0.9718 - loss: 0.1106 - precision_2: 0.9934 - recall_2: 0.9039 - val_accuracy: 0.6550 - val_loss: 2.7017 - val_precision_2: 0.6567 - val_recall_2: 0.6550
# Epoch 14/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 500s 10s/step - accuracy: 0.9786 - loss: 0.1323 - precision_2: 0.9980 - recall_2: 0.8796 - val_accuracy: 0.5853 - val_loss: 1.2432 - val_precision_2: 0.6065 - val_recall_2: 0.5778
# Epoch 15/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 500s 10s/step - accuracy: 0.9784 - loss: 0.1188 - precision_2: 0.9948 - recall_2: 0.8888 - val_accuracy: 0.9539 - val_loss: 0.1190 - val_precision_2: 0.9647 - val_recall_2: 0.9539
# Epoch 16/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 504s 10s/step - accuracy: 0.9712 - loss: 0.1291 - precision_2: 0.9852 - recall_2: 0.8818 - val_accuracy: 0.9527 - val_loss: 0.0854 - val_precision_2: 0.9683 - val_recall_2: 0.9514
# Epoch 17/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 499s 10s/step - accuracy: 0.9876 - loss: 0.0997 - precision_2: 0.9978 - recall_2: 0.9120 - val_accuracy: 0.9975 - val_loss: 0.0175 - val_precision_2: 0.9975 - val_recall_2: 0.9963
# Epoch 18/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 503s 10s/step - accuracy: 0.9731 - loss: 0.1367 - precision_2: 0.9910 - recall_2: 0.8786 - val_accuracy: 0.9875 - val_loss: 0.0440 - val_precision_2: 0.9899 - val_recall_2: 0.9801
# Epoch 19/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 501s 10s/step - accuracy: 0.9853 - loss: 0.0902 - precision_2: 0.9935 - recall_2: 0.9176 - val_accuracy: 1.0000 - val_loss: 0.0073 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 20/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 499s 10s/step - accuracy: 0.9804 - loss: 0.1116 - precision_2: 0.9951 - recall_2: 0.8964 - val_accuracy: 1.0000 - val_loss: 0.0059 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 21/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 501s 10s/step - accuracy: 0.9777 - loss: 0.1071 - precision_2: 0.9948 - recall_2: 0.9012 - val_accuracy: 1.0000 - val_loss: 0.0033 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 22/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 500s 10s/step - accuracy: 0.9755 - loss: 0.1170 - precision_2: 0.9991 - recall_2: 0.8884 - val_accuracy: 1.0000 - val_loss: 0.0013 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 23/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 504s 10s/step - accuracy: 0.9839 - loss: 0.0985 - precision_2: 0.9979 - recall_2: 0.9063 - val_accuracy: 1.0000 - val_loss: 4.5611e-04 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 24/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 501s 10s/step - accuracy: 0.9831 - loss: 0.1057 - precision_2: 0.9971 - recall_2: 0.8979 - val_accuracy: 1.0000 - val_loss: 1.7058e-04 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 25/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 500s 10s/step - accuracy: 0.9865 - loss: 0.0967 - precision_2: 0.9986 - recall_2: 0.9052 - val_accuracy: 1.0000 - val_loss: 8.2351e-05 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 26/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 500s 10s/step - accuracy: 0.9846 - loss: 0.1070 - precision_2: 0.9990 - recall_2: 0.8946 - val_accuracy: 1.0000 - val_loss: 4.6423e-05 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 27/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 501s 10s/step - accuracy: 0.9867 - loss: 0.0916 - precision_2: 1.0000 - recall_2: 0.9097 - val_accuracy: 1.0000 - val_loss: 3.1401e-05 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 28/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 500s 10s/step - accuracy: 0.9890 - loss: 0.0936 - precision_2: 1.0000 - recall_2: 0.9073 - val_accuracy: 1.0000 - val_loss: 2.5198e-05 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 29/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 499s 10s/step - accuracy: 0.9864 - loss: 0.1044 - precision_2: 0.9977 - recall_2: 0.8964 - val_accuracy: 1.0000 - val_loss: 2.7145e-05 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 30/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 504s 10s/step - accuracy: 0.9920 - loss: 0.0861 - precision_2: 0.9997 - recall_2: 0.9134 - val_accuracy: 1.0000 - val_loss: 1.3945e-05 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 31/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 500s 10s/step - accuracy: 0.9753 - loss: 0.1231 - precision_2: 0.9974 - recall_2: 0.8792 - val_accuracy: 1.0000 - val_loss: 5.2193e-04 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 32/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 502s 10s/step - accuracy: 0.9889 - loss: 0.0873 - precision_2: 1.0000 - recall_2: 0.9120 - val_accuracy: 1.0000 - val_loss: 1.8714e-04 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 33/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 500s 10s/step - accuracy: 0.9815 - loss: 0.1060 - precision_2: 1.0000 - recall_2: 0.8938 - val_accuracy: 1.0000 - val_loss: 7.1808e-05 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 34/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 500s 10s/step - accuracy: 0.9912 - loss: 0.0714 - precision_2: 1.0000 - recall_2: 0.9274 - val_accuracy: 1.0000 - val_loss: 3.0444e-05 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 35/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 512s 10s/step - accuracy: 0.9804 - loss: 0.1029 - precision_2: 0.9979 - recall_2: 0.8975 - val_accuracy: 0.9975 - val_loss: 0.0115 - val_precision_2: 0.9975 - val_recall_2: 0.9975
# Epoch 36/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 532s 11s/step - accuracy: 0.9630 - loss: 0.3780 - precision_2: 0.9847 - recall_2: 0.8729 - val_accuracy: 0.4570 - val_loss: 1230.4039 - val_precision_2: 0.4570 - val_recall_2: 0.4570
# Epoch 37/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 583s 12s/step - accuracy: 0.9392 - loss: 0.4637 - precision_2: 0.9677 - recall_2: 0.8500 - val_accuracy: 0.6862 - val_loss: 14.1243 - val_precision_2: 0.6862 - val_recall_2: 0.6862
# Epoch 38/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 525s 10s/step - accuracy: 0.9683 - loss: 0.1427 - precision_2: 0.9911 - recall_2: 0.8792 - val_accuracy: 0.9390 - val_loss: 1.8699 - val_precision_2: 0.9390 - val_recall_2: 0.9390
# Epoch 39/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 493s 10s/step - accuracy: 0.9611 - loss: 0.2512 - precision_2: 0.9863 - recall_2: 0.8825 - val_accuracy: 0.3562 - val_loss: 829.4830 - val_precision_2: 0.3562 - val_recall_2: 0.3562
# Epoch 40/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 490s 10s/step - accuracy: 0.9822 - loss: 0.1002 - precision_2: 0.9981 - recall_2: 0.9001 - val_accuracy: 0.7833 - val_loss: 42.4095 - val_precision_2: 0.7833 - val_recall_2: 0.7833
# Epoch 41/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 499s 10s/step - accuracy: 0.9806 - loss: 0.1177 - precision_2: 0.9964 - recall_2: 0.8881 - val_accuracy: 0.9689 - val_loss: 1.7014 - val_precision_2: 0.9689 - val_recall_2: 0.9689
# Epoch 42/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 499s 10s/step - accuracy: 0.9831 - loss: 0.0983 - precision_2: 0.9984 - recall_2: 0.9059 - val_accuracy: 0.9651 - val_loss: 1.9351 - val_precision_2: 0.9651 - val_recall_2: 0.9651
# Epoch 43/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 499s 10s/step - accuracy: 0.9759 - loss: 0.1305 - precision_2: 0.9947 - recall_2: 0.8854 - val_accuracy: 0.9614 - val_loss: 7.7879 - val_precision_2: 0.9613 - val_recall_2: 0.9601
# Epoch 44/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 506s 10s/step - accuracy: 0.9629 - loss: 0.3121 - precision_2: 0.9837 - recall_2: 0.8943 - val_accuracy: 0.9851 - val_loss: 0.4318 - val_precision_2: 0.9851 - val_recall_2: 0.9851
# Epoch 45/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 498s 10s/step - accuracy: 0.9826 - loss: 0.1071 - precision_2: 0.9982 - recall_2: 0.8999 - val_accuracy: 1.0000 - val_loss: 0.0023 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 46/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 501s 10s/step - accuracy: 0.9761 - loss: 0.1114 - precision_2: 0.9949 - recall_2: 0.8920 - val_accuracy: 1.0000 - val_loss: 0.0017 - val_precision_2: 1.0000 - val_recall_2: 0.9988
# Epoch 47/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 500s 10s/step - accuracy: 0.9777 - loss: 0.1064 - precision_2: 0.9971 - recall_2: 0.9019 - val_accuracy: 0.9826 - val_loss: 0.0635 - val_precision_2: 0.9937 - val_recall_2: 0.9763
# Epoch 48/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 499s 10s/step - accuracy: 0.9901 - loss: 0.0808 - precision_2: 0.9995 - recall_2: 0.9144 - val_accuracy: 0.9888 - val_loss: 0.0557 - val_precision_2: 0.9925 - val_recall_2: 0.9888
# Epoch 49/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 498s 10s/step - accuracy: 0.9851 - loss: 0.0919 - precision_2: 0.9988 - recall_2: 0.9037 - val_accuracy: 0.9838 - val_loss: 0.1035 - val_precision_2: 0.9875 - val_recall_2: 0.9826
# Epoch 50/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 500s 10s/step - accuracy: 0.9910 - loss: 0.0842 - precision_2: 0.9996 - recall_2: 0.9090 - val_accuracy: 0.9963 - val_loss: 0.0126 - val_precision_2: 0.9975 - val_recall_2: 0.9938
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.9971 - loss: 0.0153 - precision_2: 0.9973 - recall_2: 0.9933
# Fold 2 - Validation Accuracy: 0.9962639808654785
# Fold 2 - Validation Loss: 0.012594041414558887
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 17s 3s/step - accuracy: 0.5599 - loss: 316.5880 - precision_2: 0.5599 - recall_2: 0.5599
# Fold 2 - Test Accuracy: 0.3333333432674408
# Fold 2 - Test Loss: 442.8245849609375
# Epoch 1/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 550s 10s/step - accuracy: 0.7169 - loss: 0.8643 - precision_3: 0.7514 - recall_3: 0.6858 - val_accuracy: 0.3073 - val_loss: 8.1371 - val_precision_3: 0.3073 - val_recall_3: 0.3073
# Epoch 2/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 510s 10s/step - accuracy: 0.9606 - loss: 0.0745 - precision_3: 0.9806 - recall_3: 0.9550 - val_accuracy: 0.3555 - val_loss: 16.0253 - val_precision_3: 0.3555 - val_recall_3: 0.3555
# Epoch 3/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 509s 10s/step - accuracy: 0.9616 - loss: 0.0812 - precision_3: 0.9820 - recall_3: 0.9572 - val_accuracy: 0.3073 - val_loss: 32.5036 - val_precision_3: 0.3073 - val_recall_3: 0.3073
# Epoch 4/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 506s 10s/step - accuracy: 0.9688 - loss: 0.0562 - precision_3: 0.9908 - recall_3: 0.9635 - val_accuracy: 0.3073 - val_loss: 32.5142 - val_precision_3: 0.3073 - val_recall_3: 0.3073
# Epoch 5/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 510s 10s/step - accuracy: 0.9634 - loss: 0.0550 - precision_3: 0.9820 - recall_3: 0.9571 - val_accuracy: 0.3073 - val_loss: 29.6945 - val_precision_3: 0.3073 - val_recall_3: 0.3073
# Epoch 6/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 507s 10s/step - accuracy: 0.9585 - loss: 0.0597 - precision_3: 0.9892 - recall_3: 0.9530 - val_accuracy: 0.3073 - val_loss: 20.3324 - val_precision_3: 0.3073 - val_recall_3: 0.3073
# Epoch 7/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 507s 10s/step - accuracy: 0.9661 - loss: 0.0562 - precision_3: 0.9891 - recall_3: 0.9571 - val_accuracy: 0.3073 - val_loss: 14.7242 - val_precision_3: 0.3073 - val_recall_3: 0.3073
# Epoch 8/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 511s 10s/step - accuracy: 0.9630 - loss: 0.0652 - precision_3: 0.9842 - recall_3: 0.9549 - val_accuracy: 0.3151 - val_loss: 9.5790 - val_precision_3: 0.3151 - val_recall_3: 0.3151
# Epoch 9/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 508s 10s/step - accuracy: 0.9756 - loss: 0.0644 - precision_3: 0.9932 - recall_3: 0.9614 - val_accuracy: 0.3359 - val_loss: 9.0208 - val_precision_3: 0.3359 - val_recall_3: 0.3359
# Epoch 10/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 509s 10s/step - accuracy: 0.9625 - loss: 0.0484 - precision_3: 0.9928 - recall_3: 0.9579 - val_accuracy: 0.3451 - val_loss: 7.5866 - val_precision_3: 0.3451 - val_recall_3: 0.3451
# Epoch 11/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 508s 10s/step - accuracy: 0.9651 - loss: 0.0637 - precision_3: 0.9824 - recall_3: 0.9578 - val_accuracy: 0.4557 - val_loss: 4.4283 - val_precision_3: 0.4557 - val_recall_3: 0.4557
# Epoch 12/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 509s 10s/step - accuracy: 0.9749 - loss: 0.0419 - precision_3: 0.9907 - recall_3: 0.9671 - val_accuracy: 0.5065 - val_loss: 1.9369 - val_precision_3: 0.5125 - val_recall_3: 0.5065
# Epoch 13/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 509s 10s/step - accuracy: 0.9720 - loss: 0.0505 - precision_3: 0.9936 - recall_3: 0.9554 - val_accuracy: 0.7591 - val_loss: 0.7903 - val_precision_3: 0.7730 - val_recall_3: 0.7539
# Epoch 14/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 507s 10s/step - accuracy: 0.9750 - loss: 0.0440 - precision_3: 0.9967 - recall_3: 0.9598 - val_accuracy: 0.9049 - val_loss: 0.3788 - val_precision_3: 0.9061 - val_recall_3: 0.9049
# Epoch 15/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 509s 10s/step - accuracy: 0.9719 - loss: 0.0419 - precision_3: 0.9897 - recall_3: 0.9601 - val_accuracy: 0.9414 - val_loss: 0.1724 - val_precision_3: 0.9414 - val_recall_3: 0.9414
# Epoch 16/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 509s 10s/step - accuracy: 0.9645 - loss: 0.0488 - precision_3: 0.9914 - recall_3: 0.9559 - val_accuracy: 0.9896 - val_loss: 0.0337 - val_precision_3: 0.9896 - val_recall_3: 0.9896
# Epoch 17/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 508s 10s/step - accuracy: 0.9362 - loss: 0.2007 - precision_3: 0.9629 - recall_3: 0.9228 - val_accuracy: 0.6849 - val_loss: 8.1860 - val_precision_3: 0.6841 - val_recall_3: 0.6823
# Epoch 18/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 509s 10s/step - accuracy: 0.9403 - loss: 0.1251 - precision_3: 0.9802 - recall_3: 0.9280 - val_accuracy: 0.9609 - val_loss: 0.1709 - val_precision_3: 0.9609 - val_recall_3: 0.9609
# Epoch 19/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 507s 10s/step - accuracy: 0.9628 - loss: 0.1500 - precision_3: 0.9816 - recall_3: 0.9461 - val_accuracy: 0.9909 - val_loss: 0.0522 - val_precision_3: 0.9909 - val_recall_3: 0.9909
# Epoch 20/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 507s 10s/step - accuracy: 0.9677 - loss: 0.0560 - precision_3: 0.9841 - recall_3: 0.9569 - val_accuracy: 0.9935 - val_loss: 0.0267 - val_precision_3: 0.9935 - val_recall_3: 0.9935
# Epoch 21/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 508s 10s/step - accuracy: 0.9687 - loss: 0.0391 - precision_3: 0.9931 - recall_3: 0.9648 - val_accuracy: 0.9961 - val_loss: 0.0092 - val_precision_3: 0.9961 - val_recall_3: 0.9961
# Epoch 22/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 511s 10s/step - accuracy: 0.9634 - loss: 0.0431 - precision_3: 0.9924 - recall_3: 0.9603 - val_accuracy: 1.0000 - val_loss: 0.0014 - val_precision_3: 1.0000 - val_recall_3: 1.0000
# Epoch 23/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 507s 10s/step - accuracy: 0.9650 - loss: 0.0451 - precision_3: 0.9971 - recall_3: 0.9592 - val_accuracy: 1.0000 - val_loss: 7.8758e-05 - val_precision_3: 1.0000 - val_recall_3: 1.0000
# Epoch 24/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 508s 10s/step - accuracy: 0.9694 - loss: 0.0412 - precision_3: 0.9932 - recall_3: 0.9623 - val_accuracy: 1.0000 - val_loss: 4.0356e-05 - val_precision_3: 1.0000 - val_recall_3: 1.0000
# Epoch 25/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 508s 10s/step - accuracy: 0.9816 - loss: 0.0316 - precision_3: 0.9945 - recall_3: 0.9750 - val_accuracy: 1.0000 - val_loss: 2.6445e-04 - val_precision_3: 1.0000 - val_recall_3: 1.0000
# Epoch 26/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 506s 10s/step - accuracy: 0.9752 - loss: 0.0345 - precision_3: 0.9965 - recall_3: 0.9687 - val_accuracy: 1.0000 - val_loss: 3.1130e-04 - val_precision_3: 1.0000 - val_recall_3: 1.0000
# Epoch 27/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 507s 10s/step - accuracy: 0.9765 - loss: 0.0579 - precision_3: 0.9921 - recall_3: 0.9695 - val_accuracy: 0.9948 - val_loss: 0.0311 - val_precision_3: 0.9948 - val_recall_3: 0.9948
# Epoch 28/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 505s 10s/step - accuracy: 0.9045 - loss: 0.7708 - precision_3: 0.9519 - recall_3: 0.8713 - val_accuracy: 0.7982 - val_loss: 7.9283 - val_precision_3: 0.8008 - val_recall_3: 0.7904
# Epoch 29/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 509s 10s/step - accuracy: 0.9294 - loss: 0.1534 - precision_3: 0.9859 - recall_3: 0.8984 - val_accuracy: 0.9180 - val_loss: 1.4324 - val_precision_3: 0.9190 - val_recall_3: 0.9154
# Epoch 30/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 508s 10s/step - accuracy: 0.9441 - loss: 0.1141 - precision_3: 0.9942 - recall_3: 0.9220 - val_accuracy: 0.9948 - val_loss: 0.0302 - val_precision_3: 0.9948 - val_recall_3: 0.9883
# Epoch 31/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 505s 10s/step - accuracy: 0.9485 - loss: 0.0749 - precision_3: 0.9978 - recall_3: 0.9370 - val_accuracy: 0.9974 - val_loss: 0.0307 - val_precision_3: 0.9974 - val_recall_3: 0.9974
# Epoch 32/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 508s 10s/step - accuracy: 0.9670 - loss: 0.0489 - precision_3: 0.9979 - recall_3: 0.9588 - val_accuracy: 0.9883 - val_loss: 0.0745 - val_precision_3: 0.9883 - val_recall_3: 0.9883
# Epoch 33/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 504s 10s/step - accuracy: 0.9087 - loss: 0.2362 - precision_3: 0.9683 - recall_3: 0.8850 - val_accuracy: 0.8164 - val_loss: 33.8004 - val_precision_3: 0.8164 - val_recall_3: 0.8164
# Epoch 34/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 506s 10s/step - accuracy: 0.9303 - loss: 0.1340 - precision_3: 0.9800 - recall_3: 0.9115 - val_accuracy: 0.9635 - val_loss: 0.9009 - val_precision_3: 0.9635 - val_recall_3: 0.9635
# Epoch 35/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 506s 10s/step - accuracy: 0.9551 - loss: 0.0709 - precision_3: 0.9938 - recall_3: 0.9450 - val_accuracy: 0.9935 - val_loss: 0.1671 - val_precision_3: 0.9935 - val_recall_3: 0.9935
# Epoch 36/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 508s 10s/step - accuracy: 0.9536 - loss: 0.0563 - precision_3: 0.9949 - recall_3: 0.9521 - val_accuracy: 1.0000 - val_loss: 4.4383e-04 - val_precision_3: 1.0000 - val_recall_3: 1.0000
# Epoch 37/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 512s 10s/step - accuracy: 0.9602 - loss: 0.0562 - precision_3: 0.9983 - recall_3: 0.9520 - val_accuracy: 1.0000 - val_loss: 4.6518e-05 - val_precision_3: 1.0000 - val_recall_3: 1.0000
# Epoch 38/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 508s 10s/step - accuracy: 0.9715 - loss: 0.0416 - precision_3: 0.9989 - recall_3: 0.9628 - val_accuracy: 1.0000 - val_loss: 5.5090e-05 - val_precision_3: 1.0000 - val_recall_3: 1.0000
# Epoch 39/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 505s 10s/step - accuracy: 0.9680 - loss: 0.0482 - precision_3: 0.9930 - recall_3: 0.9632 - val_accuracy: 0.9935 - val_loss: 0.0783 - val_precision_3: 0.9935 - val_recall_3: 0.9935
# Epoch 40/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 507s 10s/step - accuracy: 0.9619 - loss: 0.0551 - precision_3: 0.9951 - recall_3: 0.9525 - val_accuracy: 0.9961 - val_loss: 0.0625 - val_precision_3: 0.9961 - val_recall_3: 0.9961
# Epoch 41/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 508s 10s/step - accuracy: 0.9635 - loss: 0.0620 - precision_3: 0.9933 - recall_3: 0.9529 - val_accuracy: 0.9948 - val_loss: 0.0682 - val_precision_3: 0.9948 - val_recall_3: 0.9948
# Epoch 42/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 505s 10s/step - accuracy: 0.9734 - loss: 0.0470 - precision_3: 0.9988 - recall_3: 0.9656 - val_accuracy: 0.9948 - val_loss: 0.1057 - val_precision_3: 0.9948 - val_recall_3: 0.9948
# Epoch 43/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 504s 10s/step - accuracy: 0.9758 - loss: 0.0379 - precision_3: 0.9996 - recall_3: 0.9658 - val_accuracy: 0.9948 - val_loss: 0.1095 - val_precision_3: 0.9948 - val_recall_3: 0.9948
# Epoch 44/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 510s 10s/step - accuracy: 0.9750 - loss: 0.0631 - precision_3: 0.9974 - recall_3: 0.9668 - val_accuracy: 0.9961 - val_loss: 0.0577 - val_precision_3: 0.9961 - val_recall_3: 0.9961
# Epoch 45/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 505s 10s/step - accuracy: 0.9763 - loss: 0.0452 - precision_3: 0.9983 - recall_3: 0.9699 - val_accuracy: 0.9961 - val_loss: 0.0070 - val_precision_3: 0.9961 - val_recall_3: 0.9961
# Epoch 46/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 506s 10s/step - accuracy: 0.9467 - loss: 0.1103 - precision_3: 0.9892 - recall_3: 0.9304 - val_accuracy: 0.9909 - val_loss: 0.1360 - val_precision_3: 0.9909 - val_recall_3: 0.9909
# Epoch 47/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 506s 10s/step - accuracy: 0.9677 - loss: 0.0548 - precision_3: 0.9998 - recall_3: 0.9560 - val_accuracy: 0.9935 - val_loss: 0.1621 - val_precision_3: 0.9935 - val_recall_3: 0.9935
# Epoch 48/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 506s 10s/step - accuracy: 0.9749 - loss: 0.0442 - precision_3: 0.9989 - recall_3: 0.9640 - val_accuracy: 1.0000 - val_loss: 2.6729e-04 - val_precision_3: 1.0000 - val_recall_3: 1.0000
# Epoch 49/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 505s 10s/step - accuracy: 0.9690 - loss: 0.0499 - precision_3: 0.9999 - recall_3: 0.9575 - val_accuracy: 1.0000 - val_loss: 1.7096e-04 - val_precision_3: 1.0000 - val_recall_3: 1.0000
# Epoch 50/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 507s 10s/step - accuracy: 0.9703 - loss: 0.0549 - precision_3: 0.9987 - recall_3: 0.9534 - val_accuracy: 1.0000 - val_loss: 1.6884e-04 - val_precision_3: 1.0000 - val_recall_3: 1.0000
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 1.0000 - loss: 1.1453e-04 - precision_3: 1.0000 - recall_3: 1.0000
# Fold 3 - Validation Accuracy: 1.0
# Fold 3 - Validation Loss: 0.00016884056094568223
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - accuracy: 0.5599 - loss: 74.2270 - precision_3: 0.5599 - recall_3: 0.5599
# Fold 3 - Test Accuracy: 0.3333333432674408
# Fold 3 - Test Loss: 126.01062774658203
#
# Average Validation Accuracy: 0.9983540177345276
# Average Validation Loss: 0.0048499742745965095
#
# Average Test Accuracy: 0.3333333432674408

# %%
# Additional code to evaluate and calculate TP, FN, TN, FP for each fold
fold_results = []       

for fold in range(k):
    # Load the saved model for this fold
    model = load_model(f"D:/kuliah/Tugas Akhir/Code/Klasifikasi Jenis Buah Lokal/models/K-Fold Validation/ResNet50-RGB_fold_{fold+1}.h5")
    
    # Predict on the test data
    test_preds = model.predict(test_generator)
    test_preds_classes = np.argmax(test_preds, axis=1)
    test_labels = test_generator.classes
    
    # Calculate confusion matrix components
    TP = np.sum((test_preds_classes == 1) & (test_labels == 1))
    TN = np.sum((test_preds_classes == 0) & (test_labels == 0))
    FP = np.sum((test_preds_classes == 1) & (test_labels == 0))
    FN = np.sum((test_preds_classes == 0) & (test_labels == 1))
    
    # Calculate accuracy
    accuracy = (TP + TN) / (TP + TN + FP + FN)
    
    # Store results
    fold_results.append({
        "Fold": fold + 1,
        "TP": TP,
        "FN": FN,
        "TN": TN,
        "FP": FP,
        "Accuracy": accuracy * 100  # Convert to percentage
    })
    
    # Print results for this fold
    print(f"Fold {fold + 1} Results:")
    print(f"TP: {TP}")
    print(f"FN: {FN}")
    print(f"TN: {TN}")
    print(f"FP: {FP}")
    print(f"Accuracy: {accuracy}")
    print()

# Convert to DataFrame for easier handling
df = pd.DataFrame(fold_results)

# Calculate average accuracy
average_accuracy = df["Accuracy"].mean()

# Add the average row
df = df.append({
    "Fold": "Rata-rata (%)",
    "TP": "",
    "FN": "",
    "TN": "",
    "FP": "",
    "Accuracy": round(average_accuracy, 2)
}, ignore_index=True)

# Create the table
fig, ax = plt.subplots(figsize=(8, 4))  # Set size frame
ax.axis('tight')
ax.axis('off')
table = ax.table(cellText=df.values, colLabels=df.columns, cellLoc='center', loc='center')

# Style the table
table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1.2, 1.2)

# Save as image
plt.savefig("performance_table.png", bbox_inches='tight', pad_inches=0.1)
plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step
# Fold 1 Results:
# TP: 0
# FN: 100
# TN: 100
# FP: 0
# Accuracy: 0.5
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 20s 4s/step
# Fold 2 Results:
# TP: 0
# FN: 100
# TN: 100
# FP: 0
# Accuracy: 0.5
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001BDE9F1AE50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001BDE9F1AE50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/5 ━━━━━━━━━━━━━━━━━━━━ 3s 4s/stepWARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001BDE9F1AE50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001BDE9F1AE50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 20s 4s/step
# Fold 3 Results:
# TP: 0
# FN: 100
# TN: 100
# FP: 0
# Accuracy: 0.5
