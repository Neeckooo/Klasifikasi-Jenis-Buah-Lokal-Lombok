# %%
import numpy as np
import pandas as pd
import pathlib
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from sklearn.metrics import confusion_matrix
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from sklearn.model_selection import KFold

# %%
# Parameter
train_dir = "D:/kuliah/Tugas Akhir/Code/Klasifikasi Jenis Buah Lokal/dataset/hsv_dataset/train"
validation_dir = "D:/kuliah/Tugas Akhir/Code/Klasifikasi Jenis Buah Lokal/dataset/hsv_dataset/val"
test_dir = "D:/kuliah/Tugas Akhir/Code/Klasifikasi Jenis Buah Lokal/dataset/test" 
k = 3  # Jumlah fold untuk K-FCV
epochs = 50  # Jumlah epoch untuk training model per fold
batch_size = 64  # Batch size

# Image size
IMG_SIZE = (300, 300)

# %%
# Import data
train_datagen = ImageDataGenerator(rescale=1.0 / 255)
test_datagen = ImageDataGenerator(rescale=1.0 / 255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=IMG_SIZE,
    batch_size=batch_size,
    class_mode="categorical",
    shuffle=True
)

validation_generator = test_datagen.flow_from_directory(
    validation_dir,
    target_size=IMG_SIZE,
    batch_size=batch_size,
    class_mode="categorical",
    shuffle=False
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=IMG_SIZE,
    batch_size=batch_size,
    class_mode="categorical",
    shuffle=False
)
# Out:
# Found 2100 images belonging to 3 classes.
# Found 600 images belonging to 3 classes.
# Found 300 images belonging to 3 classes.

# %%
def get_batch(generator, index):
    data = []
    labels = []
    for i in index:
        x, y = generator[i]
        data.extend(x)
        labels.extend(y)
    return np.array(data), np.array(labels)

# %%
def create_model():
    base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(300, 300, 3))
    model = Sequential([
        base_model,
        Flatten(),
        Dropout(0.5),
        Dense(16, activation="relu"),
        Dropout(0.5),
        Dense(3, activation="softmax"),
    ])

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
        loss="categorical_crossentropy",
        metrics=["accuracy", tf.keras.metrics.Precision(), tf.keras.metrics.Recall()],
    )
    
    return model

model = create_model()
print(model.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)           │ ?                      │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,587,712 (89.98 MB)
#  Trainable params: 23,534,592 (89.78 MB)
#  Non-trainable params: 53,120 (207.50 KB)
# None

# %%
def plot_history(history_list, k):
    fig, axs = plt.subplots(nrows=k, ncols=2, figsize=(12, k * 4))

    for i, history in enumerate(history_list):
        # Plot Accuracy
        axs[i, 0].plot(history['accuracy'], label=f'Train Fold {i+1}')
        axs[i, 0].plot(history['val_accuracy'], label=f'Validation Fold {i+1}')
        axs[i, 0].set_title(f'Fold {i+1} - Training and Validation Accuracy')
        axs[i, 0].set_xlabel('Epochs')
        axs[i, 0].set_ylabel('Accuracy')
        axs[i, 0].legend()

        # Plot Loss
        axs[i, 1].plot(history['loss'], label=f'Train Fold {i+1}')
        axs[i, 1].plot(history['val_loss'], label=f'Validation Fold {i+1}')
        axs[i, 1].set_title(f'Fold {i+1} - Training and Validation Loss')
        axs[i, 1].set_xlabel('Epochs')
        axs[i, 1].set_ylabel('Loss')
        axs[i, 1].legend()

    plt.tight_layout()
    plt.show()

# %%
# Evaluasi dengan K-FCV
history_list = []
average_acc = 0
average_loss = 0

kf = KFold(n_splits=k, shuffle=True, random_state=42)

# List to store accuracy and loss for each fold
fold_accuracy = []
fold_loss = []
test_accuracies = []

for fold, (train_index, val_index) in enumerate(kf.split(train_generator)):
    # Dapatkan batch data pelatihan dan validasi berdasarkan indeks fold
    train_data, train_labels = get_batch(train_generator, train_index)
    val_data, val_labels = get_batch(train_generator, val_index)

    # Buat model baru untuk setiap fold
    model = create_model()

    # Latih model menggunakan data pelatihan
    history = model.fit(
        train_data,
        train_labels,
        epochs=epochs,
        validation_data=(val_data, val_labels),
        verbose=1,  # Tampilkan informasi training per epoch
    )

    history_list.append(history.history)

    # Save the model for each fold
    model.save(f"D:/kuliah/Tugas Akhir/Code/Klasifikasi Jenis Buah Lokal/models/K-Fold Validation/ResNet50-HSV_fold_{fold+1}.h5")
    

    # Evaluate the model using the validation data
    val_loss, val_accuracy, val_precision, val_recall = model.evaluate(val_data, val_labels)
    fold_accuracy.append(val_accuracy)
    fold_loss.append(val_loss)

    print(f"Fold {fold+1} - Validation Accuracy: {val_accuracy}")
    print(f"Fold {fold+1} - Validation Loss: {val_loss}")

    # Evaluate the model using the test data
    test_loss, test_accuracy, test_precision, test_recall = model.evaluate(test_generator)
    test_accuracies.append(test_accuracy)
    print(f"Fold {fold+1} - Test Accuracy: {test_accuracy}")
    print(f"Fold {fold+1} - Test Loss: {test_loss}")

# Calculate average accuracy and loss across all folds
average_acc = np.mean(fold_accuracy)
average_loss = np.mean(fold_loss)
average_test_accuracy = np.mean(test_accuracies)

print(f"\nAverage Validation Accuracy: {average_acc}")
print(f"Average Validation Loss: {average_loss}")
print(f"\nAverage Test Accuracy: {average_test_accuracy}")

# Plotting hasil training dan validasi untuk setiap fold
plot_history(history_list, k)
# Out:
# Epoch 1/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 464s 10s/step - accuracy: 0.7042 - loss: 1.0774 - precision_1: 0.7504 - recall_1: 0.6599 - val_accuracy: 0.3196 - val_loss: 1.7074 - val_precision_1: 0.3196 - val_recall_1: 0.3196
# Epoch 2/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 432s 10s/step - accuracy: 0.9458 - loss: 0.1243 - precision_1: 0.9693 - recall_1: 0.9135 - val_accuracy: 0.3267 - val_loss: 3.8516 - val_precision_1: 0.3267 - val_recall_1: 0.3267
# Epoch 3/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 431s 10s/step - accuracy: 0.9604 - loss: 0.1011 - precision_1: 0.9829 - recall_1: 0.9473 - val_accuracy: 0.3267 - val_loss: 5.9414 - val_precision_1: 0.3267 - val_recall_1: 0.3267
# Epoch 4/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 429s 10s/step - accuracy: 0.9623 - loss: 0.1085 - precision_1: 0.9864 - recall_1: 0.9382 - val_accuracy: 0.3267 - val_loss: 7.8449 - val_precision_1: 0.3267 - val_recall_1: 0.3267
# Epoch 5/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 430s 10s/step - accuracy: 0.9656 - loss: 0.0758 - precision_1: 0.9904 - recall_1: 0.9477 - val_accuracy: 0.3267 - val_loss: 7.8258 - val_precision_1: 0.3267 - val_recall_1: 0.3267
# Epoch 6/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 432s 10s/step - accuracy: 0.9606 - loss: 0.0952 - precision_1: 0.9907 - recall_1: 0.9351 - val_accuracy: 0.3267 - val_loss: 3.6693 - val_precision_1: 0.3267 - val_recall_1: 0.3267
# Epoch 7/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 437s 10s/step - accuracy: 0.9699 - loss: 0.0839 - precision_1: 0.9882 - recall_1: 0.9509 - val_accuracy: 0.3210 - val_loss: 4.9263 - val_precision_1: 0.3210 - val_recall_1: 0.3210
# Epoch 8/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 437s 10s/step - accuracy: 0.9651 - loss: 0.0603 - precision_1: 0.9980 - recall_1: 0.9490 - val_accuracy: 0.3537 - val_loss: 4.7060 - val_precision_1: 0.3537 - val_recall_1: 0.3537
# Epoch 9/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 436s 10s/step - accuracy: 0.9786 - loss: 0.0615 - precision_1: 0.9970 - recall_1: 0.9471 - val_accuracy: 0.4702 - val_loss: 3.3266 - val_precision_1: 0.4702 - val_recall_1: 0.4702
# Epoch 10/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 437s 10s/step - accuracy: 0.9691 - loss: 0.0655 - precision_1: 0.9947 - recall_1: 0.9419 - val_accuracy: 0.3778 - val_loss: 2.0254 - val_precision_1: 0.3778 - val_recall_1: 0.3778
# Epoch 11/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 436s 10s/step - accuracy: 0.9777 - loss: 0.0619 - precision_1: 0.9990 - recall_1: 0.9451 - val_accuracy: 0.5312 - val_loss: 1.2519 - val_precision_1: 0.5364 - val_recall_1: 0.5227
# Epoch 12/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 436s 10s/step - accuracy: 0.9716 - loss: 0.0478 - precision_1: 0.9978 - recall_1: 0.9579 - val_accuracy: 0.7599 - val_loss: 0.6197 - val_precision_1: 0.7590 - val_recall_1: 0.7514
# Epoch 13/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 435s 10s/step - accuracy: 0.9605 - loss: 0.0668 - precision_1: 0.9995 - recall_1: 0.9398 - val_accuracy: 0.9517 - val_loss: 0.1376 - val_precision_1: 0.9556 - val_recall_1: 0.9474
# Epoch 14/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 436s 10s/step - accuracy: 0.9670 - loss: 0.0645 - precision_1: 0.9979 - recall_1: 0.9414 - val_accuracy: 0.9872 - val_loss: 0.0394 - val_precision_1: 0.9886 - val_recall_1: 0.9872
# Epoch 15/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 436s 10s/step - accuracy: 0.9753 - loss: 0.0500 - precision_1: 0.9963 - recall_1: 0.9559 - val_accuracy: 0.9957 - val_loss: 0.0230 - val_precision_1: 0.9957 - val_recall_1: 0.9943
# Epoch 16/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 411s 9s/step - accuracy: 0.9697 - loss: 0.0633 - precision_1: 0.9973 - recall_1: 0.9466 - val_accuracy: 0.9943 - val_loss: 0.0269 - val_precision_1: 0.9957 - val_recall_1: 0.9943
# Epoch 17/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 388s 9s/step - accuracy: 0.9688 - loss: 0.0709 - precision_1: 0.9994 - recall_1: 0.9405 - val_accuracy: 0.9943 - val_loss: 0.0230 - val_precision_1: 0.9943 - val_recall_1: 0.9943
# Epoch 18/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 387s 9s/step - accuracy: 0.9574 - loss: 0.0773 - precision_1: 0.9957 - recall_1: 0.9328 - val_accuracy: 0.9929 - val_loss: 0.0266 - val_precision_1: 0.9929 - val_recall_1: 0.9929
# Epoch 19/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 402s 9s/step - accuracy: 0.9589 - loss: 0.1648 - precision_1: 0.9959 - recall_1: 0.9383 - val_accuracy: 0.9844 - val_loss: 0.0612 - val_precision_1: 0.9858 - val_recall_1: 0.9844
# Epoch 20/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 434s 10s/step - accuracy: 0.9604 - loss: 0.0828 - precision_1: 0.9972 - recall_1: 0.9266 - val_accuracy: 0.9957 - val_loss: 0.0067 - val_precision_1: 0.9957 - val_recall_1: 0.9957
# Epoch 21/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 436s 10s/step - accuracy: 0.9393 - loss: 0.2490 - precision_1: 0.9875 - recall_1: 0.9154 - val_accuracy: 0.9957 - val_loss: 0.0198 - val_precision_1: 0.9957 - val_recall_1: 0.9929
# Epoch 22/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 433s 10s/step - accuracy: 0.9598 - loss: 0.0792 - precision_1: 0.9942 - recall_1: 0.9405 - val_accuracy: 1.0000 - val_loss: 0.0011 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 23/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 435s 10s/step - accuracy: 0.9736 - loss: 0.0696 - precision_1: 0.9967 - recall_1: 0.9545 - val_accuracy: 0.9943 - val_loss: 0.0269 - val_precision_1: 0.9943 - val_recall_1: 0.9943
# Epoch 24/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 434s 10s/step - accuracy: 0.9826 - loss: 0.0485 - precision_1: 0.9985 - recall_1: 0.9582 - val_accuracy: 0.9986 - val_loss: 0.0017 - val_precision_1: 0.9986 - val_recall_1: 0.9986
# Epoch 25/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 435s 10s/step - accuracy: 0.9742 - loss: 0.0576 - precision_1: 0.9995 - recall_1: 0.9481 - val_accuracy: 0.9986 - val_loss: 0.0018 - val_precision_1: 0.9986 - val_recall_1: 0.9986
# Epoch 26/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 434s 10s/step - accuracy: 0.9783 - loss: 0.0446 - precision_1: 0.9997 - recall_1: 0.9611 - val_accuracy: 1.0000 - val_loss: 4.2070e-05 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 27/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 435s 10s/step - accuracy: 0.9801 - loss: 0.0462 - precision_1: 1.0000 - recall_1: 0.9579 - val_accuracy: 1.0000 - val_loss: 2.7337e-06 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 28/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 435s 10s/step - accuracy: 0.9851 - loss: 0.0339 - precision_1: 0.9998 - recall_1: 0.9697 - val_accuracy: 1.0000 - val_loss: 3.8877e-07 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 29/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 434s 10s/step - accuracy: 0.9793 - loss: 0.0409 - precision_1: 0.9985 - recall_1: 0.9633 - val_accuracy: 1.0000 - val_loss: 1.1582e-07 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 30/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 434s 10s/step - accuracy: 0.9746 - loss: 0.0501 - precision_1: 0.9968 - recall_1: 0.9545 - val_accuracy: 1.0000 - val_loss: 1.1497e-07 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 31/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 435s 10s/step - accuracy: 0.9803 - loss: 0.0492 - precision_1: 1.0000 - recall_1: 0.9549 - val_accuracy: 1.0000 - val_loss: 1.4545e-07 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 32/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 434s 10s/step - accuracy: 0.9778 - loss: 0.0466 - precision_1: 1.0000 - recall_1: 0.9578 - val_accuracy: 1.0000 - val_loss: 1.2987e-07 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 33/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 435s 10s/step - accuracy: 0.9802 - loss: 0.0463 - precision_1: 1.0000 - recall_1: 0.9578 - val_accuracy: 1.0000 - val_loss: 9.3807e-08 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 34/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 434s 10s/step - accuracy: 0.9823 - loss: 0.0414 - precision_1: 1.0000 - recall_1: 0.9627 - val_accuracy: 1.0000 - val_loss: 4.5041e-08 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 35/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 435s 10s/step - accuracy: 0.9711 - loss: 0.0636 - precision_1: 0.9998 - recall_1: 0.9419 - val_accuracy: 1.0000 - val_loss: 4.4703e-08 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 36/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 435s 10s/step - accuracy: 0.9780 - loss: 0.0497 - precision_1: 1.0000 - recall_1: 0.9545 - val_accuracy: 1.0000 - val_loss: 5.2661e-08 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 37/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 434s 10s/step - accuracy: 0.9791 - loss: 0.0386 - precision_1: 1.0000 - recall_1: 0.9650 - val_accuracy: 1.0000 - val_loss: 1.4900e-07 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 38/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 434s 10s/step - accuracy: 0.9737 - loss: 0.0642 - precision_1: 1.0000 - recall_1: 0.9410 - val_accuracy: 1.0000 - val_loss: 5.4480e-07 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 39/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 434s 10s/step - accuracy: 0.9834 - loss: 0.0372 - precision_1: 1.0000 - recall_1: 0.9659 - val_accuracy: 1.0000 - val_loss: 5.3126e-07 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 40/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 435s 10s/step - accuracy: 0.9779 - loss: 0.0483 - precision_1: 1.0000 - recall_1: 0.9558 - val_accuracy: 1.0000 - val_loss: 3.9263e-07 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 41/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 434s 10s/step - accuracy: 0.9794 - loss: 0.0419 - precision_1: 1.0000 - recall_1: 0.9616 - val_accuracy: 1.0000 - val_loss: 2.7886e-07 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 42/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 434s 10s/step - accuracy: 0.9787 - loss: 0.0447 - precision_1: 1.0000 - recall_1: 0.9591 - val_accuracy: 1.0000 - val_loss: 2.1487e-07 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 43/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 435s 10s/step - accuracy: 0.9821 - loss: 0.0378 - precision_1: 1.0000 - recall_1: 0.9654 - val_accuracy: 1.0000 - val_loss: 1.5171e-07 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 44/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 435s 10s/step - accuracy: 0.9763 - loss: 0.1010 - precision_1: 0.9924 - recall_1: 0.9511 - val_accuracy: 0.7287 - val_loss: 7.3073 - val_precision_1: 0.7313 - val_recall_1: 0.7230
# Epoch 45/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 435s 10s/step - accuracy: 0.9600 - loss: 0.1005 - precision_1: 0.9945 - recall_1: 0.9287 - val_accuracy: 0.7685 - val_loss: 21.7502 - val_precision_1: 0.7685 - val_recall_1: 0.7685
# Epoch 46/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 434s 10s/step - accuracy: 0.9675 - loss: 0.0753 - precision_1: 0.9936 - recall_1: 0.9503 - val_accuracy: 0.9560 - val_loss: 2.9672 - val_precision_1: 0.9560 - val_recall_1: 0.9560
# Epoch 47/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 434s 10s/step - accuracy: 0.9733 - loss: 0.1437 - precision_1: 0.9896 - recall_1: 0.9611 - val_accuracy: 0.8423 - val_loss: 12.4853 - val_precision_1: 0.8423 - val_recall_1: 0.8423
# Epoch 48/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 435s 10s/step - accuracy: 0.9674 - loss: 0.1460 - precision_1: 0.9954 - recall_1: 0.9454 - val_accuracy: 0.9801 - val_loss: 0.1881 - val_precision_1: 0.9801 - val_recall_1: 0.9801
# Epoch 49/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 434s 10s/step - accuracy: 0.9687 - loss: 0.0547 - precision_1: 0.9915 - recall_1: 0.9570 - val_accuracy: 1.0000 - val_loss: 3.9477e-04 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 50/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 435s 10s/step - accuracy: 0.9808 - loss: 0.0481 - precision_1: 0.9960 - recall_1: 0.9601 - val_accuracy: 1.0000 - val_loss: 1.9338e-05 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 1.0000 - loss: 2.1537e-05 - precision_1: 1.0000 - recall_1: 1.0000
# Fold 1 - Validation Accuracy: 1.0
# Fold 1 - Validation Loss: 1.933753810590133e-05
# c:\Users\CATUR WARGA COMPUTER\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - accuracy: 0.5599 - loss: 230.6494 - precision_1: 0.5599 - recall_1: 0.5599
# Fold 1 - Test Accuracy: 0.3333333432674408
# Fold 1 - Test Loss: 327.12579345703125
# Epoch 1/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 471s 10s/step - accuracy: 0.7179 - loss: 1.1196 - precision_2: 0.7528 - recall_2: 0.6127 - val_accuracy: 0.3466 - val_loss: 3.1113 - val_precision_2: 0.3466 - val_recall_2: 0.3466
# Epoch 2/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 436s 10s/step - accuracy: 0.9748 - loss: 0.1464 - precision_2: 0.9822 - recall_2: 0.8947 - val_accuracy: 0.3466 - val_loss: 5.4661 - val_precision_2: 0.3466 - val_recall_2: 0.3466
# Epoch 3/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 434s 10s/step - accuracy: 0.9716 - loss: 0.1636 - precision_2: 0.9891 - recall_2: 0.8676 - val_accuracy: 0.3466 - val_loss: 3.8927 - val_precision_2: 0.3466 - val_recall_2: 0.3466
# Epoch 4/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 434s 10s/step - accuracy: 0.9900 - loss: 0.0966 - precision_2: 0.9950 - recall_2: 0.9149 - val_accuracy: 0.3466 - val_loss: 3.1138 - val_precision_2: 0.3466 - val_recall_2: 0.3466
# Epoch 5/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 437s 10s/step - accuracy: 0.9805 - loss: 0.1218 - precision_2: 0.9931 - recall_2: 0.8953 - val_accuracy: 0.3509 - val_loss: 1.3998 - val_precision_2: 0.3575 - val_recall_2: 0.3509
# Epoch 6/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 436s 10s/step - accuracy: 0.9885 - loss: 0.1038 - precision_2: 0.9987 - recall_2: 0.9076 - val_accuracy: 0.2855 - val_loss: 1.0826 - val_precision_2: 0.5439 - val_recall_2: 0.0440
# Epoch 7/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 435s 10s/step - accuracy: 0.9841 - loss: 0.1010 - precision_2: 0.9990 - recall_2: 0.9083 - val_accuracy: 0.4119 - val_loss: 1.5697 - val_precision_2: 0.4099 - val_recall_2: 0.3878
# Epoch 8/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 434s 10s/step - accuracy: 0.9890 - loss: 0.1126 - precision_2: 0.9983 - recall_2: 0.8993 - val_accuracy: 0.3835 - val_loss: 1.7060 - val_precision_2: 0.3920 - val_recall_2: 0.3736
# Epoch 9/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 434s 10s/step - accuracy: 0.9912 - loss: 0.1081 - precision_2: 0.9971 - recall_2: 0.9084 - val_accuracy: 0.6236 - val_loss: 0.8210 - val_precision_2: 0.6357 - val_recall_2: 0.6023
# Epoch 10/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 430s 10s/step - accuracy: 0.9935 - loss: 0.0943 - precision_2: 0.9994 - recall_2: 0.9141 - val_accuracy: 0.4460 - val_loss: 1.3579 - val_precision_2: 0.4506 - val_recall_2: 0.4020
# Epoch 11/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 431s 10s/step - accuracy: 0.9928 - loss: 0.0848 - precision_2: 0.9990 - recall_2: 0.9229 - val_accuracy: 0.7443 - val_loss: 0.5421 - val_precision_2: 0.8795 - val_recall_2: 0.6534
# Epoch 12/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 430s 10s/step - accuracy: 0.9861 - loss: 0.0934 - precision_2: 0.9921 - recall_2: 0.9239 - val_accuracy: 0.7060 - val_loss: 0.4922 - val_precision_2: 0.9138 - val_recall_2: 0.6776
# Epoch 13/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 430s 10s/step - accuracy: 0.9885 - loss: 0.1256 - precision_2: 0.9969 - recall_2: 0.9047 - val_accuracy: 0.7628 - val_loss: 0.3505 - val_precision_2: 0.7726 - val_recall_2: 0.7528
# Epoch 14/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 431s 10s/step - accuracy: 0.9821 - loss: 0.1160 - precision_2: 0.9958 - recall_2: 0.8997 - val_accuracy: 0.4787 - val_loss: 2.0013 - val_precision_2: 0.4807 - val_recall_2: 0.4787
# Epoch 15/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 430s 10s/step - accuracy: 0.9813 - loss: 0.1259 - precision_2: 0.9899 - recall_2: 0.9014 - val_accuracy: 0.9886 - val_loss: 0.0542 - val_precision_2: 0.9900 - val_recall_2: 0.9801
# Epoch 16/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 430s 10s/step - accuracy: 0.9942 - loss: 0.0953 - precision_2: 0.9988 - recall_2: 0.9104 - val_accuracy: 0.9986 - val_loss: 0.0144 - val_precision_2: 0.9986 - val_recall_2: 0.9986
# Epoch 17/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 432s 10s/step - accuracy: 0.9898 - loss: 0.1416 - precision_2: 0.9977 - recall_2: 0.8968 - val_accuracy: 0.9688 - val_loss: 0.1298 - val_precision_2: 0.9825 - val_recall_2: 0.9574
# Epoch 18/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 431s 10s/step - accuracy: 0.9933 - loss: 0.0922 - precision_2: 0.9975 - recall_2: 0.9141 - val_accuracy: 0.9645 - val_loss: 0.1515 - val_precision_2: 0.9684 - val_recall_2: 0.9588
# Epoch 19/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 431s 10s/step - accuracy: 0.9942 - loss: 0.0893 - precision_2: 0.9993 - recall_2: 0.9148 - val_accuracy: 0.9844 - val_loss: 0.0725 - val_precision_2: 0.9841 - val_recall_2: 0.9702
# Epoch 20/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 431s 10s/step - accuracy: 0.9913 - loss: 0.0910 - precision_2: 0.9993 - recall_2: 0.9134 - val_accuracy: 0.9972 - val_loss: 0.0268 - val_precision_2: 0.9972 - val_recall_2: 0.9957
# Epoch 21/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 431s 10s/step - accuracy: 0.9949 - loss: 0.0924 - precision_2: 1.0000 - recall_2: 0.9102 - val_accuracy: 0.9972 - val_loss: 0.0206 - val_precision_2: 0.9972 - val_recall_2: 0.9972
# Epoch 22/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 432s 10s/step - accuracy: 0.9933 - loss: 0.0882 - precision_2: 0.9977 - recall_2: 0.9220 - val_accuracy: 0.9957 - val_loss: 0.0596 - val_precision_2: 0.9957 - val_recall_2: 0.9929
# Epoch 23/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 431s 10s/step - accuracy: 0.9955 - loss: 0.1055 - precision_2: 0.9987 - recall_2: 0.9029 - val_accuracy: 0.9886 - val_loss: 0.0432 - val_precision_2: 0.9900 - val_recall_2: 0.9886
# Epoch 24/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 432s 10s/step - accuracy: 0.9909 - loss: 0.1011 - precision_2: 0.9978 - recall_2: 0.9099 - val_accuracy: 1.0000 - val_loss: 0.0037 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 25/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 431s 10s/step - accuracy: 0.9914 - loss: 0.0980 - precision_2: 0.9960 - recall_2: 0.9067 - val_accuracy: 1.0000 - val_loss: 0.0010 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 26/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 431s 10s/step - accuracy: 0.9892 - loss: 0.0846 - precision_2: 0.9973 - recall_2: 0.9193 - val_accuracy: 1.0000 - val_loss: 0.0036 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 27/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 431s 10s/step - accuracy: 0.9920 - loss: 0.1020 - precision_2: 0.9990 - recall_2: 0.9014 - val_accuracy: 1.0000 - val_loss: 0.0020 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 28/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 432s 10s/step - accuracy: 0.9880 - loss: 0.0899 - precision_2: 0.9989 - recall_2: 0.9143 - val_accuracy: 1.0000 - val_loss: 0.0016 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 29/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 431s 10s/step - accuracy: 0.9879 - loss: 0.1027 - precision_2: 0.9983 - recall_2: 0.8997 - val_accuracy: 0.9972 - val_loss: 0.0777 - val_precision_2: 0.9972 - val_recall_2: 0.9957
# Epoch 30/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 431s 10s/step - accuracy: 0.9956 - loss: 0.0879 - precision_2: 0.9990 - recall_2: 0.9141 - val_accuracy: 0.9972 - val_loss: 0.0166 - val_precision_2: 0.9972 - val_recall_2: 0.9972
# Epoch 31/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 431s 10s/step - accuracy: 0.9890 - loss: 0.0774 - precision_2: 0.9989 - recall_2: 0.9264 - val_accuracy: 1.0000 - val_loss: 3.1310e-04 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 32/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 431s 10s/step - accuracy: 0.9913 - loss: 0.0912 - precision_2: 1.0000 - recall_2: 0.9082 - val_accuracy: 1.0000 - val_loss: 1.5078e-05 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 33/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 432s 10s/step - accuracy: 0.9930 - loss: 0.0991 - precision_2: 0.9989 - recall_2: 0.9000 - val_accuracy: 1.0000 - val_loss: 1.4593e-05 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 34/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 434s 10s/step - accuracy: 0.9894 - loss: 0.0922 - precision_2: 1.0000 - recall_2: 0.9070 - val_accuracy: 1.0000 - val_loss: 8.8029e-06 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 35/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 435s 10s/step - accuracy: 0.9849 - loss: 0.0924 - precision_2: 1.0000 - recall_2: 0.9073 - val_accuracy: 1.0000 - val_loss: 5.9103e-06 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 36/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 435s 10s/step - accuracy: 0.9930 - loss: 0.0946 - precision_2: 0.9991 - recall_2: 0.9038 - val_accuracy: 1.0000 - val_loss: 1.1025e-05 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 37/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 434s 10s/step - accuracy: 0.9917 - loss: 0.0886 - precision_2: 1.0000 - recall_2: 0.9090 - val_accuracy: 1.0000 - val_loss: 7.1653e-06 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 38/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 436s 10s/step - accuracy: 0.9884 - loss: 0.0876 - precision_2: 1.0000 - recall_2: 0.9106 - val_accuracy: 1.0000 - val_loss: 6.2921e-06 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 39/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 435s 10s/step - accuracy: 0.9936 - loss: 0.0799 - precision_2: 1.0000 - recall_2: 0.9171 - val_accuracy: 1.0000 - val_loss: 1.7410e-06 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 40/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 433s 10s/step - accuracy: 0.9942 - loss: 0.0815 - precision_2: 1.0000 - recall_2: 0.9148 - val_accuracy: 1.0000 - val_loss: 1.7239e-06 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 41/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 435s 10s/step - accuracy: 0.9909 - loss: 0.0892 - precision_2: 1.0000 - recall_2: 0.9076 - val_accuracy: 1.0000 - val_loss: 2.9191e-06 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 42/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 435s 10s/step - accuracy: 0.9915 - loss: 0.0790 - precision_2: 1.0000 - recall_2: 0.9176 - val_accuracy: 1.0000 - val_loss: 2.2489e-06 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 43/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 435s 10s/step - accuracy: 0.9911 - loss: 0.0790 - precision_2: 1.0000 - recall_2: 0.9174 - val_accuracy: 1.0000 - val_loss: 1.7235e-06 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 44/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 434s 10s/step - accuracy: 0.9868 - loss: 0.0919 - precision_2: 0.9998 - recall_2: 0.9044 - val_accuracy: 1.0000 - val_loss: 5.8806e-07 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 45/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 435s 10s/step - accuracy: 0.9898 - loss: 0.0824 - precision_2: 1.0000 - recall_2: 0.9139 - val_accuracy: 1.0000 - val_loss: 9.2686e-07 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 46/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 435s 10s/step - accuracy: 0.9937 - loss: 0.0618 - precision_2: 1.0000 - recall_2: 0.9345 - val_accuracy: 1.0000 - val_loss: 1.2494e-06 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 47/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 436s 10s/step - accuracy: 0.9852 - loss: 0.0915 - precision_2: 1.0000 - recall_2: 0.9046 - val_accuracy: 1.0000 - val_loss: 1.4921e-06 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 48/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 435s 10s/step - accuracy: 0.9915 - loss: 0.0820 - precision_2: 1.0000 - recall_2: 0.9125 - val_accuracy: 1.0000 - val_loss: 1.6990e-06 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 49/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 437s 10s/step - accuracy: 0.9939 - loss: 0.0801 - precision_2: 1.0000 - recall_2: 0.9136 - val_accuracy: 1.0000 - val_loss: 1.8661e-06 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# Epoch 50/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 434s 10s/step - accuracy: 0.9896 - loss: 0.0831 - precision_2: 1.0000 - recall_2: 0.9114 - val_accuracy: 1.0000 - val_loss: 1.9364e-06 - val_precision_2: 1.0000 - val_recall_2: 1.0000
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 1.0000 - loss: 1.1309e-06 - precision_2: 1.0000 - recall_2: 1.0000
# Fold 2 - Validation Accuracy: 1.0
# Fold 2 - Validation Loss: 1.9363626506674336e-06
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 18s 3s/step - accuracy: 0.5757 - loss: 85.8257 - precision_2: 0.5757 - recall_2: 0.5757
# Fold 2 - Test Accuracy: 0.35333332419395447
# Fold 2 - Test Loss: 156.59378051757812
# Epoch 1/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 475s 10s/step - accuracy: 0.7034 - loss: 1.0806 - precision_3: 0.7300 - recall_3: 0.6695 - val_accuracy: 0.3974 - val_loss: 2.0240 - val_precision_3: 0.4082 - val_recall_3: 0.3887
# Epoch 2/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 439s 10s/step - accuracy: 0.9584 - loss: 0.0970 - precision_3: 0.9899 - recall_3: 0.9372 - val_accuracy: 0.3324 - val_loss: 3.7584 - val_precision_3: 0.3324 - val_recall_3: 0.3324
# Epoch 3/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 439s 10s/step - accuracy: 0.9742 - loss: 0.0780 - precision_3: 0.9913 - recall_3: 0.9660 - val_accuracy: 0.3324 - val_loss: 3.6974 - val_precision_3: 0.3324 - val_recall_3: 0.3324
# Epoch 4/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 437s 10s/step - accuracy: 0.9744 - loss: 0.0399 - precision_3: 0.9955 - recall_3: 0.9669 - val_accuracy: 0.3324 - val_loss: 3.6808 - val_precision_3: 0.3324 - val_recall_3: 0.3324
# Epoch 5/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 442s 10s/step - accuracy: 0.9809 - loss: 0.0465 - precision_3: 0.9955 - recall_3: 0.9654 - val_accuracy: 0.3353 - val_loss: 3.2533 - val_precision_3: 0.3353 - val_recall_3: 0.3353
# Epoch 6/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 437s 10s/step - accuracy: 0.9747 - loss: 0.0760 - precision_3: 0.9888 - recall_3: 0.9655 - val_accuracy: 0.3627 - val_loss: 3.2168 - val_precision_3: 0.3627 - val_recall_3: 0.3627
# Epoch 7/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 439s 10s/step - accuracy: 0.9746 - loss: 0.0743 - precision_3: 0.9923 - recall_3: 0.9634 - val_accuracy: 0.3280 - val_loss: 2.0473 - val_precision_3: 0.3280 - val_recall_3: 0.3280
# Epoch 8/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 439s 10s/step - accuracy: 0.9736 - loss: 0.0523 - precision_3: 0.9973 - recall_3: 0.9585 - val_accuracy: 0.4046 - val_loss: 2.9850 - val_precision_3: 0.4046 - val_recall_3: 0.4046
# Epoch 9/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 439s 10s/step - accuracy: 0.9843 - loss: 0.0475 - precision_3: 0.9921 - recall_3: 0.9733 - val_accuracy: 0.4364 - val_loss: 2.0134 - val_precision_3: 0.4392 - val_recall_3: 0.4335
# Epoch 10/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 439s 10s/step - accuracy: 0.9855 - loss: 0.0233 - precision_3: 0.9937 - recall_3: 0.9806 - val_accuracy: 0.4075 - val_loss: 2.6519 - val_precision_3: 0.4075 - val_recall_3: 0.4075
# Epoch 11/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 438s 10s/step - accuracy: 0.9869 - loss: 0.0299 - precision_3: 1.0000 - recall_3: 0.9738 - val_accuracy: 0.4884 - val_loss: 2.0478 - val_precision_3: 0.4884 - val_recall_3: 0.4884
# Epoch 12/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 439s 10s/step - accuracy: 0.9849 - loss: 0.0276 - precision_3: 0.9999 - recall_3: 0.9753 - val_accuracy: 0.5824 - val_loss: 1.2447 - val_precision_3: 0.6153 - val_recall_3: 0.5824
# Epoch 13/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 438s 10s/step - accuracy: 0.9799 - loss: 0.0301 - precision_3: 0.9993 - recall_3: 0.9731 - val_accuracy: 0.6272 - val_loss: 0.9057 - val_precision_3: 0.6911 - val_recall_3: 0.6272
# Epoch 14/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 439s 10s/step - accuracy: 0.9793 - loss: 0.0410 - precision_3: 1.0000 - recall_3: 0.9628 - val_accuracy: 0.7023 - val_loss: 0.5993 - val_precision_3: 0.7737 - val_recall_3: 0.6720
# Epoch 15/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 438s 10s/step - accuracy: 0.9812 - loss: 0.0343 - precision_3: 0.9975 - recall_3: 0.9735 - val_accuracy: 0.7702 - val_loss: 0.5004 - val_precision_3: 0.8155 - val_recall_3: 0.7153
# Epoch 16/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 439s 10s/step - accuracy: 0.9874 - loss: 0.0275 - precision_3: 0.9977 - recall_3: 0.9783 - val_accuracy: 0.8699 - val_loss: 0.3695 - val_precision_3: 0.8924 - val_recall_3: 0.8512
# Epoch 17/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 438s 10s/step - accuracy: 0.9764 - loss: 0.0445 - precision_3: 0.9948 - recall_3: 0.9643 - val_accuracy: 0.9653 - val_loss: 0.1386 - val_precision_3: 0.9680 - val_recall_3: 0.9610
# Epoch 18/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 438s 10s/step - accuracy: 0.9791 - loss: 0.0486 - precision_3: 0.9961 - recall_3: 0.9667 - val_accuracy: 0.9783 - val_loss: 0.0548 - val_precision_3: 0.9797 - val_recall_3: 0.9783
# Epoch 19/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 438s 10s/step - accuracy: 0.9753 - loss: 0.0455 - precision_3: 0.9976 - recall_3: 0.9635 - val_accuracy: 0.9798 - val_loss: 0.0517 - val_precision_3: 0.9840 - val_recall_3: 0.9769
# Epoch 20/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 439s 10s/step - accuracy: 0.9737 - loss: 0.1090 - precision_3: 0.9932 - recall_3: 0.9554 - val_accuracy: 0.9523 - val_loss: 0.1881 - val_precision_3: 0.9523 - val_recall_3: 0.9523
# Epoch 21/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 439s 10s/step - accuracy: 0.9728 - loss: 0.0498 - precision_3: 0.9945 - recall_3: 0.9646 - val_accuracy: 0.9812 - val_loss: 0.0337 - val_precision_3: 0.9812 - val_recall_3: 0.9798
# Epoch 22/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 439s 10s/step - accuracy: 0.9810 - loss: 0.0299 - precision_3: 0.9976 - recall_3: 0.9735 - val_accuracy: 0.9986 - val_loss: 0.0064 - val_precision_3: 0.9986 - val_recall_3: 0.9971
# Epoch 23/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 439s 10s/step - accuracy: 0.9847 - loss: 0.0275 - precision_3: 0.9985 - recall_3: 0.9751 - val_accuracy: 0.9986 - val_loss: 0.0038 - val_precision_3: 0.9986 - val_recall_3: 0.9986
# Epoch 24/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 440s 10s/step - accuracy: 0.9832 - loss: 0.0347 - precision_3: 0.9984 - recall_3: 0.9728 - val_accuracy: 0.9986 - val_loss: 0.0031 - val_precision_3: 0.9986 - val_recall_3: 0.9986
# Epoch 25/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 435s 10s/step - accuracy: 0.9847 - loss: 0.0262 - precision_3: 0.9976 - recall_3: 0.9768 - val_accuracy: 0.9986 - val_loss: 0.0029 - val_precision_3: 1.0000 - val_recall_3: 0.9986
# Epoch 26/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 435s 10s/step - accuracy: 0.9845 - loss: 0.0282 - precision_3: 0.9990 - recall_3: 0.9747 - val_accuracy: 1.0000 - val_loss: 2.6736e-04 - val_precision_3: 1.0000 - val_recall_3: 1.0000
# Epoch 27/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 438s 10s/step - accuracy: 0.9854 - loss: 0.0233 - precision_3: 1.0000 - recall_3: 0.9794 - val_accuracy: 1.0000 - val_loss: 8.2951e-05 - val_precision_3: 1.0000 - val_recall_3: 1.0000
# Epoch 28/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 439s 10s/step - accuracy: 0.9815 - loss: 0.0271 - precision_3: 0.9992 - recall_3: 0.9753 - val_accuracy: 1.0000 - val_loss: 3.4248e-04 - val_precision_3: 1.0000 - val_recall_3: 1.0000
# Epoch 29/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 438s 10s/step - accuracy: 0.9883 - loss: 0.0258 - precision_3: 0.9995 - recall_3: 0.9768 - val_accuracy: 1.0000 - val_loss: 3.0296e-06 - val_precision_3: 1.0000 - val_recall_3: 1.0000
# Epoch 30/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 440s 10s/step - accuracy: 0.9830 - loss: 0.0244 - precision_3: 0.9958 - recall_3: 0.9776 - val_accuracy: 1.0000 - val_loss: 7.9432e-05 - val_precision_3: 1.0000 - val_recall_3: 1.0000
# Epoch 31/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 438s 10s/step - accuracy: 0.9915 - loss: 0.0232 - precision_3: 1.0000 - recall_3: 0.9801 - val_accuracy: 1.0000 - val_loss: 8.4675e-04 - val_precision_3: 1.0000 - val_recall_3: 1.0000
# Epoch 32/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 438s 10s/step - accuracy: 0.9871 - loss: 0.0242 - precision_3: 0.9996 - recall_3: 0.9781 - val_accuracy: 0.9986 - val_loss: 0.0015 - val_precision_3: 0.9986 - val_recall_3: 0.9986
# Epoch 33/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 438s 10s/step - accuracy: 0.9854 - loss: 0.0241 - precision_3: 1.0000 - recall_3: 0.9781 - val_accuracy: 1.0000 - val_loss: 4.0886e-05 - val_precision_3: 1.0000 - val_recall_3: 1.0000
# Epoch 34/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 438s 10s/step - accuracy: 0.9888 - loss: 0.0139 - precision_3: 1.0000 - recall_3: 0.9875 - val_accuracy: 1.0000 - val_loss: 1.7475e-05 - val_precision_3: 1.0000 - val_recall_3: 1.0000
# Epoch 35/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 439s 10s/step - accuracy: 0.9862 - loss: 0.0296 - precision_3: 0.9994 - recall_3: 0.9730 - val_accuracy: 0.9971 - val_loss: 0.0138 - val_precision_3: 0.9971 - val_recall_3: 0.9971
# Epoch 36/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 439s 10s/step - accuracy: 0.9867 - loss: 0.0307 - precision_3: 0.9998 - recall_3: 0.9729 - val_accuracy: 1.0000 - val_loss: 1.7227e-10 - val_precision_3: 1.0000 - val_recall_3: 1.0000
# Epoch 37/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 438s 10s/step - accuracy: 0.9861 - loss: 0.0260 - precision_3: 1.0000 - recall_3: 0.9767 - val_accuracy: 1.0000 - val_loss: 2.2395e-09 - val_precision_3: 1.0000 - val_recall_3: 1.0000
# Epoch 38/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 439s 10s/step - accuracy: 0.9840 - loss: 0.0305 - precision_3: 1.0000 - recall_3: 0.9729 - val_accuracy: 0.8555 - val_loss: 26.7216 - val_precision_3: 0.8555 - val_recall_3: 0.8555
# Epoch 39/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 439s 10s/step - accuracy: 0.9727 - loss: 0.8113 - precision_3: 0.9882 - recall_3: 0.9567 - val_accuracy: 0.9393 - val_loss: 1.8835 - val_precision_3: 0.9393 - val_recall_3: 0.9393
# Epoch 40/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 439s 10s/step - accuracy: 0.9710 - loss: 0.0904 - precision_3: 0.9873 - recall_3: 0.9571 - val_accuracy: 0.9393 - val_loss: 0.2032 - val_precision_3: 0.9393 - val_recall_3: 0.9393
# Epoch 41/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 439s 10s/step - accuracy: 0.9580 - loss: 0.1266 - precision_3: 0.9821 - recall_3: 0.9387 - val_accuracy: 0.9552 - val_loss: 1.6492 - val_precision_3: 0.9552 - val_recall_3: 0.9552
# Epoch 42/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 438s 10s/step - accuracy: 0.9715 - loss: 0.0761 - precision_3: 0.9860 - recall_3: 0.9635 - val_accuracy: 0.9538 - val_loss: 0.8005 - val_precision_3: 0.9538 - val_recall_3: 0.9538
# Epoch 43/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 439s 10s/step - accuracy: 0.9728 - loss: 0.0517 - precision_3: 0.9945 - recall_3: 0.9673 - val_accuracy: 0.9798 - val_loss: 0.1197 - val_precision_3: 0.9797 - val_recall_3: 0.9783
# Epoch 44/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 438s 10s/step - accuracy: 0.9711 - loss: 0.0627 - precision_3: 0.9905 - recall_3: 0.9611 - val_accuracy: 0.9971 - val_loss: 0.0344 - val_precision_3: 0.9971 - val_recall_3: 0.9971
# Epoch 45/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 438s 10s/step - accuracy: 0.9893 - loss: 0.0291 - precision_3: 0.9990 - recall_3: 0.9745 - val_accuracy: 0.9812 - val_loss: 3.2300 - val_precision_3: 0.9812 - val_recall_3: 0.9812
# Epoch 46/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 439s 10s/step - accuracy: 0.9821 - loss: 0.2636 - precision_3: 0.9950 - recall_3: 0.9696 - val_accuracy: 0.9480 - val_loss: 1.1044 - val_precision_3: 0.9507 - val_recall_3: 0.9465
# Epoch 47/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 439s 10s/step - accuracy: 0.9652 - loss: 0.0929 - precision_3: 0.9875 - recall_3: 0.9421 - val_accuracy: 1.0000 - val_loss: 4.9454e-04 - val_precision_3: 1.0000 - val_recall_3: 1.0000
# Epoch 48/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 437s 10s/step - accuracy: 0.9777 - loss: 0.0399 - precision_3: 0.9979 - recall_3: 0.9691 - val_accuracy: 1.0000 - val_loss: 2.4449e-06 - val_precision_3: 1.0000 - val_recall_3: 1.0000
# Epoch 49/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 439s 10s/step - accuracy: 0.9858 - loss: 0.0250 - precision_3: 1.0000 - recall_3: 0.9776 - val_accuracy: 1.0000 - val_loss: 9.4402e-08 - val_precision_3: 1.0000 - val_recall_3: 1.0000
# Epoch 50/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 438s 10s/step - accuracy: 0.9857 - loss: 0.0296 - precision_3: 1.0000 - recall_3: 0.9730 - val_accuracy: 1.0000 - val_loss: 4.5478e-08 - val_precision_3: 1.0000 - val_recall_3: 1.0000
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 1.0000 - loss: 4.4352e-08 - precision_3: 1.0000 - recall_3: 1.0000
# Fold 3 - Validation Accuracy: 1.0
# Fold 3 - Validation Loss: 4.5478461885295474e-08
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 17s 3s/step - accuracy: 0.5599 - loss: 359.0986 - precision_3: 0.5599 - recall_3: 0.5599
# Fold 3 - Test Accuracy: 0.3333333432674408
# Fold 3 - Test Loss: 555.9024047851562
#
# Average Validation Accuracy: 1.0
# Average Validation Loss: 7.106459739484687e-06
#
# Average Test Accuracy: 0.3400000035762787

# %%
# Additional code to evaluate and calculate TP, FN, TN, FP for each fold
fold_results = []

for fold in range(k):
    # Load the saved model for this fold
    model = load_model(f"D:/kuliah/Tugas Akhir/Code/Klasifikasi Jenis Buah Lokal/models/K-Fold Validation/ResNet50-HSV_fold_{fold+1}.h5")
    
    # Predict on the test data
    test_preds = model.predict(test_generator)
    test_preds_classes = np.argmax(test_preds, axis=1)
    test_labels = test_generator.classes
    
    # Calculate confusion matrix components
    TP = np.sum((test_preds_classes == 1) & (test_labels == 1))
    TN = np.sum((test_preds_classes == 0) & (test_labels == 0))
    FP = np.sum((test_preds_classes == 1) & (test_labels == 0))
    FN = np.sum((test_preds_classes == 0) & (test_labels == 1))
    
    # Calculate accuracy
    accuracy = (TP + TN) / (TP + TN + FP + FN)
    
    # Store results
    fold_results.append({
        "Fold": fold + 1,
        "TP": TP,
        "FN": FN,
        "TN": TN,
        "FP": FP,
        "Accuracy": accuracy * 100  # Convert to percentage
    })
    
    # Print results for this fold
    print(f"Fold {fold + 1} Results:")
    print(f"TP: {TP}")
    print(f"FN: {FN}")
    print(f"TN: {TN}")
    print(f"FP: {FP}")
    print(f"Accuracy: {accuracy}")
    print()

# Convert to DataFrame for easier handling
df = pd.DataFrame(fold_results)

# Calculate average accuracy
average_accuracy = df["Accuracy"].mean()

# Add the average row
df = df.append({
    "Fold": "Rata-rata (%)",
    "TP": "",
    "FN": "",
    "TN": "",
    "FP": "",
    "Accuracy": round(average_accuracy, 2)
}, ignore_index=True)

# Create the table
fig, ax = plt.subplots(figsize=(8, 4))  # Set size frame
ax.axis('tight')
ax.axis('off')
table = ax.table(cellText=df.values, colLabels=df.columns, cellLoc='center', loc='center')

# Style the table
table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1.2, 1.2)

# Save as image
plt.savefig("performance_table.png", bbox_inches='tight', pad_inches=0.1)
plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step
# Fold 1 Results:
# TP: 0
# FN: 100
# TN: 100
# FP: 0
# Accuracy: 0.5
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 18s 3s/step
# Fold 2 Results:
# TP: 6
# FN: 94
# TN: 100
# FP: 0
# Accuracy: 0.53
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001DE54DF1D30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001DE54DF1D30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/5 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/stepWARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001DE54DF1D30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001DE54DF1D30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 18s 3s/step
# Fold 3 Results:
# TP: 0
# FN: 100
# TN: 100
# FP: 0
# Accuracy: 0.5
